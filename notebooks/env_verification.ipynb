# %% [markdown]
# # ENV Verification

# %%
from lib.env import (get_fred_api_key, get_bls_api_key, get_fred_base_url, get_bls_base_url)

# %%
FRED_API_KEY = get_fred_api_key()
BLS_API_KEY = get_bls_api_key()

print(f"Loaded FRED key ({len(FRED_API_KEY)} chars)")
print(f"Loaded BLS key ({len(BLS_API_KEY)} chars)")

print(f"Loaded FRED base URL ({get_fred_base_url()})")
print(f"Loaded BLS base URL ({get_bls_base_url()})")
# Out:
# Loaded FRED key (32 chars)
# Loaded BLS key (32 chars)
# Loaded FRED base URL (https://api.stlouisfed.org/fred)
# Loaded BLS base URL (https://api.bls.gov/publicAPI/v2)
