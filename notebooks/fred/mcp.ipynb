# %% [markdown]
# # FRED MCP

# %%
# %reload_ext autoreload
# %autoreload 2

from lib.utils import print_json_vertical
from utils import call_tool, list_mcp_tools, show_tool_schema

# %% [markdown]
# ## FRED Tools

# %%
await list_mcp_tools()
# Out:
# fred.category_children: List the child categories for a FRED category.
# fred.category_series: List the series contained within a FRED category.
# fred.series_info: Fetch metadata for a single FRED series.
# fred.series_observations: Return observations for a series (limit defaults to 100).
# fred.series_updates: Return recently updated FRED series.
# fred.releases: List the available FRED releases.
# fred.release_series: List the series that belong to a FRED release.

# %% [markdown]
# ## fred.category_children

# %%
tool_name = "fred.category_children"
await show_tool_schema(tool_name)
# Out:
# {
#   "properties": {
#     "category_id": {
#       "title": "Category Id",
#       "type": "integer"
#     }
#   },
#   "required": [
#     "category_id"
#   ],
#   "title": "list_category_childrenArguments",
#   "type": "object"
# }

# %%
args = {"category_id": 0}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32991,
#     "name": "Money, Banking, & Finance",
#     "parent_id": 0
#   },
#   {
#     "id": 10,
#     "name": "Population, Employment, & Labor Markets",
#     "parent_id": 0
#   },
#   {
#     "id": 32992,
#     "name": "National Accounts",
#     "parent_id": 0
#   },
#   {
#     "id": 1,
#     "name": "Production & Business Activity",
#     "parent_id": 0
#   },
#   {
#     "id": 32455,
#     "name": "Prices",
#     "parent_id": 0
#   },
#   {
#     "id": 32263,
#     "name": "International Data",
#     "parent_id": 0
#   },
#   {
#     "id": 3008,
#     "name": "U.S. Regional Data",
#     "parent_id": 0
#   },
#   {
#     "id": 33060,
#     "name": "Academic Data",
#     "parent_id": 0
#   }
# ]

# %% [markdown]
# ## fred.category_series

# %%
tool_name = "fred.category_series"
await show_tool_schema(tool_name)
# Out:
# {
#   "properties": {
#     "category_id": {
#       "title": "Category Id",
#       "type": "integer"
#     },
#     "limit": {
#       "anyOf": [
#         {
#           "type": "integer"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "title": "Limit"
#     },
#     "order_by": {
#       "anyOf": [
#         {
#           "type": "string"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "title": "Order By"
#     }
#   },
#   "required": [
#     "category_id"
#   ],
#   "title": "list_category_seriesArguments",
#   "type": "object"
# }

# %%
args = {"category_id": 33913}
result = await call_tool(tool_name, args)
series = result.structuredContent['result'] # type: ignore
print_json_vertical(series)
# Out:
# {
#   "count": 5,
#   "limit": 1000,
#   "offset": 0,
#   "order_by": "series_id",
#   "realtime_end": "2026-01-01",
#   "realtime_start": "2026-01-01",
#   "seriess": [
#     {
#       "frequency": "Daily, 7-Day",
#       "frequency_short": "D",
#       "id": "CBBCHUSD",
#       "last_updated": "2026-01-01T19:05:41-06:00",
#       "notes": "All data is as of 5 PM PST. \n\nCopyright, 2018, Coinbase. \n\nReproduction of Coinbase data in any form is prohibited except with the prior written permission of Coinbase.",
#       "observation_end": "2026-01-01",
#       "observation_start": "2017-12-20",
#       "popularity": 25,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Coinbase Bitcoin Cash",
#       "units": "U.S. Dollars",
#       "units_short": "U.S. $"
#     },
#     {
#       "frequency": "Daily, 7-Day",
#       "frequency_short": "D",
#       "id": "CBBTCUSD",
# ...

# %% [markdown]
# ## fred.series_info

# %%
tool_name = "fred.series_info"
await show_tool_schema(tool_name)
# Out:
# {
#   "properties": {
#     "series_id": {
#       "title": "Series Id",
#       "type": "string"
#     }
#   },
#   "required": [
#     "series_id"
#   ],
#   "title": "get_series_infoArguments",
#   "type": "object"
# }

# %%
args = {"series_id": "CBBCHUSD"}
result = await call_tool(tool_name, args)
info = result.structuredContent['result'] # type: ignore
print_json_vertical(info)
# Out:
# {
#   "count": null,
#   "limit": null,
#   "offset": null,
#   "order_by": null,
#   "realtime_end": "2026-01-01",
#   "realtime_start": "2026-01-01",
#   "seriess": [
#     {
#       "frequency": "Daily, 7-Day",
#       "frequency_short": "D",
#       "id": "CBBCHUSD",
#       "last_updated": "2026-01-01T19:05:41-06:00",
#       "notes": "All data is as of 5 PM PST. \n\nCopyright, 2018, Coinbase. \n\nReproduction of Coinbase data in any form is prohibited except with the prior written permission of Coinbase.",
#       "observation_end": "2026-01-01",
#       "observation_start": "2017-12-20",
#       "popularity": 25,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Coinbase Bitcoin Cash",
#       "units": "U.S. Dollars",
#       "units_short": "U.S. $"
#     }
#   ],
#   "sort_order": null
# }

# %% [markdown]
# ## fred.series_observations

# %%
tool_name = "fred.series_observations"
await show_tool_schema(tool_name)
info = result.structuredContent['result'] # type: ignore
print_json_vertical(info)
# Out:
# {
#   "properties": {
#     "frequency": {
#       "anyOf": [
#         {
#           "type": "string"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "title": "Frequency"
#     },
#     "limit": {
#       "anyOf": [
#         {
#           "type": "integer"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": 100,
#       "title": "Limit"
#     },
#     "series_id": {
#       "title": "Series Id",
#       "type": "string"
#     },
#     "units": {
#       "anyOf": [
#         {
#           "type": "string"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "title": "Units"
#     }
#   },
#   "required": [
#     "series_id"
#   ],
#   "title": "get_series_observationsArguments",
#   "type": "object"
# }

# %%
args = {"series_id": "CBBCHUSD"}
result = await call_tool(tool_name, args)
seriess = result.structuredContent['result'] # type: ignore
print_json_vertical(seriess)
# Out:
# {
#   "count": 2935,
#   "limit": 100,
#   "observations": [
#     {
#       "date": "2017-12-20",
#       "realtime_end": "2026-01-01",
#       "realtime_start": "2026-01-01",
#       "value": "3746.84"
#     },
#     {
#       "date": "2017-12-21",
#       "realtime_end": "2026-01-01",
#       "realtime_start": "2026-01-01",
#       "value": "3162.53"
#     },
#     {
#       "date": "2017-12-22",
#       "realtime_end": "2026-01-01",
#       "realtime_start": "2026-01-01",
#       "value": "2719.99"
#     },
#     {
#       "date": "2017-12-23",
#       "realtime_end": "2026-01-01",
#       "realtime_start": "2026-01-01",
#       "value": "3160"
#     },
#     {
#       "date": "2017-12-24",
#       "realtime_end": "2026-01-01",
#       "realtime_start": "2026-01-01",
#       "value": "2919.01"
#     },
#     {
#       "date": "2017-12-25",
#       "realtime_end": "2026-01-01",
#       "realtime_start": "2026-01-01",
#       "value": "2835.99"
#     },
#     {
# ...

# %% [markdown]
# ## fred.series_updates

# %%
tool_name = "fred.series_updates"
await show_tool_schema(tool_name)
# Out:
# {
#   "properties": {
#     "limit": {
#       "anyOf": [
#         {
#           "type": "integer"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": 50,
#       "title": "Limit"
#     },
#     "offset": {
#       "anyOf": [
#         {
#           "type": "integer"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": 0,
#       "title": "Offset"
#     }
#   },
#   "title": "get_series_updatesArguments",
#   "type": "object"
# }

# %%
args = {"series_id": "CBBCHUSD"}
result = await call_tool(tool_name, args)
updates = result.structuredContent['result'] # type: ignore
print_json_vertical(updates)
# Out:
# {
#   "count": 2935,
#   "limit": 100,
#   "observations": [
#     {
#       "date": "2017-12-20",
#       "realtime_end": "2026-01-01",
#       "realtime_start": "2026-01-01",
#       "value": "3746.84"
#     },
#     {
#       "date": "2017-12-21",
#       "realtime_end": "2026-01-01",
#       "realtime_start": "2026-01-01",
#       "value": "3162.53"
#     },
#     {
#       "date": "2017-12-22",
#       "realtime_end": "2026-01-01",
#       "realtime_start": "2026-01-01",
#       "value": "2719.99"
#     },
#     {
#       "date": "2017-12-23",
#       "realtime_end": "2026-01-01",
#       "realtime_start": "2026-01-01",
#       "value": "3160"
#     },
#     {
#       "date": "2017-12-24",
#       "realtime_end": "2026-01-01",
#       "realtime_start": "2026-01-01",
#       "value": "2919.01"
#     },
#     {
#       "date": "2017-12-25",
#       "realtime_end": "2026-01-01",
#       "realtime_start": "2026-01-01",
#       "value": "2835.99"
#     },
#     {
# ...

# %% [markdown]
# ## fred.releases

# %%
tool_name = "fred.releases"
await show_tool_schema(tool_name)
# Out:
# {
#   "properties": {
#     "limit": {
#       "anyOf": [
#         {
#           "type": "integer"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": 50,
#       "title": "Limit"
#     },
#     "order_by": {
#       "anyOf": [
#         {
#           "type": "string"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "title": "Order By"
#     }
#   },
#   "title": "list_releasesArguments",
#   "type": "object"
# }

# %%
args = {"series_id": "CBBCHUSD"}
result = await call_tool(tool_name, args)
releases = result.structuredContent['result'] # type: ignore
print_json_vertical(releases)
# Out:
# {
#   "count": 2935,
#   "limit": 100,
#   "observations": [
#     {
#       "date": "2017-12-20",
#       "realtime_end": "2026-01-01",
#       "realtime_start": "2026-01-01",
#       "value": "3746.84"
#     },
#     {
#       "date": "2017-12-21",
#       "realtime_end": "2026-01-01",
#       "realtime_start": "2026-01-01",
#       "value": "3162.53"
#     },
#     {
#       "date": "2017-12-22",
#       "realtime_end": "2026-01-01",
#       "realtime_start": "2026-01-01",
#       "value": "2719.99"
#     },
#     {
#       "date": "2017-12-23",
#       "realtime_end": "2026-01-01",
#       "realtime_start": "2026-01-01",
#       "value": "3160"
#     },
#     {
#       "date": "2017-12-24",
#       "realtime_end": "2026-01-01",
#       "realtime_start": "2026-01-01",
#       "value": "2919.01"
#     },
#     {
#       "date": "2017-12-25",
#       "realtime_end": "2026-01-01",
#       "realtime_start": "2026-01-01",
#       "value": "2835.99"
#     },
#     {
# ...

# %% [markdown]
# ## fred.release_series

# %%
tool_name = "fred.release_series"
await show_tool_schema(tool_name)
# Out:
# {
#   "properties": {
#     "limit": {
#       "anyOf": [
#         {
#           "type": "integer"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": 50,
#       "title": "Limit"
#     },
#     "release_id": {
#       "title": "Release Id",
#       "type": "integer"
#     }
#   },
#   "required": [
#     "release_id"
#   ],
#   "title": "list_release_seriesArguments",
#   "type": "object"
# }

# %%
args = {"series_id": "CBBCHUSD"}
result = await call_tool(tool_name, args)
# releases = result.structuredContent['result'] # type: ignore
# print_json_vertical(releases)
print(result)
# Out:
# meta=None content=[TextContent(type='text', text="Error executing tool fred.release_series: 1 validation error for list_release_seriesArguments\nrelease_id\n  Field required [type=missing, input_value={'series_id': 'CBBCHUSD'}, input_type=dict]\n    For further information visit https://errors.pydantic.dev/2.12/v/missing", annotations=None, meta=None)] structuredContent=None isError=True
