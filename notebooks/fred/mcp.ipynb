# %% [markdown]
# # FRED MCP

# %%
# %reload_ext autoreload
# %autoreload 2

from lib.utils import print_json_vertical
from utils import call_tool, list_mcp_tools, show_tool_schema

# %% [markdown]
# ## FRED Tools

# %%
await list_mcp_tools()
# Out:
# fred_category_children: List the child categories for a FRED category.
# fred_category_series: List the series contained within a FRED category.
# fred_series_info: Fetch metadata for a single FRED series.
# fred_series_observations: Return observations for a series (limit defaults to 100).
# fred_series_updates: Return recently updated FRED series.
# list_releases: List FRED releases — the publications data arrives in, such as the Employment Situation or the H.15 selected interest rates. Returns the release ids that fred_release_series takes.
# fred_release_series: List the series that belong to a FRED release.
# tiingo_series_info: Fetch metadata for a Tiingo ticker (ETF, mutual fund, or stock), including its available date range.
# tiingo_price_series: Return the end-of-day price series (OHLCV plus split/dividend-adjusted prices) for a Tiingo ticker. Provide start_date/end_date as YYYY-MM-DD for a range; omit for the latest day.
# bls_series_data: Fetch observations for one or more BLS series IDs (up to 50). Optionally restrict to a start_year/end_year range and enable catalog metadata, net/percent-change calculations, annual averages, and aspects.
# bls_series_latest: Return the single most-recent datapoint for a BLS series.
# bls_popular_series: List the 25 most popular BLS series IDs, optionally within a survey (e.g. 'LA').
# bls_all_surveys: List all BLS surveys (abbreviation and name).
# bls_survey_info: Fetch metadata for a single BLS survey by its abbreviation (e.g. 'TU').
# bis_dataflows: List the BIS statistical dataflows (datasets) available, such as total credit, policy rates, property prices, and banking statistics. Each entry gives the dataflow id used by the other BIS tools.
# bis_datastructure: Describe a BIS dataflow's structure: the ordered dimensions that make up a series key and the codelist that decodes each one. Set include_codes=true to also return every code/label pair — some codelists have 1000+ entries, so it is off by default.
# bis_series_data: Return observations for a BIS dataflow. 'key' is the dot-joined series key in dimension order (e.g. 'M.US' for monthly/United States); omit a position to wildcard it ('M..A'), use '+' for alternatives ('M.US+GB'), or 'all' for every series. Dimension values come back as codes — use bis_datastructure to decode them.
# cdc_discover: Search the CDC open-data (Socrata) catalog for datasets by keyword (e.g. 'life expectancy', 'drug overdose') and/or a 'category' from cdc_categories. Returns dataset ids + names for the other CDC tools.
# cdc_categories: List the CDC catalog's categories with dataset counts (e.g. 'National Center for Health Statistics', 'Behavioral Risk Factors') — the topic map for browsing. Pass a category to cdc_discover to list its datasets.
# cdc_tags: List the CDC catalog's tags with dataset counts (e.g. 'mortality', 'covid-19', 'prevalence') — finer-grained topics for search.
# cdc_dataset_columns: Describe a CDC dataset's columns (field name, type, label) from its id — use it to see which fields to filter/select in cdc_series_data. CDC datasets have inconsistent schemas, so check columns before querying.
# cdc_series_data: Return one CDC time series, selected by naming its facets. Facet names and tokens are the catalog's metadata keys, so a value read off a discovered series passes straight back in. Enums are the union across datasets — see cdc_dataset_facets for what one dataset actually defines. Several datasets stratify one demographic at a time, so age and race together is usually a series that was never published.
# cdc_dataset_facets: The facet tokens one CDC dataset actually defines — the per-dataset subset of cdc_series_data's union enums. Use it to check what is available before querying, or after an unsupported-token error.
# timeseries_source_list: List stored time series held in meida's database — sources with no live API, so their values are stored rather than fetched per request: cause-of-death rates, life expectancy, congressional polarization. Returns identity and coverage without observations, as {'series': [...]}. Optional 'source' narrows to one; call it without a source to see which sources exist.
# timeseries_source_data: Return one stored time series in full, with its observations, from meida's database. 'source' and 'native_id' both come from timeseries_source_list — call that first rather than guessing an id. Pass 'frequency' only if an id is ambiguous. Observation values are strings — cast as needed.
# timeseries_source_stale: List stored series that are due for an update — past their refresh horizon. These sources have no live API (CDC WONDER is throttled behind a bot filter; NVSR is a manual annual download), so refreshing is a deliberate act rather than an automatic re-fetch. Stale series are still served normally. Returns {'series': [...]}.
# series_catalog_search: Find which series exist, without fetching any data. Filters are exact, not fuzzy: narrow by dataset_id, concept, and facet values (e.g. {'state': 'TX', 'race': 'hispanic'}). Each result carries a 'retrieval' block naming the tool that fetches it — cdc_series_data for live Socrata series, timeseries_source_data for stored WONDER and NVSR ones — and a 'facets' block whose keys are exactly the arguments cdc_series_data takes. 'total' counts every match, so compare it against the entries returned to tell a complete result from a truncated one. Descriptions are shared across series that differ only by facet value, so filter on facets rather than trying to pick a series out by its prose.
# series_catalog_entry: Look up one catalog entry by its series_id — its coverage, units, facets, and the tool that fetches it.
# series_catalog_concepts: What the catalog measures, with a series count per concept and dataset — the coarse map to pick a concept before searching within it. A concept served by several datasets appears once per dataset, because those are different series with different coverage and vocabularies.

# %% [markdown]
# ## fred.category_children

# %%
tool_name = "fred_category_children"
await show_tool_schema(tool_name, raw=True)
# Out:
# {
#   "properties": {
#     "category_id": {
#       "title": "Category Id",
#       "type": "integer"
#     }
#   },
#   "required": [
#     "category_id"
#   ],
#   "title": "list_category_childrenArguments",
#   "type": "object"
# }
# {'properties': {'category_id': {'title': 'Category Id', 'type': 'integer'}},
#  'required': ['category_id'],
#  'title': 'list_category_childrenArguments',
#  'type': 'object'}

# %%
args = {"category_id": 0}
result = await call_tool(tool_name, args)
children = result.structuredContent['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32991,
#     "name": "Money, Banking, & Finance",
#     "parent_id": 0
#   },
#   {
#     "id": 10,
#     "name": "Population, Employment, & Labor Markets",
#     "parent_id": 0
#   },
#   {
#     "id": 32992,
#     "name": "National Accounts",
#     "parent_id": 0
#   },
#   {
#     "id": 1,
#     "name": "Production & Business Activity",
#     "parent_id": 0
#   },
#   {
#     "id": 32455,
#     "name": "Prices",
#     "parent_id": 0
#   },
#   {
#     "id": 32263,
#     "name": "International Data",
#     "parent_id": 0
#   },
#   {
#     "id": 3008,
#     "name": "U.S. Regional Data",
#     "parent_id": 0
#   },
#   {
#     "id": 33060,
#     "name": "Academic Data",
#     "parent_id": 0
#   }
# ]

# %% [markdown]
# ## fred.category_series

# %%
tool_name = "fred_category_series"
await show_tool_schema(tool_name, raw=True)
# Out:
# {
#   "properties": {
#     "category_id": {
#       "title": "Category Id",
#       "type": "integer"
#     },
#     "limit": {
#       "anyOf": [
#         {
#           "type": "integer"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "title": "Limit"
#     },
#     "order_by": {
#       "anyOf": [
#         {
#           "type": "string"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "title": "Order By"
#     }
#   },
#   "required": [
#     "category_id"
#   ],
#   "title": "list_category_seriesArguments",
#   "type": "object"
# }
# {'properties': {'category_id': {'title': 'Category Id', 'type': 'integer'},
#   'limit': {'anyOf': [{'type': 'integer'}, {'type': 'null'}],
#    'default': None,
#    'title': 'Limit'},
#   'order_by': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#    'default': None,
#    'title': 'Order By'}},
#  'required': ['category_id'],
#  'title': 'list_category_seriesArguments',
#  'type': 'object'}

# %%
args = {"category_id": 33913}
result = await call_tool(tool_name, args)
series = result.structuredContent # type: ignore
print_json_vertical(series)
# Out:
# {
#   "count": 5,
#   "series": [
#     {
#       "frequency": "Daily, 7-Day",
#       "frequency_short": "D",
#       "id": "CBBCHUSD",
#       "last_updated": "2026-09-12T19:06:28-05:00",
#       "notes": "All data is as of 5 PM PST. \n\nCopyright, 2018, Coinbase. \n\nReproduction of Coinbase data in any form is prohibited except with the prior written permission of Coinbase.",
#       "observation_end": "2026-09-12",
#       "observation_start": "2017-12-20",
#       "popularity": 19,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Coinbase Bitcoin Cash",
#       "units": "U.S. Dollars",
#       "units_short": "U.S. $"
#     },
#     {
#       "frequency": "Daily, 7-Day",
#       "frequency_short": "D",
#       "id": "CBBTCUSD",
#       "last_updated": "2026-09-12T19:06:29-05:00",
#       "notes": "All data is as of 5 PM PST. \n\nCopyright, 2018, Coinbase. \n\nReproduction of Coinbase data in any form is prohibited except with the prior written permission of Coinbase.",
#       "observation_end": "2026-09-12",
#       "observation_start": "2014-12-01",
#       "popularity": 72,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Coinbase Bitcoin",
#       "units": "U.S. Dollars",
#       "units_short": "U.S. $"
#     },
#     {
#       "frequency": "Daily, 7-Day",
#       "frequency_short": "D",
#       "id": "CBCCIND",
#       "last_updated": "2020-05-26T19:26:02-05:00",
#       "notes": "All data is as of 5 PM PST. \r\nGiven the volatility in the cryptocurrency markets, users may wish to view the large variation in values in a log scale. Changes in the data can be analyzed by turning on a log scale functionality that can be applied in the Format tab under Edit Graph button. \r\nFor more information to the Coinbase index, see https://am.coinbase.com/index\r\n\r\nCopyright, 2018, Coinbase.\r\n\r\nReproduction of Coinbase data in any form is prohibited except with the prior written permission of Coinbase.",
#       "observation_end": "2020-05-26",
#       "observation_start": "2015-01-01",
#       "popularity": 9,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Coinbase Index (DISCONTINUED)",
#       "units": "Index Jan 1, 2015=100",
#       "units_short": "Index Jan 1, 2015=100"
#     },
#     {
#       "frequency": "Daily, 7-Day",
#       "frequency_short": "D",
#       "id": "CBETHUSD",
#       "last_updated": "2026-09-12T19:06:29-05:00",
#       "notes": "All data is as of 5 PM PST. \n\nCopyright, 2018, Coinbase. \n\nReproduction of Coinbase data in any form is prohibited except with the prior written permission of Coinbase.",
#       "observation_end": "2026-09-12",
#       "observation_start": "2016-05-18",
#       "popularity": 43,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Coinbase Ethereum",
#       "units": "U.S. Dollars",
#       "units_short": "U.S. $"
#     },
#     {
#       "frequency": "Daily, 7-Day",
#       "frequency_short": "D",
#       "id": "CBLTCUSD",
#       "last_updated": "2026-09-12T19:06:28-05:00",
#       "notes": "All data is as of 5 PM PST. \n\nCopyright, 2018, Coinbase. \n\nReproduction of Coinbase data in any form is prohibited except with the prior written permission of Coinbase.",
#       "observation_end": "2026-09-12",
#       "observation_start": "2016-08-17",
#       "popularity": 16,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Coinbase Litecoin",
#       "units": "U.S. Dollars",
#       "units_short": "U.S. $"
#     }
#   ]
# }

# %% [markdown]
# ## fred.series_info

# %%
tool_name = "fred_series_info"
await show_tool_schema(tool_name, raw=True)
# Out:
# {
#   "properties": {
#     "series_id": {
#       "title": "Series Id",
#       "type": "string"
#     }
#   },
#   "required": [
#     "series_id"
#   ],
#   "title": "get_series_infoArguments",
#   "type": "object"
# }
# {'properties': {'series_id': {'title': 'Series Id', 'type': 'string'}},
#  'required': ['series_id'],
#  'title': 'get_series_infoArguments',
#  'type': 'object'}

# %%
args = {"series_id": "CBBCHUSD"}
result = await call_tool(tool_name, args)
info = result.structuredContent # type: ignore
print_json_vertical(info)
# Out:
# {
#   "count": null,
#   "series": [
#     {
#       "frequency": "Daily, 7-Day",
#       "frequency_short": "D",
#       "id": "CBBCHUSD",
#       "last_updated": "2026-09-12T19:06:28-05:00",
#       "notes": "All data is as of 5 PM PST. \n\nCopyright, 2018, Coinbase. \n\nReproduction of Coinbase data in any form is prohibited except with the prior written permission of Coinbase.",
#       "observation_end": "2026-09-12",
#       "observation_start": "2017-12-20",
#       "popularity": 19,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Coinbase Bitcoin Cash",
#       "units": "U.S. Dollars",
#       "units_short": "U.S. $"
#     }
#   ]
# }

# %% [markdown]
# ## fred.series_observations

# %%
tool_name = "fred_series_observations"
await show_tool_schema(tool_name, raw=True)
info = result.structuredContent # type: ignore
print_json_vertical(info)
# Out:
# {
#   "properties": {
#     "frequency": {
#       "anyOf": [
#         {
#           "type": "string"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "title": "Frequency"
#     },
#     "limit": {
#       "anyOf": [
#         {
#           "type": "integer"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": 100,
#       "title": "Limit"
#     },
#     "offset": {
#       "anyOf": [
#         {
#           "type": "integer"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": 0,
#       "title": "Offset"
#     },
#     "series_id": {
#       "title": "Series Id",
#       "type": "string"
#     },
#     "units": {
#       "anyOf": [
#         {
#           "type": "string"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "title": "Units"
#     }
#   },
#   "required": [
#     "series_id"
#   ],
#   "title": "get_series_observationsArguments",
#   "type": "object"
# }
# {
#   "count": null,
#   "series": [
#     {
#       "frequency": "Daily, 7-Day",
#       "frequency_short": "D",
#       "id": "CBBCHUSD",
#       "last_updated": "2026-09-12T19:06:28-05:00",
#       "notes": "All data is as of 5 PM PST. \n\nCopyright, 2018, Coinbase. \n\nReproduction of Coinbase data in any form is prohibited except with the prior written permission of Coinbase.",
#       "observation_end": "2026-09-12",
#       "observation_start": "2017-12-20",
#       "popularity": 19,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Coinbase Bitcoin Cash",
#       "units": "U.S. Dollars",
#       "units_short": "U.S. $"
#     }
#   ]
# }

# %%
args = {"series_id": "CBBCHUSD"}
result = await call_tool(tool_name, args)
seriess = result.structuredContent # type: ignore
print_json_vertical(seriess)
# Out:
# {
#   "count": 3189,
#   "observations": [
#     {
#       "date": "2017-12-20",
#       "value": "3746.84"
#     },
#     {
#       "date": "2017-12-21",
#       "value": "3162.53"
#     },
#     {
#       "date": "2017-12-22",
#       "value": "2719.99"
#     },
#     {
#       "date": "2017-12-23",
#       "value": "3160"
#     },
#     {
#       "date": "2017-12-24",
#       "value": "2919.01"
#     },
#     {
#       "date": "2017-12-25",
#       "value": "2835.99"
#     },
#     {
#       "date": "2017-12-26",
#       "value": "2928.04"
#     },
#     {
#       "date": "2017-12-27",
#       "value": "2719.69"
#     },
#     {
#       "date": "2017-12-28",
#       "value": "2493.19"
#     },
#     {
#       "date": "2017-12-29",
#       "value": "2658.51"
#     },
#     {
#       "date": "2017-12-30",
#       "value": "2261"
#     },
#     {
#       "date": "2017-12-31",
#       "value": "2366.9"
#     },
#     {
#       "date": "2018-01-01",
#       "value": "2326.86"
#     },
#     {
#       "date": "2018-01-02",
#       "value": "2558.58"
#     },
#     {
#       "date": "2018-01-03",
#       "value": "2548.65"
#     },
#     {
#       "date": "2018-01-04",
#       "value": "2362.74"
#     },
#     {
#       "date": "2018-01-05",
#       "value": "2398"
#     },
#     {
#       "date": "2018-01-06",
#       "value": "2524.72"
#     },
#     {
#       "date": "2018-01-07",
#       "value": "2523.1"
#     },
#     {
#       "date": "2018-01-08",
#       "value": "2409.29"
#     },
#     {
#       "date": "2018-01-09",
#       "value": "2375.99"
#     },
#     {
#       "date": "2018-01-10",
#       "value": "2859.97"
#     },
#     {
#       "date": "2018-01-11",
#       "value": "2433.8"
#     },
#     {
#       "date": "2018-01-12",
#       "value": "2599"
#     },
#     {
#       "date": "2018-01-13",
#       "value": "2654.95"
#     },
#     {
#       "date": "2018-01-14",
#       "value": "2544.87"
#     },
#     {
#       "date": "2018-01-15",
#       "value": "2400.06"
#     },
#     {
#       "date": "2018-01-16",
#       "value": "1890.01"
#     },
#     {
#       "date": "2018-01-17",
#       "value": "1755.98"
#     },
#     {
#       "date": "2018-01-18",
#       "value": "1730.67"
#     },
#     {
#       "date": "2018-01-19",
#       "value": "1758.69"
#     },
#     {
#       "date": "2018-01-20",
#       "value": "2030.22"
#     },
#     {
#       "date": "2018-01-21",
#       "value": "1770"
#     },
#     {
#       "date": "2018-01-22",
#       "value": "1609.34"
#     },
#     {
#       "date": "2018-01-23",
#       "value": "1615.75"
#     },
#     {
#       "date": "2018-01-24",
#       "value": "1644.5"
#     },
#     {
#       "date": "2018-01-25",
#       "value": "1628.39"
#     },
#     {
#       "date": "2018-01-26",
#       "value": "1592.14"
#     },
#     {
#       "date": "2018-01-27",
#       "value": "1613.41"
#     },
#     {
#       "date": "2018-01-28",
#       "value": "1719.99"
#     },
#     {
#       "date": "2018-01-29",
#       "value": "1636.38"
#     },
#     {
#       "date": "2018-01-30",
#       "value": "1446"
#     },
#     {
#       "date": "2018-01-31",
#       "value": "1472.74"
#     },
#     {
#       "date": "2018-02-01",
#       "value": "1254.86"
#     },
#     {
#       "date": "2018-02-02",
#       "value": "1181"
#     },
#     {
#       "date": "2018-02-03",
#       "value": "1269.71"
#     },
#     {
#       "date": "2018-02-04",
#       "value": "1156.16"
#     },
#     {
#       "date": "2018-02-05",
#       "value": "880"
#     },
#     {
#       "date": "2018-02-06",
#       "value": "968.01"
#     },
#     {
#       "date": "2018-02-07",
#       "value": "955"
#     },
#     {
#       "date": "2018-02-08",
#       "value": "1278"
#     },
#     {
#       "date": "2018-02-09",
#       "value": "1299.83"
#     },
#     {
#       "date": "2018-02-10",
#       "value": "1239.7"
#     },
#     {
#       "date": "2018-02-11",
#       "value": "1210"
#     },
#     {
#       "date": "2018-02-12",
#       "value": "1279.39"
#     },
#     {
#       "date": "2018-02-13",
#       "value": "1219.82"
#     },
#     {
#       "date": "2018-02-14",
#       "value": "1355"
#     },
#     {
#       "date": "2018-02-15",
#       "value": "1358.72"
#     },
#     {
#       "date": "2018-02-16",
#       "value": "1533"
#     },
#     {
#       "date": "2018-02-17",
#       "value": "1546.35"
#     },
#     {
#       "date": "2018-02-18",
#       "value": "1452.97"
#     },
#     {
#       "date": "2018-02-19",
#       "value": "1523.14"
#     },
#     {
#       "date": "2018-02-20",
#       "value": "1386.99"
#     },
#     {
#       "date": "2018-02-21",
#       "value": "1284.73"
#     },
#     {
#       "date": "2018-02-22",
#       "value": "1210"
#     },
#     {
#       "date": "2018-02-23",
#       "value": "1252.01"
#     },
#     {
#       "date": "2018-02-24",
#       "value": "1178"
#     },
#     {
#       "date": "2018-02-25",
#       "value": "1173.02"
#     },
#     {
#       "date": "2018-02-26",
#       "value": "1245.62"
#     },
#     {
#       "date": "2018-02-27",
#       "value": "1230.01"
#     },
#     {
#       "date": "2018-02-28",
#       "value": "1195.94"
#     },
#     {
#       "date": "2018-03-01",
#       "value": "1283.33"
#     },
#     {
#       "date": "2018-03-02",
#       "value": "1275.12"
#     },
#     {
#       "date": "2018-03-03",
#       "value": "1269.24"
#     },
#     {
#       "date": "2018-03-04",
#       "value": "1280.01"
#     },
#     {
#       "date": "2018-03-05",
#       "value": "1263"
#     },
#     {
#       "date": "2018-03-06",
#       "value": "1206.22"
#     },
#     {
#       "date": "2018-03-07",
#       "value": "1095.3"
#     },
#     {
#       "date": "2018-03-08",
#       "value": "1032"
#     },
#     {
#       "date": "2018-03-09",
#       "value": "1067.18"
#     },
#     {
#       "date": "2018-03-10",
#       "value": "1003.01"
#     },
#     {
#       "date": "2018-03-11",
#       "value": "1138.05"
#     },
#     {
#       "date": "2018-03-12",
#       "value": "1049.32"
#     },
#     {
#       "date": "2018-03-13",
#       "value": "1052.87"
#     },
#     {
#       "date": "2018-03-14",
#       "value": "947"
#     },
#     {
#       "date": "2018-03-15",
#       "value": "935.37"
#     },
#     {
#       "date": "2018-03-16",
#       "value": "970.51"
#     },
#     {
#       "date": "2018-03-17",
#       "value": "947.35"
#     },
#     {
#       "date": "2018-03-18",
#       "value": "931.99"
#     },
#     {
#       "date": "2018-03-19",
#       "value": "992.14"
#     },
#     {
#       "date": "2018-03-20",
#       "value": "1061.66"
#     },
#     {
#       "date": "2018-03-21",
#       "value": "1028.4"
#     },
#     {
#       "date": "2018-03-22",
#       "value": "1012.3"
#     },
#     {
#       "date": "2018-03-23",
#       "value": "1025"
#     },
#     {
#       "date": "2018-03-24",
#       "value": "971.51"
#     },
#     {
#       "date": "2018-03-25",
#       "value": "971.38"
#     },
#     {
#       "date": "2018-03-26",
#       "value": "914"
#     },
#     {
#       "date": "2018-03-27",
#       "value": "873.92"
#     },
#     {
#       "date": "2018-03-28",
#       "value": "859.08"
#     },
#     {
#       "date": "2018-03-29",
#       "value": "709.9"
#     }
#   ],
#   "series_id": "CBBCHUSD"
# }

# %% [markdown]
# ## fred.series_updates

# %%
tool_name = "fred_series_updates"
await show_tool_schema(tool_name, raw=True)
# Out:
# {
#   "properties": {
#     "limit": {
#       "anyOf": [
#         {
#           "type": "integer"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": 100,
#       "title": "Limit"
#     },
#     "offset": {
#       "anyOf": [
#         {
#           "type": "integer"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": 0,
#       "title": "Offset"
#     }
#   },
#   "title": "get_series_updatesArguments",
#   "type": "object"
# }
# {'properties': {'limit': {'anyOf': [{'type': 'integer'}, {'type': 'null'}],
#    'default': 100,
#    'title': 'Limit'},
#   'offset': {'anyOf': [{'type': 'integer'}, {'type': 'null'}],
#    'default': 0,
#    'title': 'Offset'}},
#  'title': 'get_series_updatesArguments',
#  'type': 'object'}

# %%
args = {"series_id": "CBBCHUSD"}
result = await call_tool(tool_name, args)
updates = result.structuredContent # type: ignore
print_json_vertical(updates)
# Out:
# {
#   "count": 179829,
#   "series": [
#     {
#       "frequency": "Daily, 7-Day",
#       "frequency_short": "D",
#       "id": "DFEDTARL",
#       "last_updated": "2026-09-13T07:00:32-05:00",
#       "notes": "This series represents lower limit of the federal funds target range established by the Federal Open Market Committee. The data updated each day is the data effective as of that day.",
#       "observation_end": "2026-09-13",
#       "observation_start": "2008-12-16",
#       "popularity": 66,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Federal Funds Target Range - Lower Limit",
#       "units": "Percent",
#       "units_short": "%"
#     },
#     {
#       "frequency": "Daily, 7-Day",
#       "frequency_short": "D",
#       "id": "DFEDTARU",
#       "last_updated": "2026-09-13T07:00:31-05:00",
#       "notes": "This series represents upper limit of the federal funds target range established by the Federal Open Market Committee. The data updated each day is the data effective as of that day.",
#       "observation_end": "2026-09-13",
#       "observation_start": "2008-12-16",
#       "popularity": 82,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Federal Funds Target Range - Upper Limit",
#       "units": "Percent",
#       "units_short": "%"
#     },
#     {
#       "frequency": "Daily, 7-Day",
#       "frequency_short": "D",
#       "id": "CBBTCUSD",
#       "last_updated": "2026-09-12T19:06:29-05:00",
#       "notes": "All data is as of 5 PM PST. \n\nCopyright, 2018, Coinbase. \n\nReproduction of Coinbase data in any form is prohibited except with the prior written permission of Coinbase.",
#       "observation_end": "2026-09-12",
#       "observation_start": "2014-12-01",
#       "popularity": 72,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Coinbase Bitcoin",
#       "units": "U.S. Dollars",
#       "units_short": "U.S. $"
#     },
#     {
#       "frequency": "Daily, 7-Day",
#       "frequency_short": "D",
#       "id": "CBETHUSD",
#       "last_updated": "2026-09-12T19:06:29-05:00",
#       "notes": "All data is as of 5 PM PST. \n\nCopyright, 2018, Coinbase. \n\nReproduction of Coinbase data in any form is prohibited except with the prior written permission of Coinbase.",
#       "observation_end": "2026-09-12",
#       "observation_start": "2016-05-18",
#       "popularity": 43,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Coinbase Ethereum",
#       "units": "U.S. Dollars",
#       "units_short": "U.S. $"
#     },
#     {
#       "frequency": "Daily, 7-Day",
#       "frequency_short": "D",
#       "id": "CBLTCUSD",
#       "last_updated": "2026-09-12T19:06:28-05:00",
#       "notes": "All data is as of 5 PM PST. \n\nCopyright, 2018, Coinbase. \n\nReproduction of Coinbase data in any form is prohibited except with the prior written permission of Coinbase.",
#       "observation_end": "2026-09-12",
#       "observation_start": "2016-08-17",
#       "popularity": 16,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Coinbase Litecoin",
#       "units": "U.S. Dollars",
#       "units_short": "U.S. $"
#     },
#     {
#       "frequency": "Daily, 7-Day",
#       "frequency_short": "D",
#       "id": "CBBCHUSD",
#       "last_updated": "2026-09-12T19:06:28-05:00",
#       "notes": "All data is as of 5 PM PST. \n\nCopyright, 2018, Coinbase. \n\nReproduction of Coinbase data in any form is prohibited except with the prior written permission of Coinbase.",
#       "observation_end": "2026-09-12",
#       "observation_start": "2017-12-20",
#       "popularity": 19,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Coinbase Bitcoin Cash",
#       "units": "U.S. Dollars",
#       "units_short": "U.S. $"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQSX502020PI",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: SX502020PI (https://indexes.nasdaq.com/Index/Overview/SX502020PI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2000-01-03",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Electronic and Electrical Equipment Price Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQSX30GI",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: SX30GI (https://indexes.nasdaq.com/Index/Overview/SX30GI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2000-01-03",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Financials Gross Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQOMXBBCAPGI",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: OMXBBCAPGI (https://indexes.nasdaq.com/Index/Overview/OMXBBCAPGI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2008-11-17",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Baltic Benchmark Cap Gross Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQSX5020GI",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: SX5020GI (https://indexes.nasdaq.com/Index/Overview/SX5020GI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2000-01-03",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Industrial Goods and Services Gross Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQSX4010PI",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: SX4010PI (https://indexes.nasdaq.com/Index/Overview/SX4010PI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2000-01-03",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Automobiles and Parts Price Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQSX60PI",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: SX60PI (https://indexes.nasdaq.com/Index/Overview/SX60PI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2002-12-30",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Energy Price Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQOMXSBPI",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: OMXSBPI (https://indexes.nasdaq.com/Index/Overview/OMXSBPI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2008-11-17",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Benchmark Price Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQXNDX10NC",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: XNDX10NC (https://indexes.nasdaq.com/Index/Overview/XNDX10NC)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2024-04-30",
#       "popularity": 4,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Nasdaq-100 Volatility Control 10% Net Cost Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQOMRXTBOND5",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: OMRXTBOND5 (https://indexes.nasdaq.com/Index/Overview/OMRXTBOND5)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2008-11-17",
#       "popularity": 2,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMRX Treasury Bond 5- y Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQXCQ",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: XCQ (https://indexes.nasdaq.com/Index/Overview/XCQ)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2009-04-17",
#       "popularity": 2,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Settle - NASDAQ Composite",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQSX451020GI",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: SX451020GI (https://indexes.nasdaq.com/Index/Overview/SX451020GI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2000-01-03",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Food Producers Gross Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQXNDXCHFMH",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: XNDXCHFMH (https://indexes.nasdaq.com/Index/Overview/XNDXCHFMH)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2017-07-10",
#       "popularity": 2,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "XNDXCHF Monthly Currency Hedged",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQSFW",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: SFW (https://indexes.nasdaq.com/Index/Overview/SFW)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2008-12-08",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Settle - Swiss Francs WCO",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQXNDXHKD",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: XNDXHKD (https://indexes.nasdaq.com/Index/Overview/XNDXHKD)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2015-12-14",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Nasdaq-100 Total Return Index Hong Kong Dollar",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQVMILMN",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: VMILMN (https://indexes.nasdaq.com/Index/Overview/VMILMN)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2022-09-19",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Nasdaq Victory International Value Momentum Net Total Return Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQQGDEEX",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: QGDEEX (https://indexes.nasdaq.com/Index/Overview/QGDEEX)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2025-04-16",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Nasdaq OMX Clean Edge Smart Grid Infrastructure Exclusions Total Return Euro Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQOMXB10",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: OMXB10 (https://indexes.nasdaq.com/Index/Overview/OMXB10)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2008-11-17",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX_Baltic_10",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQSX65GI",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: SX65GI (https://indexes.nasdaq.com/Index/Overview/SX65GI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2000-01-03",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Utilities Gross Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQXNDC",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: XNDC (https://indexes.nasdaq.com/Index/Overview/XNDC)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2021-01-21",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Close Settle - Nasdaq-100 Micro Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQSX402040GI",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: SX402040GI (https://indexes.nasdaq.com/Index/Overview/SX402040GI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2000-01-03",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Personal Goods Gross Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQXNBINNRJPY",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: XNBINNRJPY (https://indexes.nasdaq.com/Index/Overview/XNBINNRJPY)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2018-01-22",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "NASDAQ Biotechnology Net Total Return Japanese Yen",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQSX",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: SX (https://indexes.nasdaq.com/Index/Overview/SX)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2008-11-03",
#       "popularity": 2,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Settle - PHLX Semiconductor",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQSX502060PI",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: SX502060PI (https://indexes.nasdaq.com/Index/Overview/SX502060PI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2000-01-03",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Industrial Transportation Price Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQSX5010PI",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: SX5010PI (https://indexes.nasdaq.com/Index/Overview/SX5010PI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2000-01-03",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Construction and Materials Price Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQSX402010PI",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: SX402010PI (https://indexes.nasdaq.com/Index/Overview/SX402010PI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2008-11-17",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Consumer Services Price Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQSOX",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: SOX (https://indexes.nasdaq.com/Index/Overview/SOX)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2004-09-02",
#       "popularity": 53,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "PHLX Semiconductor",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQNSCOPJT",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: NSCOPJT (https://indexes.nasdaq.com/Index/Overview/NSCOPJT)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2023-01-16",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Nasdaq Sprott Junior Copper Miners Total Return Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQXXAU",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: XXAU (https://indexes.nasdaq.com/Index/Overview/XXAU)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2011-07-01",
#       "popularity": 5,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "PHLX Gold/Silver Sector Total Return",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQUTY",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: UTY (https://indexes.nasdaq.com/Index/Overview/UTY)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2004-09-02",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "PHLX Utility Sector",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQOMXNSCDKKPI",
#       "last_updated": "2026-09-11T22:44:35-05:00",
#       "notes": "For more information about this series, see: OMXNSCDKKPI (https://indexes.nasdaq.com/Index/Overview/OMXNSCDKKPI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2008-11-17",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Nordic Small Cap Danish Krone Price Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQVMULCT",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: VMULCT (https://indexes.nasdaq.com/Index/Overview/VMULCT)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2022-09-19",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Nasdaq Victory US Value Momentum Total Return Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQNQUSS50206010T",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: NQUSS50206010T (https://indexes.nasdaq.com/Index/Overview/NQUSS50206010T)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2011-06-07",
#       "popularity": 0,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Nasdaq US Small Cap Trucking Total Return Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQNQUSS4520",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: NQUSS4520 (https://indexes.nasdaq.com/Index/Overview/NQUSS4520)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2020-09-22",
#       "popularity": 0,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Nasdaq US Small Cap Personal Care, Drug and Grocery Stores Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQSX20PI",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: SX20PI (https://indexes.nasdaq.com/Index/Overview/SX20PI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2000-01-03",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Health Care Price Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQXDB",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: XDB (https://indexes.nasdaq.com/Index/Overview/XDB)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2008-12-08",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "PHLX British Pound",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQSX451020PI",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: SX451020PI (https://indexes.nasdaq.com/Index/Overview/SX451020PI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2000-01-03",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Food Producers Price Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQXNDXCADH",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: XNDXCADH (https://indexes.nasdaq.com/Index/Overview/XNDXCADH)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-10",
#       "observation_start": "2010-01-08",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "NASDAQ-100 Currency Hedged Canadaian Dollar Total Return",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQXNDXOS",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: XNDXOS (https://indexes.nasdaq.com/Index/Overview/XNDXOS)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2018-12-10",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "NASDAQ-100 Total Return Opening Settlement Value",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQOMXNORDICISKPI",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: OMXNORDICISKPI (https://indexes.nasdaq.com/Index/Overview/OMXNORDICISKPI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2008-11-17",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Nordic Icelandic Krona Price Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQSX404010PI",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: SX404010PI (https://indexes.nasdaq.com/Index/Overview/SX404010PI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2000-01-03",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Retailers Price Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQSX551030PI",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: SX551030PI (https://indexes.nasdaq.com/Index/Overview/SX551030PI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2000-01-03",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Precious Metals and Mining Price Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQNQUSS50206030T",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: NQUSS50206030T (https://indexes.nasdaq.com/Index/Overview/NQUSS50206030T)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2017-09-18",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Nasdaq US Small Cap Marine Transportation Total Return Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQOMXI15EUR",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: OMXI15EUR (https://indexes.nasdaq.com/Index/Overview/OMXI15EUR)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2023-07-11",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Iceland 15 Euro",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQNQVDIV",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: NQVDIV (https://indexes.nasdaq.com/Index/Overview/NQVDIV)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2017-03-31",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Nasdaq Victory Dividend Accelerator Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQNQZAN",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: NQZAN (https://indexes.nasdaq.com/Index/Overview/NQZAN)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2001-03-30",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "NASDAQ South Africa Net Total Return Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQSX55PI",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: SX55PI (https://indexes.nasdaq.com/Index/Overview/SX55PI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2000-01-03",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Basic Materials Price Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQNQUSS50204000",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: NQUSS50204000 (https://indexes.nasdaq.com/Index/Overview/NQUSS50204000)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2011-06-06",
#       "popularity": 0,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Nasdaq Small Cap Machinery: Industrial Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQOMXSBESGCAPGI",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: OMXSBESGCAPGI (https://indexes.nasdaq.com/Index/Overview/OMXSBESGCAPGI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2021-10-25",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Benchmark Environmental, Social and Governance Responsible Capped Gross Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQNQUSS50202010",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: NQUSS50202010 (https://indexes.nasdaq.com/Index/Overview/NQUSS50202010)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2020-09-22",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Nasdaq Small Cap Electrical Components Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQVMUSMN",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: VMUSMN (https://indexes.nasdaq.com/Index/Overview/VMUSMN)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2022-09-19",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Nasdaq Victory US Small Mid Cap Value Momentum Net Total Return Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQVMULC",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: VMULC (https://indexes.nasdaq.com/Index/Overview/VMULC)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2022-09-19",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Nasdaq Victory US Value Momentum Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQOMRXTBOND35",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: OMRXTBOND35 (https://indexes.nasdaq.com/Index/Overview/OMRXTBOND35)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2008-11-17",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMRX Treasury Bond 3-5 y Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQOMXNORDICSEKPI",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: OMXNORDICSEKPI (https://indexes.nasdaq.com/Index/Overview/OMXNORDICSEKPI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2008-11-17",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Nordic Swedish Krona Price Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQXNDXS2",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: XNDXS2 (https://indexes.nasdaq.com/Index/Overview/XNDXS2)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2016-04-04",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "NASDAQ-100 2x Short Total Return Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQRCMP",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: RCMP (https://indexes.nasdaq.com/Index/Overview/RCMP)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2006-07-05",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "NASDAQ Capital Market Composite",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQOMXNSCEURGI",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: OMXNSCEURGI (https://indexes.nasdaq.com/Index/Overview/OMXNSCEURGI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2008-11-17",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Nordic Small Cap Euro Gross Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQOMXI5YNI",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: OMXI5YNI (https://indexes.nasdaq.com/Index/Overview/OMXI5YNI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2022-03-14",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMXI 5-year non-indexed 5 years",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQNQZA45LM",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: NQZA45LM (https://indexes.nasdaq.com/Index/Overview/NQZA45LM)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2021-03-22",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Nasdaq South Africa Consumer Staples Large Mid Cap Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQOMXCMCPI",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: OMXCMCPI (https://indexes.nasdaq.com/Index/Overview/OMXCMCPI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2008-11-17",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Copenhagen Mid Cap Price Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQNQUSS402040N",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: NQUSS402040N (https://indexes.nasdaq.com/Index/Overview/NQUSS402040N)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2012-12-03",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Nasdaq US Small Cap Personal Goods Net Total Return Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQNYDTBNGBP",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: NYDTBNGBP (https://indexes.nasdaq.com/Index/Overview/NYDTBNGBP)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2023-10-03",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Nasdaq Global Disruptive Technology Benchmark Net Total Return Great British Pound Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQNQUSS40204025T",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: NQUSS40204025T (https://indexes.nasdaq.com/Index/Overview/NQUSS40204025T)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2011-06-07",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Nasdaq US Small Cap Footwear Total Return Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQNQUSS601020",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: NQUSS601020 (https://indexes.nasdaq.com/Index/Overview/NQUSS601020)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2011-05-31",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Nasdaq US Small Cap Alternative Energy Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQNQXAUEAUDTMH",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: NQXAUEAUDTMH (https://indexes.nasdaq.com/Index/Overview/NQXAUEAUDTMH)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2016-06-10",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "NQXAUEAUDT Monthly Currency Hedged",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQXNDXS1NNR",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: XNDXS1NNR (https://indexes.nasdaq.com/Index/Overview/XNDXS1NNR)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2016-04-04",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "NASDAQ-100 1x Short Net Total Return Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQSX402020GI",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: SX402020GI (https://indexes.nasdaq.com/Index/Overview/SX402020GI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2000-01-03",
#       "popularity": 2,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Household Goods and Home Construction Gross Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQNQZA40",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: NQZA40 (https://indexes.nasdaq.com/Index/Overview/NQZA40)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2020-09-21",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Nasdaq South Africa Consumer Discretionary Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQNQUSSVN",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: NQUSSVN (https://indexes.nasdaq.com/Index/Overview/NQUSSVN)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2001-03-30",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Nasdaq US Small Cap Value Net Total Return Index ",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQOMXSBCAPPI",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: OMXSBCAPPI (https://indexes.nasdaq.com/Index/Overview/OMXSBCAPPI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2008-11-17",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Benchmark Cap Price Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQXAG",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: XAG (https://indexes.nasdaq.com/Index/Overview/XAG)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2008-11-03",
#       "popularity": 3,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Settle - PHLX Gold/Silver Sector",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQOMXNORDICEURPI",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: OMXNORDICEURPI (https://indexes.nasdaq.com/Index/Overview/OMXNORDICEURPI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2008-11-17",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Nordic Euro Price Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQNQXAUEN",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: NQXAUEN (https://indexes.nasdaq.com/Index/Overview/NQXAUEN)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2016-03-21",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Nasdaq Global Excluding Australia Energy Companies Net Total Return",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQOMXAFGX",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: OMXAFGX (https://indexes.nasdaq.com/Index/Overview/OMXAFGX)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2009-10-13",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Affarsvarldens Generalindex",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQOMXSBESGCAPNI",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: OMXSBESGCAPNI (https://indexes.nasdaq.com/Index/Overview/OMXSBESGCAPNI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2021-10-25",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Benchmark Environmental, Social and Governance Responsible Capped Net Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQNQZA30N",
#       "last_updated": "2026-09-11T22:44:34-05:00",
#       "notes": "For more information about this series, see: NQZA30N (https://indexes.nasdaq.com/Index/Overview/NQZA30N)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2001-03-30",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "NASDAQ South Africa Financials Net Total Return Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQSX402030PI",
#       "last_updated": "2026-09-11T22:44:33-05:00",
#       "notes": "For more information about this series, see: SX402030PI (https://indexes.nasdaq.com/Index/Overview/SX402030PI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2000-01-03",
#       "popularity": 0,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Leisure Goods Price Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQSX3010PI",
#       "last_updated": "2026-09-11T22:44:33-05:00",
#       "notes": "For more information about this series, see: SX3010PI (https://indexes.nasdaq.com/Index/Overview/SX3010PI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2000-01-03",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Banks Price Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQXNBIJPY",
#       "last_updated": "2026-09-11T22:44:33-05:00",
#       "notes": "For more information about this series, see: XNBIJPY (https://indexes.nasdaq.com/Index/Overview/XNBIJPY)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2018-01-22",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "NASDAQ Biotechnology Total Return Japanese Yen",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQSX302020PI",
#       "last_updated": "2026-09-11T22:44:33-05:00",
#       "notes": "For more information about this series, see: SX302020PI (https://indexes.nasdaq.com/Index/Overview/SX302020PI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2000-01-03",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Investment Banking and Brokerage Services  Price Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQXNDXNNRJPYMH",
#       "last_updated": "2026-09-11T22:44:33-05:00",
#       "notes": "For more information about this series, see: XNDXNNRJPYMH (https://indexes.nasdaq.com/Index/Overview/XNDXNNRJPYMH)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2020-07-31",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "NASDAQ -100 Currency Hedged Japanese Yen Net Total Return Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQXOSX",
#       "last_updated": "2026-09-11T22:44:33-05:00",
#       "notes": "For more information about this series, see: XOSX (https://indexes.nasdaq.com/Index/Overview/XOSX)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2011-07-01",
#       "popularity": 4,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "PHLX Oil Service Sector Total Return",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQSX502050GI",
#       "last_updated": "2026-09-11T22:44:33-05:00",
#       "notes": "For more information about this series, see: SX502050GI (https://indexes.nasdaq.com/Index/Overview/SX502050GI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2000-01-03",
#       "popularity": 2,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Industrial Support Services Gross Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQQFNX",
#       "last_updated": "2026-09-11T22:44:33-05:00",
#       "notes": "For more information about this series, see: QFNX (https://indexes.nasdaq.com/Index/Overview/QFNX)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2010-04-13",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Nasdaq Consumer Technical Association Smartphone Total Return Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQNQUSS55102015N",
#       "last_updated": "2026-09-11T22:44:33-05:00",
#       "notes": "For more information about this series, see: NQUSS55102015N (https://indexes.nasdaq.com/Index/Overview/NQUSS55102015N)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2020-09-22",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Nasdaq Small Cap Metal Fabricating Net Total Return Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQSX601010PI",
#       "last_updated": "2026-09-11T22:44:33-05:00",
#       "notes": "For more information about this series, see: SX601010PI (https://indexes.nasdaq.com/Index/Overview/SX601010PI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2002-12-30",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Oil, Gas and Coal Price Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQOMXILCPI",
#       "last_updated": "2026-09-11T22:44:33-05:00",
#       "notes": "For more information about this series, see: OMXILCPI (https://indexes.nasdaq.com/Index/Overview/OMXILCPI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2017-01-10",
#       "popularity": 0,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Iceland Large Cap Price Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQOMXCPI",
#       "last_updated": "2026-09-11T22:44:33-05:00",
#       "notes": "For more information about this series, see: OMXCPI (https://indexes.nasdaq.com/Index/Overview/OMXCPI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2008-11-17",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Copenhagen Price Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQXHGX",
#       "last_updated": "2026-09-11T22:44:33-05:00",
#       "notes": "For more information about this series, see: XHGX (https://indexes.nasdaq.com/Index/Overview/XHGX)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2011-07-01",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "PHLX Housing Sector Total Return",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQNSCOPPN",
#       "last_updated": "2026-09-11T22:44:33-05:00",
#       "notes": "For more information about this series, see: NSCOPPN (https://indexes.nasdaq.com/Index/Overview/NSCOPPN)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2023-12-18",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Nasdaq Sprott Copper Miners Net Total Return Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQSX404010GI",
#       "last_updated": "2026-09-11T22:44:33-05:00",
#       "notes": "For more information about this series, see: SX404010GI (https://indexes.nasdaq.com/Index/Overview/SX404010GI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2000-01-03",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Retailers Gross Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQNQUSS55102015T",
#       "last_updated": "2026-09-11T22:44:33-05:00",
#       "notes": "For more information about this series, see: NQUSS55102015T (https://indexes.nasdaq.com/Index/Overview/NQUSS55102015T)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2020-09-22",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Nasdaq Small Cap Metal Fabricating Total Return Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQSX551010PI",
#       "last_updated": "2026-09-11T22:44:33-05:00",
#       "notes": "For more information about this series, see: SX551010PI (https://indexes.nasdaq.com/Index/Overview/SX551010PI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2000-01-03",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Industrial Materials Price Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQXNDX7NC",
#       "last_updated": "2026-09-11T22:44:33-05:00",
#       "notes": "For more information about this series, see: XNDX7NC (https://indexes.nasdaq.com/Index/Overview/XNDX7NC)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2024-04-30",
#       "popularity": 3,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "Nasdaq-100 Volatility Control 7% Net Cost Index",
#       "units": "Index",
#       "units_short": "Index"
#     },
#     {
#       "frequency": "Daily",
#       "frequency_short": "D",
#       "id": "NASDAQSX502010PI",
#       "last_updated": "2026-09-11T22:44:33-05:00",
#       "notes": "For more information about this series, see: SX502010PI (https://indexes.nasdaq.com/Index/Overview/SX502010PI)\nCopyright \u00a9 2025, NASDAQ, Inc.",
#       "observation_end": "2026-09-11",
#       "observation_start": "2000-01-03",
#       "popularity": 1,
#       "seasonal_adjustment": "Not Seasonally Adjusted",
#       "seasonal_adjustment_short": "NSA",
#       "title": "OMX Stockholm Aerospace and Defense Price Index",
#       "units": "Index",
#       "units_short": "Index"
#     }
#   ]
# }

# %% [markdown]
# ## fred.releases

# %%
tool_name = "list_releases"
await show_tool_schema(tool_name, raw=True)
# Out:
# {
#   "properties": {
#     "limit": {
#       "anyOf": [
#         {
#           "type": "integer"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": 100,
#       "title": "Limit"
#     },
#     "order_by": {
#       "anyOf": [
#         {
#           "type": "string"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "title": "Order By"
#     }
#   },
#   "title": "list_releasesArguments",
#   "type": "object"
# }
# {'properties': {'limit': {'anyOf': [{'type': 'integer'}, {'type': 'null'}],
#    'default': 100,
#    'title': 'Limit'},
#   'order_by': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#    'default': None,
#    'title': 'Order By'}},
#  'title': 'list_releasesArguments',
#  'type': 'object'}

# %%
args = {"series_id": "CBBCHUSD"}
result = await call_tool(tool_name, args)
releases = result.structuredContent # type: ignore
print_json_vertical(releases)
# Out:
# {
#   "count": 332,
#   "releases": [
#     {
#       "id": 1,
#       "link": "https://www.fedsmallbusiness.org/about",
#       "name": "Small Business Credit Survey",
#       "press_release": true
#     },
#     {
#       "id": 2,
#       "link": "https://www.kansascityfed.org/data-and-trends/risk-on-risk-off-index/",
#       "name": "Risk-On Risk-Off Index",
#       "press_release": true
#     },
#     {
#       "id": 3,
#       "link": "https://home.treasury.gov/data/treasury-international-capital-tic-system",
#       "name": "Treasury International Capital: Continuous Securities Long Term (CSLT)",
#       "press_release": false
#     },
#     {
#       "id": 4,
#       "link": "https://www.kansascityfed.org/data-and-trends/kansas-city-fed-policy-rate-skew/",
#       "name": "Kansas City Fed Policy Rate Skew",
#       "press_release": true
#     },
#     {
#       "id": 5,
#       "link": "https://www.federalreserve.gov/consumerscommunities/shed.htm",
#       "name": "Survey of Household Economics and Decisionmaking (SHED)",
#       "press_release": false
#     },
#     {
#       "id": 6,
#       "link": "https://www.genaiadoptiontracker.com",
#       "name": "Real-Time Population Survey: Generative Artificial Intelligence Adoption Tracker",
#       "press_release": true
#     },
#     {
#       "id": 7,
#       "link": "https://recessionrisk.com/",
#       "name": "RecessionRisk.com",
#       "press_release": false
#     },
#     {
#       "id": 9,
#       "link": "http://www.census.gov/retail/",
#       "name": "Advance Monthly Sales for Retail and Food Services",
#       "press_release": true
#     },
#     {
#       "id": 10,
#       "link": "http://www.bls.gov/cpi/",
#       "name": "Consumer Price Index",
#       "press_release": true
#     },
#     {
#       "id": 11,
#       "link": "http://www.bls.gov/ncs/ect",
#       "name": "Employment Cost Index",
#       "press_release": true
#     },
#     {
#       "id": 13,
#       "link": "http://www.federalreserve.gov/releases/g17/",
#       "name": "G.17 Industrial Production and Capacity Utilization",
#       "press_release": true
#     },
#     {
#       "id": 14,
#       "link": "https://www.federalreserve.gov/releases/g19/",
#       "name": "G.19 Consumer Credit",
#       "press_release": true
#     },
#     {
#       "id": 15,
#       "link": "http://www.federalreserve.gov/releases/g5/",
#       "name": "G.5 Foreign Exchange Rates",
#       "press_release": true
#     },
#     {
#       "id": 17,
#       "link": "http://www.federalreserve.gov/releases/h10/",
#       "name": "H.10 Foreign Exchange Rates",
#       "press_release": true
#     },
#     {
#       "id": 18,
#       "link": "http://www.federalreserve.gov/releases/h15/",
#       "name": "H.15 Selected Interest Rates",
#       "press_release": true
#     },
#     {
#       "id": 19,
#       "link": "http://www.federalreserve.gov/releases/h3/",
#       "name": "H.3 Aggregate Reserves of Depository Institutions and the Monetary Base",
#       "press_release": true
#     },
#     {
#       "id": 20,
#       "link": "http://www.federalreserve.gov/releases/h41/",
#       "name": "H.4.1 Factors Affecting Reserve Balances",
#       "press_release": true
#     },
#     {
#       "id": 21,
#       "link": "http://www.federalreserve.gov/releases/h6/",
#       "name": "H.6 Money Stock Measures",
#       "press_release": true
#     },
#     {
#       "id": 22,
#       "link": "http://www.federalreserve.gov/releases/h8/",
#       "name": "H.8 Assets and Liabilities of Commercial Banks in the United States",
#       "press_release": true
#     },
#     {
#       "id": 25,
#       "link": "http://www.census.gov/mtis/www/mtis.html",
#       "name": "Manufacturing and Trade Inventories and Sales",
#       "press_release": true
#     },
#     {
#       "id": 27,
#       "link": "http://www.census.gov/construction/nrc/",
#       "name": "New Residential Construction",
#       "press_release": true
#     },
#     {
#       "id": 46,
#       "link": "http://www.bls.gov/ppi/",
#       "name": "Producer Price Index",
#       "press_release": true
#     },
#     {
#       "id": 47,
#       "link": "http://www.bls.gov/lpc/",
#       "name": "Productivity and Costs",
#       "press_release": true
#     },
#     {
#       "id": 49,
#       "link": "https://www.bea.gov/data/intl-trade-investment/international-transactions",
#       "name": "U.S. International Transactions",
#       "press_release": true
#     },
#     {
#       "id": 50,
#       "link": "http://www.bls.gov/ces/",
#       "name": "Employment Situation",
#       "press_release": true
#     },
#     {
#       "id": 51,
#       "link": "https://www.census.gov/foreign-trade/Press-Release/current_press_release/index.html",
#       "name": "U.S. International Trade in Goods and Services",
#       "press_release": true
#     },
#     {
#       "id": 52,
#       "link": "http://www.federalreserve.gov/releases/z1/",
#       "name": "Z.1 Financial Accounts of the United States",
#       "press_release": true
#     },
#     {
#       "id": 53,
#       "link": "https://www.bea.gov/data/gdp/gross-domestic-product",
#       "name": "Gross Domestic Product",
#       "press_release": true
#     },
#     {
#       "id": 54,
#       "link": "https://www.bea.gov/data/income-saving/personal-income",
#       "name": "Personal Income and Outlays",
#       "press_release": true
#     },
#     {
#       "id": 55,
#       "link": "https://cdr.ffiec.gov/public/",
#       "name": "Reports of Condition and Income for All Insured U.S. Commercial Banks",
#       "press_release": true
#     },
#     {
#       "id": 59,
#       "link": "http://www.census.gov/popest/",
#       "name": "National Population Estimates",
#       "press_release": false
#     },
#     {
#       "id": 61,
#       "link": "http://research.stlouisfed.org/publications/mt/",
#       "name": "Money Zero Maturity (MZM)",
#       "press_release": false
#     },
#     {
#       "id": 62,
#       "link": "https://research.stlouisfed.org/msi/",
#       "name": "Monetary Services Index (MSI)",
#       "press_release": false
#     },
#     {
#       "id": 63,
#       "link": "http://research.stlouisfed.org/publications/mt/",
#       "name": "M2 Related Series",
#       "press_release": false
#     },
#     {
#       "id": 64,
#       "link": null,
#       "name": "Long-Term U.S. Treasury Securities - Market Yield",
#       "press_release": false
#     },
#     {
#       "id": 70,
#       "link": null,
#       "name": "Monthly Treasury Inflation-Indexed Securities",
#       "press_release": false
#     },
#     {
#       "id": 71,
#       "link": null,
#       "name": "Weekly Treasury Inflation-Indexed Securities",
#       "press_release": false
#     },
#     {
#       "id": 72,
#       "link": null,
#       "name": "Daily Treasury Inflation-Indexed Securities",
#       "press_release": false
#     },
#     {
#       "id": 78,
#       "link": "http://research.stlouisfed.org/publications/mt/",
#       "name": "St. Louis Monthly Reserves and Monetary Base",
#       "press_release": false
#     },
#     {
#       "id": 79,
#       "link": "http://research.stlouisfed.org/publications/usfd/",
#       "name": "St. Louis Bi-Weekly Reserves and Monetary Base",
#       "press_release": false
#     },
#     {
#       "id": 80,
#       "link": "http://www.fiscal.treasury.gov/fsreports/rpt/treasBulletin/treasBulletin_home.htm",
#       "name": "Treasury Bulletin",
#       "press_release": true
#     },
#     {
#       "id": 81,
#       "link": "https://www.whitehouse.gov/omb/historical-tables/",
#       "name": "Fiscal Year Budget Data",
#       "press_release": false
#     },
#     {
#       "id": 82,
#       "link": "https://www.gpo.gov/fdsys/browse/collection.action?collectionCode=ERP",
#       "name": "Economic Report of the President",
#       "press_release": true
#     },
#     {
#       "id": 86,
#       "link": "http://www.federalreserve.gov/releases/cp/",
#       "name": "Commercial Paper",
#       "press_release": true
#     },
#     {
#       "id": 87,
#       "link": null,
#       "name": "Transitional Euro Country Exchange Rates",
#       "press_release": false
#     },
#     {
#       "id": 89,
#       "link": "https://www.federalreserve.gov/releases/DSR/",
#       "name": "Household Debt Service Ratios",
#       "press_release": true
#     },
#     {
#       "id": 91,
#       "link": "http://www.sca.isr.umich.edu/",
#       "name": "Surveys of Consumers",
#       "press_release": true
#     },
#     {
#       "id": 92,
#       "link": null,
#       "name": "Selected Real Retail Sales Series",
#       "press_release": false
#     },
#     {
#       "id": 93,
#       "link": "https://www.bea.gov/data/gdp/gross-domestic-product#collapse86",
#       "name": "Supplemental Estimates, Motor Vehicles",
#       "press_release": true
#     },
#     {
#       "id": 94,
#       "link": null,
#       "name": "Survey of Secondary Market Prices and Yields, and Interest Rates for Home Loans",
#       "press_release": true
#     },
#     {
#       "id": 95,
#       "link": "http://www.census.gov/indicator/www/m3/",
#       "name": "Manufacturer's Shipments, Inventories, and Orders (M3) Survey",
#       "press_release": true
#     },
#     {
#       "id": 97,
#       "link": "http://www.census.gov/construction/nrs/",
#       "name": "New Residential Sales",
#       "press_release": true
#     },
#     {
#       "id": 99,
#       "link": "http://www.cbo.gov/topics/budget/budget-and-economic-outlook",
#       "name": "Budget and Economic Outlook",
#       "press_release": true
#     },
#     {
#       "id": 100,
#       "link": "https://www.frbdiscountwindow.org/Home/Pages/Discount-Rates/Historical-Discount-Rates",
#       "name": "Seasonal Credit Rate",
#       "press_release": false
#     },
#     {
#       "id": 101,
#       "link": "http://www.federalreserve.gov/fomc/",
#       "name": "FOMC Press Release",
#       "press_release": true
#     },
#     {
#       "id": 102,
#       "link": "http://online.wsj.com/public/us",
#       "name": "Wall Street Journal",
#       "press_release": true
#     },
#     {
#       "id": 103,
#       "link": "http://www.federalreserve.gov/monetarypolicy/discountrate.htm",
#       "name": "Discount Rate Meeting Minutes",
#       "press_release": true
#     },
#     {
#       "id": 104,
#       "link": "https://www.federalreserve.gov/publications/bulletin.htm",
#       "name": "Federal Reserve Bulletin",
#       "press_release": true
#     },
#     {
#       "id": 105,
#       "link": "http://research.stlouisfed.org/publications/usfd/",
#       "name": "St. Louis Weekly Reserves and Monetary Base",
#       "press_release": false
#     },
#     {
#       "id": 106,
#       "link": null,
#       "name": "M2 Own Rate",
#       "press_release": false
#     },
#     {
#       "id": 107,
#       "link": "https://www.bls.gov/productivity/home.htm",
#       "name": "Total Factor Productivity for Major Industries",
#       "press_release": true
#     },
#     {
#       "id": 109,
#       "link": "https://www.philadelphiafed.org/surveys-and-data/regional-economic-analysis/state-coincident-indexes",
#       "name": "State Coincident Indexes",
#       "press_release": true
#     },
#     {
#       "id": 110,
#       "link": "https://www.bea.gov/data/income-saving/personal-income-by-state",
#       "name": "Personal Income by State",
#       "press_release": true
#     },
#     {
#       "id": 111,
#       "link": "http://www.census.gov/popest/",
#       "name": "Annual Estimates of the Population of Metropolitan and Micropolitan Statistical Areas",
#       "press_release": false
#     },
#     {
#       "id": 112,
#       "link": "http://www.bls.gov/sae",
#       "name": "State Employment and Unemployment",
#       "press_release": true
#     },
#     {
#       "id": 113,
#       "link": "http://www.bls.gov/sae/",
#       "name": "Metropolitan Area Employment and Unemployment",
#       "press_release": true
#     },
#     {
#       "id": 116,
#       "link": "http://www.bls.gov/lau/home.htm",
#       "name": "Unemployment in States and Local Areas (all other areas)",
#       "press_release": false
#     },
#     {
#       "id": 118,
#       "link": "http://www.census.gov/popest/",
#       "name": "Annual Estimates of the Population for the U.S. and States, and for Puerto Rico",
#       "press_release": false
#     },
#     {
#       "id": 119,
#       "link": "http://www.census.gov/popest/",
#       "name": "Annual Estimates of the Population for Counties",
#       "press_release": false
#     },
#     {
#       "id": 121,
#       "link": "http://www.federalreserve.gov/releases/h6/hist/",
#       "name": "H.6 Historical Data",
#       "press_release": false
#     },
#     {
#       "id": 122,
#       "link": null,
#       "name": "H.4.1 Factors Affecting Reserve Balances (data not included in press release)",
#       "press_release": false
#     },
#     {
#       "id": 131,
#       "link": "http://federalreserve.gov/releases/g13/",
#       "name": "G.13 Selected Interest Rates",
#       "press_release": true
#     },
#     {
#       "id": 138,
#       "link": null,
#       "name": "BEA Regions Employment and Unemployment",
#       "press_release": false
#     },
#     {
#       "id": 140,
#       "link": "https://www.bea.gov/data/gdp/gdp-state",
#       "name": "Gross Domestic Product by State",
#       "press_release": true
#     },
#     {
#       "id": 143,
#       "link": "https://www.census.gov/programs-surveys/stc.html",
#       "name": "Annual Survey of State Government Tax Collections",
#       "press_release": false
#     },
#     {
#       "id": 144,
#       "link": "http://www.census.gov/housing/hvs/",
#       "name": "Residential Vacancies and Homeownership Annual Statistics",
#       "press_release": false
#     },
#     {
#       "id": 148,
#       "link": "https://www.census.gov/construction/bps/",
#       "name": "Housing Units Authorized By Building Permits",
#       "press_release": false
#     },
#     {
#       "id": 152,
#       "link": "https://www.census.gov/data/tables/time-series/demo/health-insurance/historical-series/hib.html",
#       "name": "Health Insurance Coverage",
#       "press_release": false
#     },
#     {
#       "id": 153,
#       "link": "http://www.census.gov/data/tables/time-series/demo/health-insurance/historical-series/hib.html",
#       "name": "BEA Regions Health Insurance Coverage",
#       "press_release": false
#     },
#     {
#       "id": 165,
#       "link": null,
#       "name": "Australian Foreign Exchange Transactions",
#       "press_release": false
#     },
#     {
#       "id": 166,
#       "link": null,
#       "name": "German Foreign Exchange Intervention",
#       "press_release": false
#     },
#     {
#       "id": 167,
#       "link": null,
#       "name": "Italian Foreign Exchange Intervention",
#       "press_release": false
#     },
#     {
#       "id": 168,
#       "link": null,
#       "name": "Swiss Foreign Exchange Intervention",
#       "press_release": false
#     },
#     {
#       "id": 169,
#       "link": null,
#       "name": "Turkish Foreign Exchange Intervention",
#       "press_release": false
#     },
#     {
#       "id": 170,
#       "link": null,
#       "name": "U.S. Foreign Exchange Intervention",
#       "press_release": false
#     },
#     {
#       "id": 171,
#       "link": "http://www.fhfa.gov/DataTools/Downloads/Pages/House-Price-Index.aspx",
#       "name": "House Price Index",
#       "press_release": false
#     },
#     {
#       "id": 172,
#       "link": "http://www.mof.go.jp/english/international_policy/reference/feio/",
#       "name": "Japan Foreign Exchange Intervention",
#       "press_release": false
#     },
#     {
#       "id": 173,
#       "link": "https://www.census.gov/construction/bps/",
#       "name": "BEA Regions Housing Units Authorized By Building Permits",
#       "press_release": false
#     },
#     {
#       "id": 175,
#       "link": "https://www.bea.gov/data/income-saving/personal-income-by-county",
#       "name": "Personal Income by County",
#       "press_release": true
#     },
#     {
#       "id": 178,
#       "link": null,
#       "name": "Mexican Foreign Exchange Intervention",
#       "press_release": false
#     },
#     {
#       "id": 179,
#       "link": "http://www.census.gov/mrts/www/ecomm.html",
#       "name": "Quarterly Retail E-Commerce Sales",
#       "press_release": true
#     },
#     {
#       "id": 180,
#       "link": "http://www.dol.gov/ui/data.pdf",
#       "name": "Unemployment Insurance Weekly Claims Report",
#       "press_release": true
#     },
#     {
#       "id": 183,
#       "link": "http://www.eia.gov/petroleum/gasdiesel/",
#       "name": "Gasoline and Diesel Fuel Update",
#       "press_release": false
#     },
#     {
#       "id": 185,
#       "link": "http://www.federalreserve.gov/monetarypolicy/reqresbalances.htm",
#       "name": "Interest Rate on Reserve Balances",
#       "press_release": false
#     },
#     {
#       "id": 186,
#       "link": "http://www.federalreserve.gov/releases/g5a/",
#       "name": "G.5A Foreign Exchange Rates",
#       "press_release": true
#     },
#     {
#       "id": 187,
#       "link": null,
#       "name": "St. Louis Fed Financial Stress Index",
#       "press_release": false
#     },
#     {
#       "id": 188,
#       "link": "http://www.bls.gov/mxp/",
#       "name": "U.S. Import and Export Price Indexes",
#       "press_release": true
#     },
#     {
#       "id": 189,
#       "link": "https://www.spglobal.com/spdji/en/indices/equity/sp-500/#overview",
#       "name": "Standard & Poors",
#       "press_release": false
#     },
#     {
#       "id": 190,
#       "link": "http://www.freddiemac.com/pmms/",
#       "name": "Primary Mortgage Market Survey",
#       "press_release": true
#     },
#     {
#       "id": 191,
#       "link": "http://www.federalreserve.gov/boarddocs/SnLoanSurvey/",
#       "name": "Senior Loan Officer Opinion Survey on Bank Lending Practices",
#       "press_release": true
#     }
#   ]
# }

# %% [markdown]
# ## fred.release_series

# %%
tool_name = "fred_release_series"
await show_tool_schema(tool_name, raw=True)
# Out:
# {
#   "properties": {
#     "limit": {
#       "anyOf": [
#         {
#           "type": "integer"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": 100,
#       "title": "Limit"
#     },
#     "release_id": {
#       "title": "Release Id",
#       "type": "integer"
#     }
#   },
#   "required": [
#     "release_id"
#   ],
#   "title": "list_release_seriesArguments",
#   "type": "object"
# }
# {'properties': {'release_id': {'title': 'Release Id', 'type': 'integer'},
#   'limit': {'anyOf': [{'type': 'integer'}, {'type': 'null'}],
#    'default': 100,
#    'title': 'Limit'}},
#  'required': ['release_id'],
#  'title': 'list_release_seriesArguments',
#  'type': 'object'}

# %%
args = {"series_id": "CBBCHUSD"}
result = await call_tool(tool_name, args)
releases = result.structuredContent
print_json_vertical(releases)
print(result)
# Out:
# null
# meta=None content=[TextContent(type='text', text="Error executing tool fred_release_series: 1 validation error for list_release_seriesArguments\nrelease_id\n  Field required [type=missing, input_value={'series_id': 'CBBCHUSD'}, input_type=dict]\n    For further information visit https://errors.pydantic.dev/2.13/v/missing", annotations=None, meta=None)] structuredContent=None isError=True
