# %% [markdown]
# # FRED Time Series Information

# %%
# %reload_ext autoreload
# %autoreload 2

import sys
import os
import yaml
from pathlib import Path

from typing import Any
from lib.mcp_client import MCPClient, MCPClientConfig
sys.path.append('../')

from lib.utils import print_json_vertical
from utils import call_tool, export_finance_category_series

# %% [markdown]
# ## FRED Category Files

# %%
os.listdir("../categories/category_data/")
# Out:
# ['fred_prices_32455.yaml',
#  'fred_regional_census_regions_32043.yaml',
#  'fred_international_institutions_32956.yaml',
#  'fred_regional_bea_regions_32061.yaml',
#  'fred_population_10.yaml',
#  'fred_finance_32991.yaml',
#  'fred_international_countries_32264.yaml',
#  'fred_national_accounts_32992.yaml',
#  'fred_international_indicators_32265.yaml',
#  'fred_production_1.yaml',
#  'fred_academic_data_33060.yaml',
#  'fred_regional_bls_regions_32849.yaml',
#  'fred_international_finance_33000.yaml',
#  'fred_international_geography_32955.yaml']

# %% [markdown]
# ## fred_prices_32455.yaml

# %%
filename = "fred_prices_32455.yaml"
input_path = str(Path(f"../categories/category_data/{filename}").absolute())
output_path = str(Path(f"series_data/{filename}").absolute())
await export_finance_category_series(input_path, output_path)
# Out:
# Reading categories from /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/../categories/category_data/fred_prices_32455.yaml
# Writing series to /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/series_data/fred_prices_32455.yaml
# Loaded 97 categories
# Processing 1000 series for category 32217, Commodities
# Pagination: count=0, offset=0, limit=0
# Processing 5 series for category 33913, Cryptocurrencies
# Pagination: count=0, offset=0, limit=0
# Processing 417 series for category 4, Employment Cost Index
# Pagination: count=0, offset=0, limit=0
# Processing 57 series for category 33717, Health Care Indexes
# Pagination: count=0, offset=0, limit=0
# Processing 726 series for category 32261, House Price Indexes
# Pagination: count=0, offset=0, limit=0
# Processing 74 series for category 32415, Food and Beverages
# Pagination: count=0, offset=0, limit=0
# Processing 51 series for category 32416, Housing
# Pagination: count=0, offset=0, limit=0
# Processing 25 series for category 32417, Apparel
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32418, Transportation
# Pagination: count=0, offset=0, limit=0
# Processing 25 series for category 32419, Medical Care
# Pagination: count=0, offset=0, limit=0
# Processing 16 series for category 32420, Recreation
# Pagination: count=0, offset=0, limit=0
# Processing 39 series for category 32421, Education and Communication
# Pagination: count=0, offset=0, limit=0
# Processing 33 series for category 32422, Other Goods and Services
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32423, Commodity and Services Groups
# Pagination: count=0, offset=0, limit=0
# Processing 176 series for category 32424, Special Indexes
# Pagination: count=0, offset=0, limit=0
# Processing 28 series for category 32231, Services Price Indexes
# Pagination: count=0, offset=0, limit=0
# Processing 11 series for category 33564, Accommodation Services
# Pagination: count=0, offset=0, limit=0
# Processing 47 series for category 33548, Advertising Space and Time Sales
# Pagination: count=0, offset=0, limit=0
# Processing 305 series for category 33533, Chemicals and Allied Products
# Pagination: count=0, offset=0, limit=0
# Processing 5 series for category 33560, Cleaning and Building Maintenance Services
# Pagination: count=0, offset=0, limit=0
# Processing 20 series for category 33573, Construction
# Pagination: count=0, offset=0, limit=0
# Processing 25 series for category 33572, Contract Work on Textile Products, Apparel, and Leather
# Pagination: count=0, offset=0, limit=0
# Processing 30 series for category 33551, Credit Intermediation Services
# Pagination: count=0, offset=0, limit=0
# Processing 9 series for category 33550, Data Processing and Related Services
# Pagination: count=0, offset=0, limit=0
# Processing 11 series for category 33574, Durability of Product
# Pagination: count=0, offset=0, limit=0
# Processing 5 series for category 33563, Educational Services
# Pagination: count=0, offset=0, limit=0
# Processing 19 series for category 33557, Employment Services
# Pagination: count=0, offset=0, limit=0
# Processing 29 series for category 33567, Entertainment Services
# Pagination: count=0, offset=0, limit=0
# Processing 255 series for category 33528, Farm Products
# Pagination: count=0, offset=0, limit=0
# Processing 220 series for category 33575, Final Demand
# Pagination: count=0, offset=0, limit=0
# Processing 11 series for category 33565, Food and Beverage for Immediate Consumption Services
# Pagination: count=0, offset=0, limit=0
# Processing 207 series for category 33532, Fuels and Related Products and Power
# Pagination: count=0, offset=0, limit=0
# Processing 202 series for category 33539, Furniture and Household Durables
# Pagination: count=0, offset=0, limit=0
# Processing 91 series for category 33561, Health Care Services
# Pagination: count=0, offset=0, limit=0
# Processing 50 series for category 33531, Hides, Skins, Leather, and Related Products
# Pagination: count=0, offset=0, limit=0
# Processing 225 series for category 33582, Inputs to Industries
# Pagination: count=0, offset=0, limit=0
# Processing 36 series for category 33553, Insurance and Annuities
# Pagination: count=0, offset=0, limit=0
# Processing 114 series for category 33577, Intermediate Demand By Commodity Type
# Pagination: count=0, offset=0, limit=0
# Processing 306 series for category 33576, Intermediate Demand By Production Flow
# Pagination: count=0, offset=0, limit=0
# Processing 15 series for category 33552, Investment Services
# Pagination: count=0, offset=0, limit=0
# Processing 139 series for category 33535, Lumber and Wood Products
# Pagination: count=0, offset=0, limit=0
# Processing 768 series for category 33538, Machinery and Equipment
# Pagination: count=0, offset=0, limit=0
# Processing 10 series for category 33570, Metal Treatment Services
# Pagination: count=0, offset=0, limit=0
# Processing 516 series for category 33537, Metals and Metal Products
# Pagination: count=0, offset=0, limit=0
# Processing 23 series for category 33571, Mining Services
# Pagination: count=0, offset=0, limit=0
# Processing 228 series for category 33542, Miscellaneous Products
# Pagination: count=0, offset=0, limit=0
# Processing 12 series for category 33547, Network Compensation from Broadcast and Cable Television and Radio
# Pagination: count=0, offset=0, limit=0
# Processing 224 series for category 33540, Nonmetallic Mineral Products
# Pagination: count=0, offset=0, limit=0
# Processing 484 series for category 33529, Processed Foods and Feeds
# Pagination: count=0, offset=0, limit=0
# Processing 58 series for category 33556, Professional Services
# Pagination: count=0, offset=0, limit=0
# Processing 52 series for category 33545, Publishing Sales, Excluding Software
# Pagination: count=0, offset=0, limit=0
# Processing 241 series for category 33536, Pulp, Paper, and Allied Products
# Pagination: count=0, offset=0, limit=0
# Processing 37 series for category 33554, Real Estate Services
# Pagination: count=0, offset=0, limit=0
# Processing 29 series for category 33555, Rental and Leasing of Goods
# Pagination: count=0, offset=0, limit=0
# Processing 29 series for category 33566, Repair and Maintenance Services
# Pagination: count=0, offset=0, limit=0
# Processing 112 series for category 33569, Retail Trade Services
# Pagination: count=0, offset=0, limit=0
# Processing 123 series for category 33534, Rubber and Plastic Products
# Pagination: count=0, offset=0, limit=0
# Processing 5 series for category 33559, Selected Security Services
# Pagination: count=0, offset=0, limit=0
# Processing 14 series for category 33546, Software Publishing
# Pagination: count=0, offset=0, limit=0
# Processing 35 series for category 33580, Special Indexes
# Pagination: count=0, offset=0, limit=0
# Processing 106 series for category 33581, Stage of Processing
# Pagination: count=0, offset=0, limit=0
# Processing 55 series for category 33549, Telecommunication, Cable, and Internet User Services
# Pagination: count=0, offset=0, limit=0
# Processing 252 series for category 33530, Textile Products and Apparel
# Pagination: count=0, offset=0, limit=0
# Processing 194 series for category 33541, Transportation Equipment
# Pagination: count=0, offset=0, limit=0
# Processing 102 series for category 33543, Transportation Services
# Pagination: count=0, offset=0, limit=0
# Processing 26 series for category 33558, Travel Arrangement Services
# Pagination: count=0, offset=0, limit=0
# Processing 5 series for category 33544, Warehousing, Storage, and Related Services
# Pagination: count=0, offset=0, limit=0
# Processing 8 series for category 33562, Waste Collection and Remediation Services
# Pagination: count=0, offset=0, limit=0
# Processing 51 series for category 33568, Wholesale Trade Services
# Pagination: count=0, offset=0, limit=0
# Processing 24 series for category 33586, Accommodation and Food Services
# Pagination: count=0, offset=0, limit=0
# Processing 56 series for category 33588, Administrative and Support and Waste Management and Remediation Services
# Pagination: count=0, offset=0, limit=0
# Processing 6 series for category 33585, Agriculture, Forestry, Fishing and Hunting
# Pagination: count=0, offset=0, limit=0
# Processing 22 series for category 33587, Arts, Entertainment, and Recreation
# Pagination: count=0, offset=0, limit=0
# Processing 50 series for category 33589, Construction
# Pagination: count=0, offset=0, limit=0
# Processing 5 series for category 33591, Educational Services
# Pagination: count=0, offset=0, limit=0
# Processing 127 series for category 33590, Finance and Insurance
# Pagination: count=0, offset=0, limit=0
# Processing 211 series for category 33593, Health Care and Social Assistance
# Pagination: count=0, offset=0, limit=0
# Processing 227 series for category 33592, Information
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33597, Manufacturing
# Pagination: count=0, offset=0, limit=0
# Processing 191 series for category 33596, Mining, Quarrying, and Oil and Gas Extraction
# Pagination: count=0, offset=0, limit=0
# Processing 9 series for category 33594, Other Services (except Public Administration)
# Pagination: count=0, offset=0, limit=0
# Processing 75 series for category 33599, Professional, Scientific, and Technical Services
# Pagination: count=0, offset=0, limit=0
# Processing 11 series for category 33595, Public Administration
# Pagination: count=0, offset=0, limit=0
# Processing 53 series for category 33598, Real Estate and Rental and Leasing
# Pagination: count=0, offset=0, limit=0
# Processing 327 series for category 33600, Retail Trade
# Pagination: count=0, offset=0, limit=0
# Processing 245 series for category 33601, Transportation and Warehousing
# Pagination: count=0, offset=0, limit=0
# Processing 90 series for category 33602, Utilities
# Pagination: count=0, offset=0, limit=0
# Processing 201 series for category 33603, Wholesale Trade
# Pagination: count=0, offset=0, limit=0
# Processing 156 series for category 32223, End Use Classification System
# Pagination: count=0, offset=0, limit=0
# Processing 169 series for category 32229, By Harmonized System
# Pagination: count=0, offset=0, limit=0
# Processing 161 series for category 32226, By NAICS
# Pagination: count=0, offset=0, limit=0
# Processing 32 series for category 32230, By Locality of Origin
# Pagination: count=0, offset=0, limit=0
# Processing 130 series for category 33907, Standard International Trade Classification
# Pagination: count=0, offset=0, limit=0
# Processing 135 series for category 32225, End Use Classification System
# Pagination: count=0, offset=0, limit=0
# Processing 127 series for category 32227, By NAICS
# Pagination: count=0, offset=0, limit=0
# Processing 128 series for category 32228, By Harmonized System
# Pagination: count=0, offset=0, limit=0
# Processing 112 series for category 33905, Standard International Trade Classification
# Pagination: count=0, offset=0, limit=0

# %% [markdown]
# ## fred_regional_census_regions_32043.yaml

# %%
filename = "fred_regional_census_regions_32043.yaml"
input_path = str(Path(f"../categories/category_data/{filename}").absolute())
output_path = str(Path(f"series_data/{filename}").absolute())
await export_finance_category_series(input_path, output_path)
# Out:
# Reading categories from /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/../categories/category_data/fred_regional_census_regions_32043.yaml
# Writing series to /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/series_data/fred_regional_census_regions_32043.yaml
# Loaded 9 categories
# Processing 63 series for category 32049, East North Central
# Pagination: count=0, offset=0, limit=0
# Processing 63 series for category 32050, West North Central
# Pagination: count=0, offset=0, limit=0
# Processing 63 series for category 32052, Middle Atlantic
# Pagination: count=0, offset=0, limit=0
# Processing 63 series for category 32053, New England
# Pagination: count=0, offset=0, limit=0
# Processing 63 series for category 32055, East South Central
# Pagination: count=0, offset=0, limit=0
# Processing 63 series for category 32056, South Atlantic
# Pagination: count=0, offset=0, limit=0
# Processing 63 series for category 32057, West South Central
# Pagination: count=0, offset=0, limit=0
# Processing 63 series for category 32059, Mountain
# Pagination: count=0, offset=0, limit=0
# Processing 63 series for category 32060, Pacific
# Pagination: count=0, offset=0, limit=0
# Wrote series data for 9 categories to /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/series_data/fred_regional_census_regions_32043.yaml

# %% [markdown]
# ## fred_international_institutions_32956.yaml

# %%
filename = "fred_international_institutions_32956.yaml"
input_path = str(Path(f"../categories/category_data/{filename}").absolute())
output_path = str(Path(f"series_data/{filename}").absolute())
await export_finance_category_series(input_path, output_path)
# Out:
# Reading categories from /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/../categories/category_data/fred_international_institutions_32956.yaml
# Writing series to /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/series_data/fred_international_institutions_32956.yaml
# Loaded 26 categories
# Processing 4 series for category 33903, Advanced Economies
# Pagination: count=0, offset=0, limit=0
# Processing 8 series for category 33127, Association of Southeast Asian Nations (ASEAN)
# Pagination: count=0, offset=0, limit=0
# Processing 8 series for category 33126, Bureau of Labor Statistics Asian Newly Industrialized Countries
# Pagination: count=0, offset=0, limit=0
# Processing 41 series for category 33124, Bureau of Labor Statistics Industrialized Countries
# Pagination: count=0, offset=0, limit=0
# Processing 15 series for category 33128, Bureau of Labor Statistics Latin America
# Pagination: count=0, offset=0, limit=0
# Processing 42 series for category 33125, Bureau of Labor Statistics Pacific Rim
# Pagination: count=0, offset=0, limit=0
# Processing 4 series for category 33901, Emerging Markets
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32947, Euro Area
# Pagination: count=0, offset=0, limit=0
# Processing 167 series for category 33002, European Economic Area
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32948, European Union
# Pagination: count=0, offset=0, limit=0
# Processing 15 series for category 32958, Four Big European Countries
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32959, Group of Seven (G7)
# Pagination: count=0, offset=0, limit=0
# Processing 67 series for category 33083, Group of Twenty Finance Ministers and Central Bank Governors (G20)
# Pagination: count=0, offset=0, limit=0
# Processing 6 series for category 33239, International Monetary Fund
# Pagination: count=0, offset=0, limit=0
# Processing 7 series for category 33711, International Organizations
# Pagination: count=0, offset=0, limit=0
# Processing 17 series for category 32957, Major 5 Asia
# Pagination: count=0, offset=0, limit=0
# Processing 19 series for category 32960, NAFTA
# Pagination: count=0, offset=0, limit=0
# Processing 10 series for category 33086, Non-OECD
# Pagination: count=0, offset=0, limit=0
# Processing 0 series for category 33085, OECD Non-member Economies
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32962, OECD Total
# Pagination: count=0, offset=0, limit=0
# Processing 17 series for category 32961, OECD + Non-member Economies
# Pagination: count=0, offset=0, limit=0
# Processing 303 series for category 33087, OECD - Europe
# Pagination: count=0, offset=0, limit=0
# Processing 19 series for category 33713, Unidentified Countries
# Pagination: count=0, offset=0, limit=0
# Processing 2 series for category 33909, Advance Technology Products
# Pagination: count=0, offset=0, limit=0
# Processing 2 series for category 33911, NICS
# Pagination: count=0, offset=0, limit=0
# Processing 4 series for category 33953, USMCA
# Pagination: count=0, offset=0, limit=0
# Wrote series data for 26 categories to /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/series_data/fred_international_institutions_32956.yaml

# %% [markdown]
# ## fred_regional_bea_regions_32061.yaml

# %%
filename = "fred_regional_bea_regions_32061.yaml"
input_path = str(Path(f"../categories/category_data/{filename}").absolute())
output_path = str(Path(f"series_data/{filename}").absolute())
await export_finance_category_series(input_path, output_path)
# Out:
# Reading categories from /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/../categories/category_data/fred_regional_bea_regions_32061.yaml
# Writing series to /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/series_data/fred_regional_bea_regions_32061.yaml
# Loaded 8 categories
# Processing 405 series for category 32062, Far West
# Pagination: count=0, offset=0, limit=0
# Processing 405 series for category 32063, Great Lakes
# Pagination: count=0, offset=0, limit=0
# Processing 405 series for category 32064, Mideast
# Pagination: count=0, offset=0, limit=0
# Processing 405 series for category 32065, New England
# Pagination: count=0, offset=0, limit=0
# Processing 405 series for category 32066, Plains
# Pagination: count=0, offset=0, limit=0
# Processing 405 series for category 32067, Rocky Mountain
# Pagination: count=0, offset=0, limit=0
# Processing 405 series for category 32068, Southeast
# Pagination: count=0, offset=0, limit=0
# Processing 405 series for category 32069, Southwest
# Pagination: count=0, offset=0, limit=0
# Wrote series data for 8 categories to /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/series_data/fred_regional_bea_regions_32061.yaml

# %% [markdown]
# ## fred_population_10.yaml

# %%
filename = "fred_population_10.yaml"
input_path = str(Path(f"../categories/category_data/{filename}").absolute())
output_path = str(Path(f"series_data/{filename}").absolute())
await export_finance_category_series(input_path, output_path)
# Out:
# Reading categories from /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/../categories/category_data/fred_population_10.yaml
# Writing series to /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/series_data/fred_population_10.yaml
# Loaded 75 categories
# Processing 93 series for category 32250, ADP Employment
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33500, Education
# Pagination: count=0, offset=0, limit=0
# Processing 515 series for category 33001, Income Distribution
# Pagination: count=0, offset=0, limit=0
# Processing 914 series for category 33509, Labor Market Conditions
# Pagination: count=0, offset=0, limit=0
# Processing 51 series for category 33831, Minimum Wage
# Pagination: count=0, offset=0, limit=0
# Processing 23 series for category 32240, Weekly Initial Claims
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33731, Tax Data
# Pagination: count=0, offset=0, limit=0
# Processing 683 series for category 32442, Civilian Labor Force
# Pagination: count=0, offset=0, limit=0
# Processing 62 series for category 32443, Civilian Labor Force Participation Rate
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32444, Employment
# Pagination: count=0, offset=0, limit=0
# Processing 75 series for category 32445, Employment Population Ratio
# Pagination: count=0, offset=0, limit=0
# Processing 748 series for category 32446, Unemployment Level
# Pagination: count=0, offset=0, limit=0
# Processing 820 series for category 32447, Unemployment Rate
# Pagination: count=0, offset=0, limit=0
# Processing 59 series for category 32448, Not in Labor Force
# Pagination: count=0, offset=0, limit=0
# Processing 18 series for category 32449, Labor Force Participation Rate
# Pagination: count=0, offset=0, limit=0
# Processing 20 series for category 32450, Multiple Jobholders
# Pagination: count=0, offset=0, limit=0
# Processing 18 series for category 32451, Duration of Unemployment
# Pagination: count=0, offset=0, limit=0
# Processing 8 series for category 32452, Losers and Leavers
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33501, Earnings
# Pagination: count=0, offset=0, limit=0
# Processing 4 series for category 32453, Entrants and Reentrants
# Pagination: count=0, offset=0, limit=0
# Processing 90 series for category 33502, Labor Force Status Flows
# Pagination: count=0, offset=0, limit=0
# Processing 13 series for category 32305, Total Nonfarm
# Pagination: count=0, offset=0, limit=0
# Processing 27 series for category 32306, Total Private
# Pagination: count=0, offset=0, limit=0
# Processing 27 series for category 32307, Goods-Producing
# Pagination: count=0, offset=0, limit=0
# Processing 1 series for category 32326, Service-Providing
# Pagination: count=0, offset=0, limit=0
# Processing 27 series for category 32308, Private Service-Providing
# Pagination: count=0, offset=0, limit=0
# Processing 39 series for category 32309, Mining and Logging
# Pagination: count=0, offset=0, limit=0
# Processing 41 series for category 32310, Construction
# Pagination: count=0, offset=0, limit=0
# Processing 31 series for category 32311, Manufacturing
# Pagination: count=0, offset=0, limit=0
# Processing 63 series for category 32312, Durable Goods
# Pagination: count=0, offset=0, limit=0
# Processing 55 series for category 32313, Nondurable Goods
# Pagination: count=0, offset=0, limit=0
# Processing 27 series for category 32314, Trade, Transportation, and Utilities
# Pagination: count=0, offset=0, limit=0
# Processing 33 series for category 32315, Wholesale Trade
# Pagination: count=0, offset=0, limit=0
# Processing 55 series for category 32316, Retail Trade
# Pagination: count=0, offset=0, limit=0
# Processing 47 series for category 32317, Transportation and Warehousing
# Pagination: count=0, offset=0, limit=0
# Processing 27 series for category 32318, Utilities
# Pagination: count=0, offset=0, limit=0
# Processing 39 series for category 32319, Information
# Pagination: count=0, offset=0, limit=0
# Processing 51 series for category 32320, Financial Activities
# Pagination: count=0, offset=0, limit=0
# Processing 55 series for category 32321, Professional and Business Services
# Pagination: count=0, offset=0, limit=0
# Processing 51 series for category 32322, Education and Health Services
# Pagination: count=0, offset=0, limit=0
# Processing 41 series for category 32323, Leisure and Hospitality
# Pagination: count=0, offset=0, limit=0
# Processing 33 series for category 32324, Other Services
# Pagination: count=0, offset=0, limit=0
# Processing 23 series for category 32325, Government
# Pagination: count=0, offset=0, limit=0
# Processing 84 series for category 32243, Job Openings (Levels and Rates)
# Pagination: count=0, offset=0, limit=0
# Processing 84 series for category 32245, Hires (Levels and Rates)
# Pagination: count=0, offset=0, limit=0
# Processing 84 series for category 32246, Total Separations (Levels and Rates)
# Pagination: count=0, offset=0, limit=0
# Processing 85 series for category 32247, Quits (Levels and Rates)
# Pagination: count=0, offset=0, limit=0
# Processing 66 series for category 32248, Layoffs and Discharges (Levels and Rates)
# Pagination: count=0, offset=0, limit=0
# Processing 52 series for category 32249, Other Separations (Levels and Rates)
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33735, Poverty Measures
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33514, Supplemental Nutrition Assistance Program
# Pagination: count=0, offset=0, limit=0
# Processing 252 series for category 33961, Agriculture, Forestry, Fishing and Hunting
# Pagination: count=0, offset=0, limit=0
# Processing 322 series for category 33963, Mining
# Pagination: count=0, offset=0, limit=0
# Processing 161 series for category 33965, Utilities
# Pagination: count=0, offset=0, limit=0
# Processing 120 series for category 33967, Construction
# Pagination: count=0, offset=0, limit=0
# Processing 575 series for category 33969, Wholesale Trade
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33972, Retail Trade
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33974, Transportation and Warehousing
# Pagination: count=0, offset=0, limit=0
# Processing 596 series for category 33976, Information
# Pagination: count=0, offset=0, limit=0
# Processing 166 series for category 33978, Finance and Insurance
# Pagination: count=0, offset=0, limit=0
# Processing 194 series for category 33980, Real Estate and Rental and Leasing
# Pagination: count=0, offset=0, limit=0
# Processing 388 series for category 33982, Professional, Scientific, and Technical Services
# Pagination: count=0, offset=0, limit=0
# Processing 24 series for category 33984, Management of Companies and Enterprises
# Pagination: count=0, offset=0, limit=0
# Processing 246 series for category 33986, Administrative and Support and Waste Management and Remediation Services
# Pagination: count=0, offset=0, limit=0
# Processing 108 series for category 33988, Educational Services
# Pagination: count=0, offset=0, limit=0
# Processing 361 series for category 33990, Health Care and Social Assistance
# Pagination: count=0, offset=0, limit=0
# Processing 320 series for category 33992, Arts, Entertainment, and Recreation
# Pagination: count=0, offset=0, limit=0
# Processing 352 series for category 33994, Accommodation and Food Services
# Pagination: count=0, offset=0, limit=0
# Processing 478 series for category 33996, Other Services (except Public Administration)
# Pagination: count=0, offset=0, limit=0
# Processing 6 series for category 33998, Government
# Pagination: count=0, offset=0, limit=0
# Processing 92 series for category 32350, Business
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32351, Nonfarm Business
# Pagination: count=0, offset=0, limit=0
# Processing 57 series for category 32354, Nonfinancial Corporations
# Pagination: count=0, offset=0, limit=0
# Processing 606 series for category 32352, Durable Goods
# Pagination: count=0, offset=0, limit=0
# Processing 504 series for category 32353, Nondurable Goods
# Pagination: count=0, offset=0, limit=0
# Wrote series data for 75 categories to /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/series_data/fred_population_10.yaml

# %% [markdown]
# ## fred_finance_32991.yaml

# %%
filename = "fred_finance_32991.yaml"
input_path = str(Path(f"../categories/category_data/{filename}").absolute())
output_path = str(Path(f"series_data/{filename}").absolute())
await export_finance_category_series(input_path, output_path)
# Out:
# Reading categories from /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/../categories/category_data/fred_finance_32991.yaml
# Writing series to /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/series_data/fred_finance_32991.yaml
# Loaded 162 categories
# Processing 21 series for category 32145, Foreign Exchange Intervention
# Pagination: count=0, offset=0, limit=0
# Processing 11 series for category 34009, AMERIBOR Benchmark Rates
# Pagination: count=0, offset=0, limit=0
# Processing 4 series for category 33058, Automobile Loan Rates
# Pagination: count=0, offset=0, limit=0
# Processing 12 series for category 51, Bankers Acceptance Rate
# Pagination: count=0, offset=0, limit=0
# Processing 46 series for category 121, Certificates of Deposit
# Pagination: count=0, offset=0, limit=0
# Processing 84 series for category 120, Commercial Paper
# Pagination: count=0, offset=0, limit=0
# Processing 362 series for category 32348, Corporate Bonds
# Pagination: count=0, offset=0, limit=0
# Processing 2 series for category 33059, Credit Card Loan Rates
# Pagination: count=0, offset=0, limit=0
# Processing 1 series for category 34005, EONIA Rates
# Pagination: count=0, offset=0, limit=0
# Processing 7 series for category 34007, Euro Short-Term Rate
# Pagination: count=0, offset=0, limit=0
# Processing 12 series for category 32298, Eurodollar Deposits
# Pagination: count=0, offset=0, limit=0
# Processing 80 series for category 118, FRB Rates - discount, fed funds, primary credit
# Pagination: count=0, offset=0, limit=0
# Processing 2 series for category 33056, Interest Checking Accounts
# Pagination: count=0, offset=0, limit=0
# Processing 36 series for category 33446, Interest Rate Spreads
# Pagination: count=0, offset=0, limit=0
# Processing 32 series for category 32299, Interest Rate Swaps
# Pagination: count=0, offset=0, limit=0
# Processing 8 series for category 32995, Long-Term Securities
# Pagination: count=0, offset=0, limit=0
# Processing 1 series for category 34242, Monetary Policy
# Pagination: count=0, offset=0, limit=0
# Processing 4 series for category 33055, Money Market Accounts
# Pagination: count=0, offset=0, limit=0
# Processing 32 series for category 114, Mortgage Rates
# Pagination: count=0, offset=0, limit=0
# Processing 1 series for category 33057, Personal Loan Rates
# Pagination: count=0, offset=0, limit=0
# Processing 6 series for category 117, Prime Bank Loan Rate
# Pagination: count=0, offset=0, limit=0
# Processing 55 series for category 33491, Saving Accounts
# Pagination: count=0, offset=0, limit=0
# Processing 7 series for category 34003, SONIA Rates
# Pagination: count=0, offset=0, limit=0
# Processing 34 series for category 116, Treasury Bills
# Pagination: count=0, offset=0, limit=0
# Processing 63 series for category 115, Treasury Constant Maturity
# Pagination: count=0, offset=0, limit=0
# Processing 177 series for category 82, Treasury Inflation-Indexed Securities
# Pagination: count=0, offset=0, limit=0
# Processing 35 series for category 94, Daily Rates
# Pagination: count=0, offset=0, limit=0
# Processing 39 series for category 95, Monthly Rates
# Pagination: count=0, offset=0, limit=0
# Processing 26 series for category 32219, Annual Rates
# Pagination: count=0, offset=0, limit=0
# Processing 79 series for category 105, Trade-Weighted Indexes
# Pagination: count=0, offset=0, limit=0
# Processing 27 series for category 124, Monetary Base
# Pagination: count=0, offset=0, limit=0
# Processing 61 series for category 123, Reserves
# Pagination: count=0, offset=0, limit=0
# Processing 72 series for category 25, M1 and Components
# Pagination: count=0, offset=0, limit=0
# Processing 50 series for category 29, M2 and Components
# Pagination: count=0, offset=0, limit=0
# Processing 7 series for category 96, M2 Minus Small Time Deposits
# Pagination: count=0, offset=0, limit=0
# Processing 60 series for category 28, M3 and Components
# Pagination: count=0, offset=0, limit=0
# Processing 10 series for category 30, MZM
# Pagination: count=0, offset=0, limit=0
# Processing 23 series for category 26, Memorandum Items
# Pagination: count=0, offset=0, limit=0
# Processing 3 series for category 32242, Money Velocity
# Pagination: count=0, offset=0, limit=0
# Processing 18 series for category 122, Borrowings
# Pagination: count=0, offset=0, limit=0
# Processing 655 series for category 32215, Factors Affecting Reserve Balances
# Pagination: count=0, offset=0, limit=0
# Processing 203 series for category 32218, Securities, Loans, & Other Assets & Liabilities Held by Fed
# Pagination: count=0, offset=0, limit=0
# Processing 134 series for category 33119, Consumer Financial Condition Indexes
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32457, Financial Activity Measures
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32255, Stock Market Indexes
# Pagination: count=0, offset=0, limit=0
# Processing 21 series for category 32425, Volatility Indexes
# Pagination: count=0, offset=0, limit=0
# Processing 8 series for category 34078, Banking Indexes
# Pagination: count=0, offset=0, limit=0
# Processing 155 series for category 101, Consumer Credit
# Pagination: count=0, offset=0, limit=0
# Processing 99 series for category 32440, Delinquencies and Delinquency Rates
# Pagination: count=0, offset=0, limit=0
# Processing 22 series for category 33121, Failures and Assistance Transactions
# Pagination: count=0, offset=0, limit=0
# Processing 89 series for category 33445, Mortgage Debt Outstanding
# Pagination: count=0, offset=0, limit=0
# Processing 99 series for category 32439, Net Charge-Offs and Charge-Off Rates
# Pagination: count=0, offset=0, limit=0
# Processing 143 series for category 99, Securities & Investments
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 34111, Senior Credit Officer Opinion Survey
# Pagination: count=0, offset=0, limit=0
# Processing 639 series for category 32239, Senior Loan Officer Survey
# Pagination: count=0, offset=0, limit=0
# Processing 178 series for category 32996, Commercial Paper
# Pagination: count=0, offset=0, limit=0
# Processing 262 series for category 33439, Commercial and Industrial Loans Backed by Small Business Association
# Pagination: count=0, offset=0, limit=0
# Processing 263 series for category 33440, Commercial and Industrial Loans Made Under Participation or Syndication
# Pagination: count=0, offset=0, limit=0
# Processing 3 series for category 287, Australia
# Pagination: count=0, offset=0, limit=0
# Processing 1 series for category 286, Austria
# Pagination: count=0, offset=0, limit=0
# Processing 1 series for category 285, Belgium
# Pagination: count=0, offset=0, limit=0
# Processing 3 series for category 284, Brazil
# Pagination: count=0, offset=0, limit=0
# Processing 3 series for category 283, Canada
# Pagination: count=0, offset=0, limit=0
# Processing 3 series for category 282, China
# Pagination: count=0, offset=0, limit=0
# Processing 3 series for category 281, Denmark
# Pagination: count=0, offset=0, limit=0
# Processing 4 series for category 280, Euro
# Pagination: count=0, offset=0, limit=0
# Processing 1 series for category 279, Finland
# Pagination: count=0, offset=0, limit=0
# Processing 1 series for category 278, France
# Pagination: count=0, offset=0, limit=0
# Processing 1 series for category 277, Germany
# Pagination: count=0, offset=0, limit=0
# Processing 1 series for category 274, Greece
# Pagination: count=0, offset=0, limit=0
# Processing 3 series for category 273, Hong Kong
# Pagination: count=0, offset=0, limit=0
# Processing 3 series for category 272, India
# Pagination: count=0, offset=0, limit=0
# Processing 1 series for category 271, Ireland
# Pagination: count=0, offset=0, limit=0
# Processing 1 series for category 276, Italy
# Pagination: count=0, offset=0, limit=0
# Processing 3 series for category 275, Japan
# Pagination: count=0, offset=0, limit=0
# Processing 3 series for category 270, Malaysia
# Pagination: count=0, offset=0, limit=0
# Processing 3 series for category 269, Mexico
# Pagination: count=0, offset=0, limit=0
# Processing 1 series for category 268, Netherlands
# Pagination: count=0, offset=0, limit=0
# Processing 3 series for category 266, New Zealand
# Pagination: count=0, offset=0, limit=0
# Processing 3 series for category 265, Norway
# Pagination: count=0, offset=0, limit=0
# Processing 1 series for category 264, Portugal
# Pagination: count=0, offset=0, limit=0
# Processing 3 series for category 263, Singapore
# Pagination: count=0, offset=0, limit=0
# Processing 3 series for category 262, South Africa
# Pagination: count=0, offset=0, limit=0
# Processing 3 series for category 261, South Korea
# Pagination: count=0, offset=0, limit=0
# Processing 1 series for category 260, Spain
# Pagination: count=0, offset=0, limit=0
# Processing 3 series for category 259, Sri Lanka
# Pagination: count=0, offset=0, limit=0
# Processing 3 series for category 258, Sweden
# Pagination: count=0, offset=0, limit=0
# Processing 3 series for category 257, Switzerland
# Pagination: count=0, offset=0, limit=0
# Processing 3 series for category 267, Taiwan
# Pagination: count=0, offset=0, limit=0
# Processing 3 series for category 254, Thailand
# Pagination: count=0, offset=0, limit=0
# Processing 3 series for category 191, United Kingdom
# Pagination: count=0, offset=0, limit=0
# Processing 3 series for category 192, Venezuela
# Pagination: count=0, offset=0, limit=0
# Processing 48 series for category 32413, BofA Merrill Lynch Total Bond Return Index Values
# Pagination: count=0, offset=0, limit=0
# Processing 361 series for category 33078, All Commercial Banks
# Pagination: count=0, offset=0, limit=0
# Processing 389 series for category 33079, Domestically Chartered Commercial Banks
# Pagination: count=0, offset=0, limit=0
# Processing 379 series for category 33080, Foreign-Related Institutions
# Pagination: count=0, offset=0, limit=0
# Processing 388 series for category 33081, Large Domestically Chartered Commercial Banks
# Pagination: count=0, offset=0, limit=0
# Processing 387 series for category 33082, Small Domestically Chartered Commercial Banks
# Pagination: count=0, offset=0, limit=0
# Processing 258 series for category 93, United States
# Pagination: count=0, offset=0, limit=0
# Processing 18 series for category 84, New England Census Division
# Pagination: count=0, offset=0, limit=0
# Processing 18 series for category 85, Middle Atlantic Census Division
# Pagination: count=0, offset=0, limit=0
# Processing 18 series for category 86, East North Central Census Division
# Pagination: count=0, offset=0, limit=0
# Processing 18 series for category 87, West North Central Census Division
# Pagination: count=0, offset=0, limit=0
# Processing 18 series for category 88, South Atlantic Census Division
# Pagination: count=0, offset=0, limit=0
# Processing 18 series for category 89, East South Central Census Division
# Pagination: count=0, offset=0, limit=0
# Processing 18 series for category 90, West South Central Census Division
# Pagination: count=0, offset=0, limit=0
# Processing 18 series for category 91, Mountain Census Division
# Pagination: count=0, offset=0, limit=0
# Processing 18 series for category 92, Pacific Census Division
# Pagination: count=0, offset=0, limit=0
# Processing 7 series for category 72, 8th District
# Pagination: count=0, offset=0, limit=0
# Processing 14 series for category 65, Arkansas
# Pagination: count=0, offset=0, limit=0
# Processing 14 series for category 66, Illinois
# Pagination: count=0, offset=0, limit=0
# Processing 14 series for category 67, Indiana
# Pagination: count=0, offset=0, limit=0
# Processing 14 series for category 68, Kentucky
# Pagination: count=0, offset=0, limit=0
# Processing 14 series for category 69, Mississippi
# Pagination: count=0, offset=0, limit=0
# Processing 14 series for category 70, Missouri
# Pagination: count=0, offset=0, limit=0
# Processing 14 series for category 71, Tennessee
# Pagination: count=0, offset=0, limit=0
# Processing 56 series for category 32407, All Commercial Banks
# Pagination: count=0, offset=0, limit=0
# Processing 56 series for category 32408, Domestic Banks
# Pagination: count=0, offset=0, limit=0
# Processing 56 series for category 32409, Foreign Banks
# Pagination: count=0, offset=0, limit=0
# Processing 56 series for category 32410, Large Domestic Banks
# Pagination: count=0, offset=0, limit=0
# Processing 56 series for category 32411, Small Domestic Banks
# Pagination: count=0, offset=0, limit=0
# Processing 10 series for category 32412, Summary Statistics
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32362, All Commercial and Industrial Loans
# Pagination: count=0, offset=0, limit=0
# Processing 18 series for category 32369, Base Rate of Loans
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32364, Daily Repricing/Maturity Interval
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32367, More Than 365 Days Repricing/Maturity Interval
# Pagination: count=0, offset=0, limit=0
# Processing 36 series for category 32368, Size of Loans
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32366, 31 to 365 Days Repricing/Maturity Interval
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32365, 2 to 30 Days Repricing/Maturity Interval
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32363, Zero Repricing/Maturity Interval
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32371, All Commercial and Industrial Loans
# Pagination: count=0, offset=0, limit=0
# Processing 18 series for category 32375, Base Rate of Loans
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32372, Daily Repricing/Maturity Interval
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32373, More Than 365 Days Repricing/Maturity Interval
# Pagination: count=0, offset=0, limit=0
# Processing 8 series for category 32374, Size of Loans
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32376, 31 to 365 Days Repricing/Maturity Interval
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32377, 2 to 30 Days Repricing/Maturity Interval
# Pagination: count=0, offset=0, limit=0
# Processing 40 series for category 32378, Zero Repricing/Maturity Interval
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32380, All Commercial and Industrial Loans
# Pagination: count=0, offset=0, limit=0
# Processing 18 series for category 32381, Base Rate of Loans
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32382, Daily Repricing/Maturity Interval
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32383, More Than 365 Days Repricing/Maturity Interval
# Pagination: count=0, offset=0, limit=0
# Processing 36 series for category 32384, Size of Loans
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32385, 31 to 365 Days Repricing/Maturity Interval
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32386, 2 to 30 Days Repricing/Maturity Interval
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32387, Zero Repricing/Maturity Interval
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32389, All Commercial and Industrial Loans
# Pagination: count=0, offset=0, limit=0
# Processing 18 series for category 32390, Base Rate of Loans
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32391, Daily Repricing/Maturity Interval
# Pagination: count=0, offset=0, limit=0
# Processing 40 series for category 32392, More Than 365 Days Repricing/Maturity Interval
# Pagination: count=0, offset=0, limit=0
# Processing 36 series for category 32393, Size of Loans
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32394, 31 to 365 Days Repricing/Maturity Interval
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32395, 2 to 30 Days Repricing/Maturity Interval
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32396, Zero Repricing/Maturity Interval
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32398, All Commercial and Industrial Loans
# Pagination: count=0, offset=0, limit=0
# Processing 18 series for category 32399, Base Rate of Loans
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32400, Daily Repricing/Maturity Interval
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32401, More Than 365 Days Repricing/Maturity Interval
# Pagination: count=0, offset=0, limit=0
# Processing 36 series for category 32402, Size of Loans
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32403, 31 to 365 Days Repricing/Maturity Interval
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32404, 2 to 30 Days Repricing/Maturity Interval
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32405, Zero Repricing/Maturity Interval
# Pagination: count=0, offset=0, limit=0
# Wrote series data for 162 categories to /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/series_data/fred_finance_32991.yaml

# %% [markdown]
# ## fred_international_countries_32264.yaml

# %%
filename = "fred_international_countries_32264.yaml"
input_path = str(Path(f"../categories/category_data/{filename}").absolute())
output_path = str(Path(f"series_data/{filename}").absolute())
await export_finance_category_series(input_path, output_path)
# Out:
# Reading categories from /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/../categories/category_data/fred_international_countries_32264.yaml
# Writing series to /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/series_data/fred_international_countries_32264.yaml
# Loaded 243 categories
# Processing 213 series for category 32641, Afghanistan
# Pagination: count=0, offset=0, limit=0
# Processing 208 series for category 32643, Albania
# Pagination: count=0, offset=0, limit=0
# Processing 255 series for category 32644, Algeria
# Pagination: count=0, offset=0, limit=0
# Processing 5 series for category 32645, American Samoa
# Pagination: count=0, offset=0, limit=0
# Processing 92 series for category 32646, Andorra
# Pagination: count=0, offset=0, limit=0
# Processing 282 series for category 32647, Angola
# Pagination: count=0, offset=0, limit=0
# Processing 108 series for category 32648, Anguilla
# Pagination: count=0, offset=0, limit=0
# Processing 181 series for category 32650, Antigua and Barbuda
# Pagination: count=0, offset=0, limit=0
# Processing 585 series for category 32651, Argentina
# Pagination: count=0, offset=0, limit=0
# Processing 242 series for category 32652, Armenia
# Pagination: count=0, offset=0, limit=0
# Processing 212 series for category 32653, Aruba
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32269, Australia
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32282, Austria
# Pagination: count=0, offset=0, limit=0
# Processing 248 series for category 32654, Azerbaijan
# Pagination: count=0, offset=0, limit=0
# Processing 232 series for category 32655, Bahamas
# Pagination: count=0, offset=0, limit=0
# Processing 217 series for category 32656, Bahrain
# Pagination: count=0, offset=0, limit=0
# Processing 358 series for category 32657, Bangladesh
# Pagination: count=0, offset=0, limit=0
# Processing 241 series for category 32658, Barbados
# Pagination: count=0, offset=0, limit=0
# Processing 226 series for category 32659, Belarus
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32270, Belgium
# Pagination: count=0, offset=0, limit=0
# Processing 230 series for category 32660, Belize
# Pagination: count=0, offset=0, limit=0
# Processing 252 series for category 32661, Benin
# Pagination: count=0, offset=0, limit=0
# Processing 171 series for category 32662, Bermuda
# Pagination: count=0, offset=0, limit=0
# Processing 153 series for category 32663, Bhutan
# Pagination: count=0, offset=0, limit=0
# Processing 262 series for category 32664, Bolivia, Plurinational State of
# Pagination: count=0, offset=0, limit=0
# Processing 114 series for category 32665, Caribbean Netherlands
# Pagination: count=0, offset=0, limit=0
# Processing 307 series for category 32666, Bosnia and Herzegovina
# Pagination: count=0, offset=0, limit=0
# Processing 293 series for category 32667, Botswana
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32327, Brazil
# Pagination: count=0, offset=0, limit=0
# Processing 56 series for category 32669, British Indian Ocean Territory
# Pagination: count=0, offset=0, limit=0
# Processing 234 series for category 32670, Brunei Darussalam
# Pagination: count=0, offset=0, limit=0
# Processing 441 series for category 32671, Bulgaria
# Pagination: count=0, offset=0, limit=0
# Processing 206 series for category 32672, Burkina Faso
# Pagination: count=0, offset=0, limit=0
# Processing 282 series for category 32673, Burundi
# Pagination: count=0, offset=0, limit=0
# Processing 214 series for category 32674, Cambodia
# Pagination: count=0, offset=0, limit=0
# Processing 281 series for category 32675, Cameroon
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32268, Canada
# Pagination: count=0, offset=0, limit=0
# Processing 169 series for category 32676, Cape Verde
# Pagination: count=0, offset=0, limit=0
# Processing 168 series for category 32677, Cayman Islands
# Pagination: count=0, offset=0, limit=0
# Processing 189 series for category 32678, Central African Republic
# Pagination: count=0, offset=0, limit=0
# Processing 219 series for category 32679, Chad
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32328, Chile
# Pagination: count=0, offset=0, limit=0
# Processing 766 series for category 32329, China
# Pagination: count=0, offset=0, limit=0
# Processing 53 series for category 32680, Christmas Island
# Pagination: count=0, offset=0, limit=0
# Processing 42 series for category 32681, Cocos (Keeling) Islands
# Pagination: count=0, offset=0, limit=0
# Processing 950 series for category 32682, Colombia
# Pagination: count=0, offset=0, limit=0
# Processing 202 series for category 32683, Comoros
# Pagination: count=0, offset=0, limit=0
# Processing 240 series for category 32684, Congo, Republic of the
# Pagination: count=0, offset=0, limit=0
# Processing 232 series for category 32685, Congo, Democratic Republic of the
# Pagination: count=0, offset=0, limit=0
# Processing 54 series for category 32686, Cook Islands
# Pagination: count=0, offset=0, limit=0
# Processing 604 series for category 32687, Costa Rica
# Pagination: count=0, offset=0, limit=0
# Processing 243 series for category 32688, Côte d’Ivoire
# Pagination: count=0, offset=0, limit=0
# Processing 531 series for category 32689, Croatia
# Pagination: count=0, offset=0, limit=0
# Processing 123 series for category 32690, Cuba
# Pagination: count=0, offset=0, limit=0
# Processing 224 series for category 32691, Curaçao
# Pagination: count=0, offset=0, limit=0
# Processing 447 series for category 32692, Cyprus
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32288, Czech Republic
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32271, Denmark
# Pagination: count=0, offset=0, limit=0
# Processing 187 series for category 32693, Djibouti
# Pagination: count=0, offset=0, limit=0
# Processing 172 series for category 32694, Dominica
# Pagination: count=0, offset=0, limit=0
# Processing 313 series for category 32695, Dominican Republic
# Pagination: count=0, offset=0, limit=0
# Processing 298 series for category 32696, Ecuador
# Pagination: count=0, offset=0, limit=0
# Processing 269 series for category 32697, Egypt
# Pagination: count=0, offset=0, limit=0
# Processing 265 series for category 32698, El Salvador
# Pagination: count=0, offset=0, limit=0
# Processing 198 series for category 32699, Equatorial Guinea
# Pagination: count=0, offset=0, limit=0
# Processing 132 series for category 32700, Eritrea
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32701, Estonia
# Pagination: count=0, offset=0, limit=0
# Processing 214 series for category 32702, Ethiopia
# Pagination: count=0, offset=0, limit=0
# Processing 39 series for category 32703, Falkland Islands
# Pagination: count=0, offset=0, limit=0
# Processing 69 series for category 32704, Faroe Islands
# Pagination: count=0, offset=0, limit=0
# Processing 243 series for category 32705, Fiji
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32289, Finland
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32272, France
# Pagination: count=0, offset=0, limit=0
# Processing 71 series for category 32706, French Guiana
# Pagination: count=0, offset=0, limit=0
# Processing 127 series for category 32707, French Polynesia
# Pagination: count=0, offset=0, limit=0
# Processing 38 series for category 32708, French Southern Territories
# Pagination: count=0, offset=0, limit=0
# Processing 249 series for category 32709, Gabon
# Pagination: count=0, offset=0, limit=0
# Processing 205 series for category 32710, Republic of the Gambia
# Pagination: count=0, offset=0, limit=0
# Processing 317 series for category 32711, Georgia
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32273, Germany
# Pagination: count=0, offset=0, limit=0
# Processing 277 series for category 32712, Ghana
# Pagination: count=0, offset=0, limit=0
# Processing 110 series for category 32713, Gibraltar
# Pagination: count=0, offset=0, limit=0
# Processing 59 series for category 32293, Great Britain
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32330, Greece
# Pagination: count=0, offset=0, limit=0
# Processing 82 series for category 32714, Greenland
# Pagination: count=0, offset=0, limit=0
# Processing 210 series for category 32715, Grenada
# Pagination: count=0, offset=0, limit=0
# Processing 95 series for category 32716, Guadeloupe
# Pagination: count=0, offset=0, limit=0
# Processing 9 series for category 32717, Guam
# Pagination: count=0, offset=0, limit=0
# Processing 257 series for category 32718, Guatemala
# Pagination: count=0, offset=0, limit=0
# Processing 337 series for category 32720, Guinea
# Pagination: count=0, offset=0, limit=0
# Processing 150 series for category 32721, Guinea-Bissau
# Pagination: count=0, offset=0, limit=0
# Processing 235 series for category 32722, Guyana
# Pagination: count=0, offset=0, limit=0
# Processing 214 series for category 32723, Haiti
# Pagination: count=0, offset=0, limit=0
# Processing 29 series for category 32724, Heard Island and McDonald Islands
# Pagination: count=0, offset=0, limit=0
# Processing 56 series for category 32725, Holy See (Vatican City State)
# Pagination: count=0, offset=0, limit=0
# Processing 237 series for category 32726, Honduras
# Pagination: count=0, offset=0, limit=0
# Processing 297 series for category 32727, Hong Kong
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32331, Hungary
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32334, Iceland
# Pagination: count=0, offset=0, limit=0
# Processing 919 series for category 32333, India
# Pagination: count=0, offset=0, limit=0
# Processing 906 series for category 32332, Indonesia
# Pagination: count=0, offset=0, limit=0
# Processing 228 series for category 32728, Iran, Islamic Republic of
# Pagination: count=0, offset=0, limit=0
# Processing 231 series for category 32729, Iraq
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32290, Ireland
# Pagination: count=0, offset=0, limit=0
# Processing 9 series for category 32730, Isle of Man
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32335, Israel
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32274, Italy
# Pagination: count=0, offset=0, limit=0
# Processing 258 series for category 32731, Jamaica
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32281, Japan
# Pagination: count=0, offset=0, limit=0
# Processing 265 series for category 32733, Jordan
# Pagination: count=0, offset=0, limit=0
# Processing 290 series for category 32734, Kazakhstan
# Pagination: count=0, offset=0, limit=0
# Processing 278 series for category 32735, Kenya
# Pagination: count=0, offset=0, limit=0
# Processing 164 series for category 32736, Kiribati
# Pagination: count=0, offset=0, limit=0
# Processing 44 series for category 32737, Korea, Democratic People's Republic of (North Korea)
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32286, Korea, Republic of (South Korea)
# Pagination: count=0, offset=0, limit=0
# Processing 256 series for category 32738, Kuwait
# Pagination: count=0, offset=0, limit=0
# Processing 210 series for category 32739, Kyrgyz Republic
# Pagination: count=0, offset=0, limit=0
# Processing 190 series for category 32740, Lao People's Democratic Republic
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32741, Latvia
# Pagination: count=0, offset=0, limit=0
# Processing 287 series for category 32742, Lebanon
# Pagination: count=0, offset=0, limit=0
# Processing 195 series for category 32743, Lesotho
# Pagination: count=0, offset=0, limit=0
# Processing 246 series for category 32744, Liberia
# Pagination: count=0, offset=0, limit=0
# Processing 225 series for category 32745, Libyan Arab Jamahiriya
# Pagination: count=0, offset=0, limit=0
# Processing 131 series for category 32746, Liechtenstein
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32747, Lithuania
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32336, Luxembourg
# Pagination: count=0, offset=0, limit=0
# Processing 213 series for category 32748, Macao
# Pagination: count=0, offset=0, limit=0
# Processing 328 series for category 32749, Macedonia, Former Yugoslav Republic of
# Pagination: count=0, offset=0, limit=0
# Processing 307 series for category 32750, Madagascar
# Pagination: count=0, offset=0, limit=0
# Processing 270 series for category 32751, Malawi
# Pagination: count=0, offset=0, limit=0
# Processing 368 series for category 32752, Malaysia
# Pagination: count=0, offset=0, limit=0
# Processing 213 series for category 32753, Maldives
# Pagination: count=0, offset=0, limit=0
# Processing 206 series for category 32754, Mali
# Pagination: count=0, offset=0, limit=0
# Processing 422 series for category 32755, Malta
# Pagination: count=0, offset=0, limit=0
# Processing 113 series for category 32756, Marshall Islands
# Pagination: count=0, offset=0, limit=0
# Processing 87 series for category 32757, Martinique
# Pagination: count=0, offset=0, limit=0
# Processing 193 series for category 32758, Mauritania
# Pagination: count=0, offset=0, limit=0
# Processing 291 series for category 32759, Mauritius
# Pagination: count=0, offset=0, limit=0
# Processing 69 series for category 32760, Mayotte
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32337, Mexico
# Pagination: count=0, offset=0, limit=0
# Processing 157 series for category 32761, Micronesia, Federated States of
# Pagination: count=0, offset=0, limit=0
# Processing 244 series for category 32762, Moldova, Republic of
# Pagination: count=0, offset=0, limit=0
# Processing 100 series for category 32763, Monaco
# Pagination: count=0, offset=0, limit=0
# Processing 196 series for category 32764, Mongolia
# Pagination: count=0, offset=0, limit=0
# Processing 350 series for category 32765, Montenegro
# Pagination: count=0, offset=0, limit=0
# Processing 80 series for category 32766, Montserrat
# Pagination: count=0, offset=0, limit=0
# Processing 292 series for category 32767, Morocco
# Pagination: count=0, offset=0, limit=0
# Processing 245 series for category 32768, Mozambique
# Pagination: count=0, offset=0, limit=0
# Processing 290 series for category 32769, Myanmar
# Pagination: count=0, offset=0, limit=0
# Processing 284 series for category 32770, Namibia
# Pagination: count=0, offset=0, limit=0
# Processing 65 series for category 32771, Nauru
# Pagination: count=0, offset=0, limit=0
# Processing 222 series for category 32772, Nepal
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32275, Netherlands
# Pagination: count=0, offset=0, limit=0
# Processing 108 series for category 32773, New Caledonia
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32338, New Zealand
# Pagination: count=0, offset=0, limit=0
# Processing 250 series for category 32774, Nicaragua
# Pagination: count=0, offset=0, limit=0
# Processing 204 series for category 32775, Niger
# Pagination: count=0, offset=0, limit=0
# Processing 288 series for category 32776, Nigeria
# Pagination: count=0, offset=0, limit=0
# Processing 37 series for category 32777, Niue
# Pagination: count=0, offset=0, limit=0
# Processing 41 series for category 32778, Norfolk Island
# Pagination: count=0, offset=0, limit=0
# Processing 4 series for category 32779, Northern Mariana Islands
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32276, Norway
# Pagination: count=0, offset=0, limit=0
# Processing 255 series for category 32780, Oman
# Pagination: count=0, offset=0, limit=0
# Processing 329 series for category 32781, Pakistan
# Pagination: count=0, offset=0, limit=0
# Processing 116 series for category 32782, Palau
# Pagination: count=0, offset=0, limit=0
# Processing 212 series for category 32783, Palestinian Territories
# Pagination: count=0, offset=0, limit=0
# Processing 251 series for category 32784, Panama
# Pagination: count=0, offset=0, limit=0
# Processing 240 series for category 32785, Papua New Guinea
# Pagination: count=0, offset=0, limit=0
# Processing 250 series for category 32786, Paraguay
# Pagination: count=0, offset=0, limit=0
# Processing 406 series for category 32787, Peru
# Pagination: count=0, offset=0, limit=0
# Processing 332 series for category 32788, Philippines
# Pagination: count=0, offset=0, limit=0
# Processing 38 series for category 32789, Pitcairn
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32339, Poland
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32340, Portugal
# Pagination: count=0, offset=0, limit=0
# Processing 427 series for category 32790, Puerto Rico
# Pagination: count=0, offset=0, limit=0
# Processing 285 series for category 32791, Qatar
# Pagination: count=0, offset=0, limit=0
# Processing 78 series for category 32792, Reunion
# Pagination: count=0, offset=0, limit=0
# Processing 456 series for category 32793, Romania
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32341, Russian Federation
# Pagination: count=0, offset=0, limit=0
# Processing 301 series for category 32794, Rwanda
# Pagination: count=0, offset=0, limit=0
# Processing 54 series for category 32796, Saint Helena, Ascension and Tristan da Cunha
# Pagination: count=0, offset=0, limit=0
# Processing 206 series for category 32797, Saint Kitts and Nevis
# Pagination: count=0, offset=0, limit=0
# Processing 168 series for category 32798, Saint Lucia
# Pagination: count=0, offset=0, limit=0
# Processing 4 series for category 32799, Saint Martin, Collectivity of
# Pagination: count=0, offset=0, limit=0
# Processing 31 series for category 32800, Saint Pierre and Miquelon
# Pagination: count=0, offset=0, limit=0
# Processing 163 series for category 32801, Saint Vincent and the Grenadines
# Pagination: count=0, offset=0, limit=0
# Processing 283 series for category 32802, Samoa
# Pagination: count=0, offset=0, limit=0
# Processing 147 series for category 32803, San Marino
# Pagination: count=0, offset=0, limit=0
# Processing 166 series for category 32804, Sao Tome and Principe
# Pagination: count=0, offset=0, limit=0
# Processing 447 series for category 32805, Saudi Arabia
# Pagination: count=0, offset=0, limit=0
# Processing 245 series for category 32806, Senegal
# Pagination: count=0, offset=0, limit=0
# Processing 438 series for category 32807, Serbia
# Pagination: count=0, offset=0, limit=0
# Processing 240 series for category 32808, Seychelles
# Pagination: count=0, offset=0, limit=0
# Processing 213 series for category 32809, Sierra Leone
# Pagination: count=0, offset=0, limit=0
# Processing 331 series for category 32287, Singapore
# Pagination: count=0, offset=0, limit=0
# Processing 211 series for category 32810, Sint Maarten (Dutch part)
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32342, Slovak Republic
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32343, Slovenia
# Pagination: count=0, offset=0, limit=0
# Processing 167 series for category 32811, Solomon Islands
# Pagination: count=0, offset=0, limit=0
# Processing 81 series for category 32812, Somalia
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32345, South Africa
# Pagination: count=0, offset=0, limit=0
# Processing 140 series for category 32814, South Sudan
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32277, Spain
# Pagination: count=0, offset=0, limit=0
# Processing 241 series for category 32815, Sri Lanka
# Pagination: count=0, offset=0, limit=0
# Processing 254 series for category 32816, Sudan
# Pagination: count=0, offset=0, limit=0
# Processing 271 series for category 32817, Suriname
# Pagination: count=0, offset=0, limit=0
# Processing 42 series for category 32818, Svalbard and Jan Mayen
# Pagination: count=0, offset=0, limit=0
# Processing 218 series for category 32819, Swaziland
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32278, Sweden
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32279, Switzerland
# Pagination: count=0, offset=0, limit=0
# Processing 203 series for category 32820, Syrian Arab Republic
# Pagination: count=0, offset=0, limit=0
# Processing 203 series for category 32438, Taiwan
# Pagination: count=0, offset=0, limit=0
# Processing 217 series for category 32821, Tajikistan
# Pagination: count=0, offset=0, limit=0
# Processing 234 series for category 32822, Tanzania, United Republic of
# Pagination: count=0, offset=0, limit=0
# Processing 376 series for category 32823, Thailand
# Pagination: count=0, offset=0, limit=0
# Processing 140 series for category 32824, Timor-Leste
# Pagination: count=0, offset=0, limit=0
# Processing 225 series for category 32825, Togo
# Pagination: count=0, offset=0, limit=0
# Processing 83 series for category 32826, Tokelau
# Pagination: count=0, offset=0, limit=0
# Processing 161 series for category 32827, Tonga
# Pagination: count=0, offset=0, limit=0
# Processing 253 series for category 32828, Trinidad and Tobago
# Pagination: count=0, offset=0, limit=0
# Processing 264 series for category 32829, Tunisia
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32344, Turkey
# Pagination: count=0, offset=0, limit=0
# Processing 142 series for category 32830, Turkmenistan
# Pagination: count=0, offset=0, limit=0
# Processing 106 series for category 32831, Turks and Caicos Islands
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 32832, Tuvalu
# Pagination: count=0, offset=0, limit=0
# Processing 283 series for category 32833, Uganda
# Pagination: count=0, offset=0, limit=0
# Processing 383 series for category 32834, Ukraine
# Pagination: count=0, offset=0, limit=0
# Processing 272 series for category 32835, United Arab Emirates
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32280, United Kingdom
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32267, United States
# Pagination: count=0, offset=0, limit=0
# Processing 263 series for category 32837, Uruguay
# Pagination: count=0, offset=0, limit=0
# Processing 183 series for category 32838, Uzbekistan
# Pagination: count=0, offset=0, limit=0
# Processing 164 series for category 32839, Vanuatu
# Pagination: count=0, offset=0, limit=0
# Processing 288 series for category 32840, Venezuela, Bolivarian Republic of
# Pagination: count=0, offset=0, limit=0
# Processing 248 series for category 32841, Viet Nam
# Pagination: count=0, offset=0, limit=0
# Processing 106 series for category 32842, Virgin Islands, British
# Pagination: count=0, offset=0, limit=0
# Processing 158 series for category 32843, Virgin Islands, U.S.
# Pagination: count=0, offset=0, limit=0
# Processing 31 series for category 32844, Wallis and Futuna
# Pagination: count=0, offset=0, limit=0
# Processing 14 series for category 32845, Western Sahara
# Pagination: count=0, offset=0, limit=0
# Processing 201 series for category 32846, Yemen, Republic of
# Pagination: count=0, offset=0, limit=0
# Processing 239 series for category 32946, Kosovo
# Pagination: count=0, offset=0, limit=0
# Processing 314 series for category 32847, Zambia
# Pagination: count=0, offset=0, limit=0
# Processing 305 series for category 32848, Zimbabwe
# Pagination: count=0, offset=0, limit=0
# Wrote series data for 243 categories to /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/series_data/fred_international_countries_32264.yaml

# %% [markdown]
# ## fred_national_accounts_32992.yaml

# %%
filename = "fred_national_accounts_32992.yaml"
input_path = str(Path(f"../categories/category_data/{filename}").absolute())
output_path = str(Path(f"series_data/{filename}").absolute())
await export_finance_category_series(input_path, output_path)
# Out:
# Reading categories from /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/../categories/category_data/fred_national_accounts_32992.yaml
# Writing series to /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/series_data/fred_national_accounts_32992.yaml
# Loaded 83 categories
# Processing 41 series for category 5, Federal Government Debt
# Pagination: count=0, offset=0, limit=0
# Processing 43 series for category 33122, Gross Domestic Income
# Pagination: count=0, offset=0, limit=0
# Processing 165 series for category 33719, Health Care Spending
# Pagination: count=0, offset=0, limit=0
# Processing 104 series for category 33054, Imputations
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 21, Price Indexes & Deflators
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33021, Quantity Indexes
# Pagination: count=0, offset=0, limit=0
# Processing 33 series for category 33401, Effect of ARRA on Selected NIPA Estimates
# Pagination: count=0, offset=0, limit=0
# Processing 61 series for category 32258, B.101 Balance Sheet of Households and Nonprofit Organizations
# Pagination: count=0, offset=0, limit=0
# Processing 55 series for category 32259, B.103 Balance Sheet of Nonfinancial Corporate Business
# Pagination: count=0, offset=0, limit=0
# Processing 48 series for category 32260, B.104 Balance Sheet of Nonfinancial Noncorporate Business
# Pagination: count=0, offset=0, limit=0
# Processing 14 series for category 32256, D.3 Credit Market Debt Outstanding by Sector
# Pagination: count=0, offset=0, limit=0
# Processing 53 series for category 32257, L.1 Credit Market Debt Outstanding
# Pagination: count=0, offset=0, limit=0
# Processing 39 series for category 33722, L.203 Net Interbank Transactions
# Pagination: count=0, offset=0, limit=0
# Processing 52 series for category 33726, L.208 Debt Securities
# Pagination: count=0, offset=0, limit=0
# Processing 52 series for category 33729, L.214 Loans
# Pagination: count=0, offset=0, limit=0
# Processing 73 series for category 33204, S.1 Total Economy - Current Account
# Pagination: count=0, offset=0, limit=0
# Processing 156 series for category 33205, S.2 Selected Aggregates for Total Economy and Sectors
# Pagination: count=0, offset=0, limit=0
# Processing 275 series for category 33240, S.3 Households and Nonprofit Institutions Serving Households
# Pagination: count=0, offset=0, limit=0
# Processing 207 series for category 33241, S.4 Nonfinancial Noncorporate Business
# Pagination: count=0, offset=0, limit=0
# Processing 266 series for category 33242, S.5 Nonfinancial Corporate Business
# Pagination: count=0, offset=0, limit=0
# Processing 270 series for category 33243, S.6 Financial Business
# Pagination: count=0, offset=0, limit=0
# Processing 266 series for category 33244, S.7 Federal Government
# Pagination: count=0, offset=0, limit=0
# Processing 192 series for category 33245, S.8 State and Local Governments
# Pagination: count=0, offset=0, limit=0
# Processing 280 series for category 33246, S.9 Rest of the World
# Pagination: count=0, offset=0, limit=0
# Processing 149 series for category 16, Exports
# Pagination: count=0, offset=0, limit=0
# Processing 165 series for category 17, Imports
# Pagination: count=0, offset=0, limit=0
# Processing 72 series for category 3000, Income Payments & Receipts
# Pagination: count=0, offset=0, limit=0
# Processing 32 series for category 33705, International Investment Position
# Pagination: count=0, offset=0, limit=0
# Processing 47 series for category 125, Trade Balance
# Pagination: count=0, offset=0, limit=0
# Processing 211 series for category 127, U.S. International Finance
# Pagination: count=0, offset=0, limit=0
# Processing 60 series for category 33042, Capital Transfers Paid
# Pagination: count=0, offset=0, limit=0
# Processing 45 series for category 33043, Capital Transfers Received
# Pagination: count=0, offset=0, limit=0
# Processing 98 series for category 33040, Consumptions of Fixed Capital
# Pagination: count=0, offset=0, limit=0
# Processing 156 series for category 33041, Corporate Capital Consumption
# Pagination: count=0, offset=0, limit=0
# Processing 134 series for category 33037, Domestic Investments
# Pagination: count=0, offset=0, limit=0
# Processing 343 series for category 33038, Inventories
# Pagination: count=0, offset=0, limit=0
# Processing 78 series for category 33044, Noncorporate Business
# Pagination: count=0, offset=0, limit=0
# Processing 507 series for category 33039, Private Fixed Investments
# Pagination: count=0, offset=0, limit=0
# Processing 327 series for category 33018, Exports
# Pagination: count=0, offset=0, limit=0
# Processing 323 series for category 33019, Imports
# Pagination: count=0, offset=0, limit=0
# Processing 22 series for category 33699, Net Stocks
# Pagination: count=0, offset=0, limit=0
# Processing 22 series for category 33701, Depreciation
# Pagination: count=0, offset=0, limit=0
# Processing 278 series for category 33703, Fixed Investment
# Pagination: count=0, offset=0, limit=0
# Processing 75 series for category 33020, Shares of GDP
# Pagination: count=0, offset=0, limit=0
# Processing 584 series for category 33022, Gov't Consumption Expenditures
# Pagination: count=0, offset=0, limit=0
# Processing 284 series for category 33024, Gov't Current Expenditures
# Pagination: count=0, offset=0, limit=0
# Processing 43 series for category 33025, Gov't Current Transfer Receipts
# Pagination: count=0, offset=0, limit=0
# Processing 141 series for category 33027, Gov't Fixed Investment
# Pagination: count=0, offset=0, limit=0
# Processing 228 series for category 33023, Gov't Investment
# Pagination: count=0, offset=0, limit=0
# Processing 137 series for category 33026, Gov't Social Benefits
# Pagination: count=0, offset=0, limit=0
# Processing 21 series for category 33883, Administrative and Waste Management Services
# Pagination: count=0, offset=0, limit=0
# Processing 21 series for category 33859, Agriculture, Forestry, Fishing, and Hunting
# Pagination: count=0, offset=0, limit=0
# Processing 48 series for category 33887, Arts, Entertainment, Recreation, Accommodation, and Food Services
# Pagination: count=0, offset=0, limit=0
# Processing 96 series for category 33046, Auto Output
# Pagination: count=0, offset=0, limit=0
# Processing 9 series for category 33865, Construction
# Pagination: count=0, offset=0, limit=0
# Processing 42 series for category 33885, Educational Services, Health Care, and Social Assistance
# Pagination: count=0, offset=0, limit=0
# Processing 55 series for category 33047, Farm Output
# Pagination: count=0, offset=0, limit=0
# Processing 60 series for category 33877, Finance, Insurance, Real Estate, Rental, and Leasing
# Pagination: count=0, offset=0, limit=0
# Processing 274 series for category 33050, Full-time Equivalent Employees
# Pagination: count=0, offset=0, limit=0
# Processing 323 series for category 33049, Full-time & Part-time Employees
# Pagination: count=0, offset=0, limit=0
# Processing 27 series for category 33889, Government
# Pagination: count=0, offset=0, limit=0
# Processing 83 series for category 33048, Households
# Pagination: count=0, offset=0, limit=0
# Processing 44 series for category 33053, Imputed Interest
# Pagination: count=0, offset=0, limit=0
# Processing 33 series for category 33875, Information
# Pagination: count=0, offset=0, limit=0
# Processing 9 series for category 33881, Management Of Companies and Enterprises
# Pagination: count=0, offset=0, limit=0
# Processing 141 series for category 33867, Manufacturing
# Pagination: count=0, offset=0, limit=0
# Processing 27 series for category 33861, Mining
# Pagination: count=0, offset=0, limit=0
# Processing 270 series for category 33052, Persons Engaged in Production
# Pagination: count=0, offset=0, limit=0
# Processing 24 series for category 33879, Professional and Business Services
# Pagination: count=0, offset=0, limit=0
# Processing 9 series for category 33871, Retail Trade
# Pagination: count=0, offset=0, limit=0
# Processing 50 series for category 33051, Self-employed Persons
# Pagination: count=0, offset=0, limit=0
# Processing 57 series for category 33873, Transportation and Warehousing
# Pagination: count=0, offset=0, limit=0
# Processing 9 series for category 33863, Utilities
# Pagination: count=0, offset=0, limit=0
# Processing 9 series for category 33869, Wholesale Trade
# Pagination: count=0, offset=0, limit=0
# Processing 306 series for category 33029, Compensation of Employees
# Pagination: count=0, offset=0, limit=0
# Processing 270 series for category 33031, Employer Contributions
# Pagination: count=0, offset=0, limit=0
# Processing 808 series for category 33028, Personal Consumption Expenditures
# Pagination: count=0, offset=0, limit=0
# Processing 28 series for category 33032, Personal Current Taxes
# Pagination: count=0, offset=0, limit=0
# Processing 567 series for category 33030, Wage and Salary Accruals
# Pagination: count=0, offset=0, limit=0
# Processing 174 series for category 33035, Corporate Dividends
# Pagination: count=0, offset=0, limit=0
# Processing 728 series for category 33033, Corporate Profits
# Pagination: count=0, offset=0, limit=0
# Processing 140 series for category 33036, Proprietorship
# Pagination: count=0, offset=0, limit=0
# Processing 179 series for category 33034, Taxes on Corporate Income
# Pagination: count=0, offset=0, limit=0
# Wrote series data for 83 categories to /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/series_data/fred_national_accounts_32992.yaml

# %% [markdown]
# ## fred_international_indicators_32265.yaml

# %%
filename = "fred_international_indicators_32265.yaml"
input_path = str(Path(f"../categories/category_data/{filename}").absolute())
output_path = str(Path(f"series_data/{filename}").absolute())
await export_finance_category_series(input_path, output_path)
# Out:
# Reading categories from /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/../categories/category_data/fred_international_indicators_32265.yaml
# Writing series to /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/series_data/fred_international_indicators_32265.yaml
# Loaded 100 categories
# Processing 1 series for category 33247, Consumer Price Index
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33195, Business Lending
# Pagination: count=0, offset=0, limit=0
# Processing 352 series for category 33191, Financial Institutions
# Pagination: count=0, offset=0, limit=0
# Processing 24 series for category 32954, Financial Stress Indicators
# Pagination: count=0, offset=0, limit=0
# Processing 553 series for category 32949, Interest Rates
# Pagination: count=0, offset=0, limit=0
# Processing 51 series for category 32952, Reserves & Monetary Base
# Pagination: count=0, offset=0, limit=0
# Processing 679 series for category 33210, Exchange Rate
# Pagination: count=0, offset=0, limit=0
# Processing 130 series for category 32951, Balance of Payments
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32291, GDP
# Pagination: count=0, offset=0, limit=0
# Processing 480 series for category 33196, GNP
# Pagination: count=0, offset=0, limit=0
# Processing 361 series for category 33097, International Trade and Transactions
# Pagination: count=0, offset=0, limit=0
# Processing 584 series for category 32458, Government Debt
# Pagination: count=0, offset=0, limit=0
# Processing 691 series for category 33526, Education
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32283, Employment
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33218, Employment Population Ratio
# Pagination: count=0, offset=0, limit=0
# Processing 158 series for category 33525, Income Distribution
# Pagination: count=0, offset=0, limit=0
# Processing 126 series for category 33215, Job Openings and Labor Turnover
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32285, Labor Force
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33217, Labor Force Participation Rate
# Pagination: count=0, offset=0, limit=0
# Processing 637 series for category 33213, Labor Compensation
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33212, Productivity & Costs
# Pagination: count=0, offset=0, limit=0
# Processing 422 series for category 32284, Unemployment
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33214, Unemployment Level
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33219, Unemployment Rate
# Pagination: count=0, offset=0, limit=0
# Processing 31 series for category 33829, Migration
# Pagination: count=0, offset=0, limit=0
# Processing 240 series for category 33527, Cell Phone Usage
# Pagination: count=0, offset=0, limit=0
# Processing 298 series for category 33092, Construction
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33090, Industrial Production & Capacity Utilization
# Pagination: count=0, offset=0, limit=0
# Processing 472 series for category 33192, Insurance
# Pagination: count=0, offset=0, limit=0
# Processing 481 series for category 33499, Internet Users
# Pagination: count=0, offset=0, limit=0
# Processing 5 series for category 32953, Real Estate
# Pagination: count=0, offset=0, limit=0
# Processing 678 series for category 33088, Retail Sales
# Pagination: count=0, offset=0, limit=0
# Processing 445 series for category 33209, Business Tendency Surveys
# Pagination: count=0, offset=0, limit=0
# Processing 132 series for category 33222, Housing
# Pagination: count=0, offset=0, limit=0
# Processing 32 series for category 33229, Wholesale
# Pagination: count=0, offset=0, limit=0
# Processing 30 series for category 33827, Ease of Doing Business
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 32427, Producer Price Indexes
# Pagination: count=0, offset=0, limit=0
# Processing 248 series for category 33129, Trade Indexes
# Pagination: count=0, offset=0, limit=0
# Processing 18 series for category 33226, Wholesale
# Pagination: count=0, offset=0, limit=0
# Processing 224 series for category 33503, House Prices
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33186, Condition of Banks
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33187, Bond Market Data
# Pagination: count=0, offset=0, limit=0
# Processing 83 series for category 33211, Financial Activity Measures
# Pagination: count=0, offset=0, limit=0
# Processing 824 series for category 33497, Money Market Instruments
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33194, Stock Market Data
# Pagination: count=0, offset=0, limit=0
# Processing 233 series for category 33220, M3 and Components
# Pagination: count=0, offset=0, limit=0
# Processing 243 series for category 33221, M1 and Components
# Pagination: count=0, offset=0, limit=0
# Processing 185 series for category 33223, Reserves
# Pagination: count=0, offset=0, limit=0
# Processing 90 series for category 33227, M2 and Components
# Pagination: count=0, offset=0, limit=0
# Processing 6 series for category 33234, Monetary Base
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33207, Trade Balance
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33208, International Finance
# Pagination: count=0, offset=0, limit=0
# Processing 734 series for category 33224, Exports
# Pagination: count=0, offset=0, limit=0
# Processing 733 series for category 33225, Imports
# Pagination: count=0, offset=0, limit=0
# Processing 3 series for category 33233, Govt Receipts, Expenditures & Investment
# Pagination: count=0, offset=0, limit=0
# Processing 3 series for category 33237, Price Indexes & Deflators
# Pagination: count=0, offset=0, limit=0
# Processing 6 series for category 33238, Personal Income & Outlays
# Pagination: count=0, offset=0, limit=0
# Processing 243 series for category 33739, Birth Rate
# Pagination: count=0, offset=0, limit=0
# Processing 466 series for category 33512, Fertility Rate
# Pagination: count=0, offset=0, limit=0
# Processing 224 series for category 33510, Infant Mortality
# Pagination: count=0, offset=0, limit=0
# Processing 240 series for category 33513, Life Expectancy
# Pagination: count=0, offset=0, limit=0
# Processing 190 series for category 33511, Literacy Rate
# Pagination: count=0, offset=0, limit=0
# Processing 462 series for category 33498, Migration
# Pagination: count=0, offset=0, limit=0
# Processing 36 series for category 33228, Inventories
# Pagination: count=0, offset=0, limit=0
# Processing 247 series for category 33006, Alcoholic Beverages and Tobacco
# Pagination: count=0, offset=0, limit=0
# Processing 873 series for category 33004, All Items
# Pagination: count=0, offset=0, limit=0
# Processing 287 series for category 33007, Clothing and Footwear
# Pagination: count=0, offset=0, limit=0
# Processing 164 series for category 33012, Communications
# Pagination: count=0, offset=0, limit=0
# Processing 42 series for category 33014, Education
# Pagination: count=0, offset=0, limit=0
# Processing 832 series for category 33005, Food and Non-Alcoholic Beverages
# Pagination: count=0, offset=0, limit=0
# Processing 327 series for category 33010, Health
# Pagination: count=0, offset=0, limit=0
# Processing 563 series for category 33009, Household Equipment
# Pagination: count=0, offset=0, limit=0
# Processing 691 series for category 33008, Housing
# Pagination: count=0, offset=0, limit=0
# Processing 205 series for category 33015, Hotels and Restaurants
# Pagination: count=0, offset=0, limit=0
# Processing 637 series for category 33016, Miscellaneous Goods and Services
# Pagination: count=0, offset=0, limit=0
# Processing 918 series for category 33013, Recreation and Culture
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33017, Special Indexes
# Pagination: count=0, offset=0, limit=0
# Processing 637 series for category 33011, Transport
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33494, Financial Sector
# Pagination: count=0, offset=0, limit=0
# Processing 833 series for category 33496, Government
# Pagination: count=0, offset=0, limit=0
# Processing 749 series for category 33495, Non-Financial Corporations
# Pagination: count=0, offset=0, limit=0
# Processing 28 series for category 33398, EC Indicator
# Pagination: count=0, offset=0, limit=0
# Processing 29 series for category 33399, EC and National Indicators
# Pagination: count=0, offset=0, limit=0
# Processing 27 series for category 33382, EC and National Indicators
# Pagination: count=0, offset=0, limit=0
# Processing 25 series for category 33384, EC Indicator
# Pagination: count=0, offset=0, limit=0
# Processing 30 series for category 33383, EC and National Indicators
# Pagination: count=0, offset=0, limit=0
# Processing 26 series for category 33385, EC Indicator
# Pagination: count=0, offset=0, limit=0
# Processing 28 series for category 33381, EC Indicator
# Pagination: count=0, offset=0, limit=0
# Processing 21 series for category 33396, EC and National Indicators
# Pagination: count=0, offset=0, limit=0
# Processing 39 series for category 33393, EC and National Indicators
# Pagination: count=0, offset=0, limit=0
# Processing 36 series for category 33394, EC and National Indicators
# Pagination: count=0, offset=0, limit=0
# Processing 35 series for category 33395, EC and National Indicators
# Pagination: count=0, offset=0, limit=0
# Processing 10 series for category 33392, National Indicator
# Pagination: count=0, offset=0, limit=0
# Processing 4 series for category 33390, EC and National Indicators
# Pagination: count=0, offset=0, limit=0
# Processing 3 series for category 33387, EC Indicator
# Pagination: count=0, offset=0, limit=0
# Processing 5 series for category 33388, EC Indicator
# Pagination: count=0, offset=0, limit=0
# Processing 3 series for category 33391, EC Indicator
# Pagination: count=0, offset=0, limit=0
# Processing 2 series for category 33389, EC and National Indicators
# Pagination: count=0, offset=0, limit=0
# Processing 1 series for category 33386, National Indicator
# Pagination: count=0, offset=0, limit=0
# Processing 2 series for category 33260, Total
# Pagination: count=0, offset=0, limit=0
# Wrote series data for 100 categories to /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/series_data/fred_international_indicators_32265.yaml

# %% [markdown]
# ## fred_academic_data_33060.yaml

# %%
filename = "fred_academic_data_33060.yaml"
input_path = str(Path(f"../categories/category_data/{filename}").absolute())
output_path = str(Path(f"series_data/{filename}").absolute())
await export_finance_category_series(input_path, output_path)
# Out:
# Reading categories from /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/../categories/category_data/fred_academic_data_33060.yaml
# Writing series to /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/series_data/fred_academic_data_33060.yaml
# Loaded 59 categories
# Processing 4 series for category 33951, Daily Federal Funds Rate, 1928-54
# Pagination: count=0, offset=0, limit=0
# Processing 40 series for category 33825, Data on the nominal term structure model from Kim and Wright
# Pagination: count=0, offset=0, limit=0
# Processing 124 series for category 33891, Historical Federal Reserve Data
# Pagination: count=0, offset=0, limit=0
# Processing 7 series for category 33120, Recession Probabilities
# Pagination: count=0, offset=0, limit=0
# Processing 1 series for category 33123, Weekly U.S. and State Bond Prices, 1855-1865
# Pagination: count=0, offset=0, limit=0
# Processing 677 series for category 33201, Economic Policy Uncertainty
# Pagination: count=0, offset=0, limit=0
# Processing 9 series for category 33442, Sticky Wages and Comovement
# Pagination: count=0, offset=0, limit=0
# Processing 26 series for category 33934, New England Textile Industry, 1815-1860
# Pagination: count=0, offset=0, limit=0
# Processing 20 series for category 34000, The Effects of the 1930s HOLC "Redlining" Maps
# Pagination: count=0, offset=0, limit=0
# Processing 20 series for category 34309, U.S. Survey of Working Arrangements and Attitudes
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33835, Section 1. General Statistics of All Banks in the United States
# Pagination: count=0, offset=0, limit=0
# Processing 495 series for category 33837, Section 2. Assets and Liabilities of All Member Banks
# Pagination: count=0, offset=0, limit=0
# Processing 454 series for category 33062, Production of Commodities
# Pagination: count=0, offset=0, limit=0
# Processing 385 series for category 33063, Construction
# Pagination: count=0, offset=0, limit=0
# Processing 172 series for category 33064, Transportation and Public Utilities
# Pagination: count=0, offset=0, limit=0
# Processing 335 series for category 33065, Prices
# Pagination: count=0, offset=0, limit=0
# Processing 192 series for category 33066, Stocks of Commodities
# Pagination: count=0, offset=0, limit=0
# Processing 164 series for category 33067, Distribution of Commodities
# Pagination: count=0, offset=0, limit=0
# Processing 77 series for category 33068, Foreign Trade
# Pagination: count=0, offset=0, limit=0
# Processing 488 series for category 33069, Income and Employment
# Pagination: count=0, offset=0, limit=0
# Processing 142 series for category 33070, Financial Status of Business
# Pagination: count=0, offset=0, limit=0
# Processing 165 series for category 33071, Savings and Investment
# Pagination: count=0, offset=0, limit=0
# Processing 31 series for category 33072, Security Markets
# Pagination: count=0, offset=0, limit=0
# Processing 59 series for category 33073, Volume of Transactions
# Pagination: count=0, offset=0, limit=0
# Processing 74 series for category 33074, Interest Rates
# Pagination: count=0, offset=0, limit=0
# Processing 180 series for category 33075, Money and Banking
# Pagination: count=0, offset=0, limit=0
# Processing 56 series for category 33076, Government and Finance
# Pagination: count=0, offset=0, limit=0
# Processing 62 series for category 33077, Leading Indicators
# Pagination: count=0, offset=0, limit=0
# Processing 570 series for category 33107, Component Shares of GDP per Capita (Constant Prices)
# Pagination: count=0, offset=0, limit=0
# Processing 570 series for category 33106, Component Shares of GDP per Capita (Current Prices)
# Pagination: count=0, offset=0, limit=0
# Processing 190 series for category 33102, Exchange Rates
# Pagination: count=0, offset=0, limit=0
# Processing 570 series for category 33110, GDP per Capita (Current Prices)
# Pagination: count=0, offset=0, limit=0
# Processing 190 series for category 33112, Gross Domestic Income, Adjustments for Changes in Terms of Trade
# Pagination: count=0, offset=0, limit=0
# Processing 380 series for category 33105, Openness
# Pagination: count=0, offset=0, limit=0
# Processing 190 series for category 33101, Population
# Pagination: count=0, offset=0, limit=0
# Processing 950 series for category 33104, Price Levels of GDP, Consumption, Government, and Investment
# Pagination: count=0, offset=0, limit=0
# Processing 190 series for category 33103, Purchasing Power Parity
# Pagination: count=0, offset=0, limit=0
# Processing 190 series for category 33118, Purchasing Power Parity Converted GDP
# Pagination: count=0, offset=0, limit=0
# Processing 190 series for category 33108, Ratio of GNP to GDP
# Pagination: count=0, offset=0, limit=0
# Processing 570 series for category 33111, Real GDP per Capita (Constant Prices)
# Pagination: count=0, offset=0, limit=0
# Processing 380 series for category 33109, Real GDP per Capita Relative to U.S.
# Pagination: count=0, offset=0, limit=0
# Processing 190 series for category 33113, Real GDP per Equivalent Adult
# Pagination: count=0, offset=0, limit=0
# Processing 52 series for category 33117, Real GDP per Hour Worked by Employees
# Pagination: count=0, offset=0, limit=0
# Processing 29 series for category 33115, Real GDP per Person Engaged
# Pagination: count=0, offset=0, limit=0
# Processing 121 series for category 33116, Real GDP per Person Counted in Total Employment
# Pagination: count=0, offset=0, limit=0
# Processing 368 series for category 33114, Real GDP per Worker
# Pagination: count=0, offset=0, limit=0
# Processing 874 series for category 33403, Real GDP, Employment and Population Levels
# Pagination: count=0, offset=0, limit=0
# Processing 616 series for category 33404, Current Price GDP, Capital and Total Factor Productivity
# Pagination: count=0, offset=0, limit=0
# Processing 579 series for category 33405, National Accounts-Based Variables
# Pagination: count=0, offset=0, limit=0
# Processing 501 series for category 33406, Exchange Rates and GDP Price Levels
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33407, Shares in Output-side Real GDP at Current Purchasing Power Parities
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33408, Price Levels, Expenditure Categories and Capital
# Pagination: count=0, offset=0, limit=0
# Processing 26 series for category 33845, National Accounts
# Pagination: count=0, offset=0, limit=0
# Processing 13 series for category 33843, Labour, Capital and Productivity
# Pagination: count=0, offset=0, limit=0
# Processing 16 series for category 33847, Wages and Prices
# Pagination: count=0, offset=0, limit=0
# Processing 38 series for category 33849, Financial Markets
# Pagination: count=0, offset=0, limit=0
# Processing 21 series for category 33851, Money and Credit
# Pagination: count=0, offset=0, limit=0
# Processing 8 series for category 33853, Fiscal
# Pagination: count=0, offset=0, limit=0
# Processing 6 series for category 33855, Trade
# Pagination: count=0, offset=0, limit=0
# Wrote series data for 59 categories to /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/series_data/fred_academic_data_33060.yaml

# %% [markdown]
# ## fred_regional_bls_regions_32849.yaml

# %%
filename = "fred_regional_bls_regions_32849.yaml"
input_path = str(Path(f"../categories/category_data/{filename}").absolute())
output_path = str(Path(f"series_data/{filename}").absolute())
await export_finance_category_series(input_path, output_path)
# Out:
# Reading categories from /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/../categories/category_data/fred_regional_bls_regions_32849.yaml
# Writing series to /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/series_data/fred_regional_bls_regions_32849.yaml
# Loaded 13 categories
# Processing 138 series for category 32860, Population Size Class A (over 1,500,000)
# Pagination: count=0, offset=0, limit=0
# Processing 138 series for category 32861, Population Size Class B/C (between 50,000 and 1,500,000)
# Pagination: count=0, offset=0, limit=0
# Processing 138 series for category 32862, Population Size Class D (under 50,000)
# Pagination: count=0, offset=0, limit=0
# Processing 100 series for category 32854, Population Size Class A (over 1,500,000)
# Pagination: count=0, offset=0, limit=0
# Processing 100 series for category 32855, Population Size Class B/C (between 50,000 and 1,500,000)
# Pagination: count=0, offset=0, limit=0
# Processing 100 series for category 32856, Population Size Class D (under 50,000)
# Pagination: count=0, offset=0, limit=0
# Processing 100 series for category 32857, Population Size Class A (over 1,500,000)
# Pagination: count=0, offset=0, limit=0
# Processing 100 series for category 32858, Population Size Class B/C (between 50,000 and 1,500,000)
# Pagination: count=0, offset=0, limit=0
# Processing 100 series for category 32863, Population Size Class A (over 1,500,000)
# Pagination: count=0, offset=0, limit=0
# Processing 100 series for category 32865, Population Size Class B/C (between 50,000 and 1,500,000)
# Pagination: count=0, offset=0, limit=0
# Processing 100 series for category 32867, Population Size Class D (under 50,000)
# Pagination: count=0, offset=0, limit=0
# Processing 100 series for category 32864, Population Size Class A (over 1,500,000)
# Pagination: count=0, offset=0, limit=0
# Processing 100 series for category 32866, Population Size Class B/C (between 50,000 and 1,500,000)
# Pagination: count=0, offset=0, limit=0
# Wrote series data for 13 categories to /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/series_data/fred_regional_bls_regions_32849.yaml

# %% [markdown]
# ## fred_international_finance_33000.yaml

# %%
filename = "fred_international_finance_33000.yaml"
input_path = str(Path(f"../categories/category_data/{filename}").absolute())
output_path = str(Path(f"series_data/{filename}").absolute())
await export_finance_category_series(input_path, output_path)
# Out:
# Reading categories from /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/../categories/category_data/fred_international_finance_33000.yaml
# Writing series to /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/series_data/fred_international_finance_33000.yaml
# Loaded 19 categories
# Processing 1000 series for category 33195, Business Lending
# Pagination: count=0, offset=0, limit=0
# Processing 352 series for category 33191, Financial Institutions
# Pagination: count=0, offset=0, limit=0
# Processing 24 series for category 32954, Financial Stress Indicators
# Pagination: count=0, offset=0, limit=0
# Processing 553 series for category 32949, Interest Rates
# Pagination: count=0, offset=0, limit=0
# Processing 51 series for category 32952, Reserves & Monetary Base
# Pagination: count=0, offset=0, limit=0
# Processing 679 series for category 33210, Exchange Rate
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33186, Condition of Banks
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33187, Bond Market Data
# Pagination: count=0, offset=0, limit=0
# Processing 83 series for category 33211, Financial Activity Measures
# Pagination: count=0, offset=0, limit=0
# Processing 824 series for category 33497, Money Market Instruments
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33194, Stock Market Data
# Pagination: count=0, offset=0, limit=0
# Processing 233 series for category 33220, M3 and Components
# Pagination: count=0, offset=0, limit=0
# Processing 243 series for category 33221, M1 and Components
# Pagination: count=0, offset=0, limit=0
# Processing 185 series for category 33223, Reserves
# Pagination: count=0, offset=0, limit=0
# Processing 90 series for category 33227, M2 and Components
# Pagination: count=0, offset=0, limit=0
# Processing 6 series for category 33234, Monetary Base
# Pagination: count=0, offset=0, limit=0
# Processing 1000 series for category 33494, Financial Sector
# Pagination: count=0, offset=0, limit=0
# Processing 833 series for category 33496, Government
# Pagination: count=0, offset=0, limit=0
# Processing 749 series for category 33495, Non-Financial Corporations
# Pagination: count=0, offset=0, limit=0
# Wrote series data for 19 categories to /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/series_data/fred_international_finance_33000.yaml

# %% [markdown]
# ## fred_international_geography_32955.yaml

# %%
filename = "fred_international_geography_32955.yaml"
input_path = str(Path(f"../categories/category_data/{filename}").absolute())
output_path = str(Path(f"series_data/{filename}").absolute())
await export_finance_category_series(input_path, output_path)
# Out:
# Reading categories from /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/../categories/category_data/fred_international_geography_32955.yaml
# Writing series to /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/series_data/fred_international_geography_32955.yaml
# Loaded 23 categories
# Processing 192 series for category 32459, World
# Pagination: count=0, offset=0, limit=0
# Processing 0 series for category 32968, Eastern Africa
# Pagination: count=0, offset=0, limit=0
# Processing 0 series for category 32969, Middle Africa
# Pagination: count=0, offset=0, limit=0
# Processing 0 series for category 32970, Northern Africa
# Pagination: count=0, offset=0, limit=0
# Processing 2 series for category 32971, Southern Africa
# Pagination: count=0, offset=0, limit=0
# Processing 0 series for category 32972, Western Africa
# Pagination: count=0, offset=0, limit=0
# Processing 2 series for category 32974, Northern America
# Pagination: count=0, offset=0, limit=0
# Processing 0 series for category 32975, Central Asia
# Pagination: count=0, offset=0, limit=0
# Processing 0 series for category 32976, Eastern Asia
# Pagination: count=0, offset=0, limit=0
# Processing 0 series for category 32977, Southern Asia
# Pagination: count=0, offset=0, limit=0
# Processing 0 series for category 32978, South-Eastern Asia
# Pagination: count=0, offset=0, limit=0
# Processing 0 series for category 32979, Western Asia
# Pagination: count=0, offset=0, limit=0
# Processing 1 series for category 32980, Eastern Europe
# Pagination: count=0, offset=0, limit=0
# Processing 0 series for category 32981, Northern Europe
# Pagination: count=0, offset=0, limit=0
# Processing 0 series for category 32982, Southern Europe
# Pagination: count=0, offset=0, limit=0
# Processing 0 series for category 32983, Western Europe
# Pagination: count=0, offset=0, limit=0
# Processing 2 series for category 32984, Australia and New Zealand
# Pagination: count=0, offset=0, limit=0
# Processing 0 series for category 32985, Melanesia
# Pagination: count=0, offset=0, limit=0
# Processing 0 series for category 32986, Micronesia
# Pagination: count=0, offset=0, limit=0
# Processing 0 series for category 32987, Polynesia
# Pagination: count=0, offset=0, limit=0
# Processing 2 series for category 32988, Caribbean
# Pagination: count=0, offset=0, limit=0
# Processing 2 series for category 32989, Central America
# Pagination: count=0, offset=0, limit=0
# Processing 0 series for category 32990, South America
# Pagination: count=0, offset=0, limit=0
# Wrote series data for 23 categories to /Users/troy/Develop/gly.fish/meida/notebooks/fred/series/series_data/fred_international_geography_32955.yaml
