# %% [markdown]
# # FRED API Regional Categories

# %%
# %reload_ext autoreload
# %autoreload 2

import sys
from pathlib import Path
sys.path.append('../')

from lib.utils import print_json_vertical
from utils import call_tool, children_of_categories, explore_categories, find_leaf_categories

MCP_URL = 'http://localhost:8080/sse'
tool_name = "fred.category_children"

# %% [markdown]
# ## First Level

# %%
args = {"category_id": 0}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32991,
#     "name": "Money, Banking, & Finance",
#     "parent_id": 0
#   },
#   {
#     "id": 10,
#     "name": "Population, Employment, & Labor Markets",
#     "parent_id": 0
#   },
#   {
#     "id": 32992,
#     "name": "National Accounts",
#     "parent_id": 0
#   },
#   {
#     "id": 1,
#     "name": "Production & Business Activity",
#     "parent_id": 0
#   },
#   {
#     "id": 32455,
#     "name": "Prices",
#     "parent_id": 0
#   },
#   {
#     "id": 32263,
#     "name": "International Data",
#     "parent_id": 0
#   },
#   {
#     "id": 3008,
#     "name": "U.S. Regional Data",
#     "parent_id": 0
#   },
#   {
#     "id": 33060,
#     "name": "Academic Data",
#     "parent_id": 0
#   }
# ]

# %% [markdown]
# ## U.S. Regional Data
#
# cat_id = 3008

# %%
args = {"category_id": 3008}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 27281,
#     "name": "States",
#     "parent_id": 3008
#   },
#   {
#     "id": 32043,
#     "name": "Census Regions",
#     "parent_id": 3008
#   },
#   {
#     "id": 32061,
#     "name": "BEA Regions",
#     "parent_id": 3008
#   },
#   {
#     "id": 32849,
#     "name": "BLS Regions",
#     "parent_id": 3008
#   },
#   {
#     "id": 32071,
#     "name": "Federal Reserve Districts",
#     "parent_id": 3008
#   },
#   {
#     "id": 32233,
#     "name": "Freddie Mac Regions",
#     "parent_id": 3008
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 27281, States has 53 children
# Category 32043, Census Regions has 4 children
# Category 32061, BEA Regions has 8 children
# Category 32849, BLS Regions has 7 children
# Category 32071, Federal Reserve Districts has 12 children
# Category 32233, Freddie Mac Regions has 5 children

# %% [markdown]
# ### States
#
# cat_id = 27281

# %%
args = {"category_id": 27281}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 27282,
#     "name": "Alabama",
#     "parent_id": 27281
#   },
#   {
#     "id": 27283,
#     "name": "Alaska",
#     "parent_id": 27281
#   },
#   {
#     "id": 27284,
#     "name": "Arizona",
#     "parent_id": 27281
#   },
#   {
#     "id": 149,
#     "name": "Arkansas",
#     "parent_id": 27281
#   },
#   {
#     "id": 27286,
#     "name": "California",
#     "parent_id": 27281
#   },
#   {
#     "id": 27287,
#     "name": "Colorado",
#     "parent_id": 27281
#   },
#   {
#     "id": 27288,
#     "name": "Connecticut",
#     "parent_id": 27281
#   },
#   {
#     "id": 27289,
#     "name": "Delaware",
#     "parent_id": 27281
#   },
#   {
#     "id": 27290,
#     "name": "District of Columbia",
#     "parent_id": 27281
#   },
#   {
#     "id": 27291,
#     "name": "Florida",
#     "parent_id": 27281
#   },
#   {
#     "id": 27292,
#     "name": "Georgia",
#     "parent_id": 27281
#   },
#   {
#     "id": 27293,
#     "name": "Hawaii",
#     "parent_id": 27281
#   },
#   {
#     "id": 27294,
#     "name": "Idaho",
#     "parent_id": 27281
#   },
#   {
#     "id": 150,
#     "name": "Illinois",
#     "parent_id": 27281
#   },
#   {
#     "id": 151,
#     "name": "Indiana",
#     "parent_id": 27281
#   },
#   {
#     "id": 27297,
#     "name": "Iowa",
#     "parent_id": 27281
#   },
#   {
#     "id": 27298,
#     "name": "Kansas",
#     "parent_id": 27281
#   },
#   {
#     "id": 152,
#     "name": "Kentucky",
#     "parent_id": 27281
#   },
#   {
#     "id": 27300,
#     "name": "Louisiana",
#     "parent_id": 27281
#   },
#   {
#     "id": 27301,
#     "name": "Maine",
#     "parent_id": 27281
#   },
#   {
#     "id": 27302,
#     "name": "Maryland",
#     "parent_id": 27281
#   },
#   {
#     "id": 27303,
#     "name": "Massachusetts",
#     "parent_id": 27281
#   },
#   {
#     "id": 27304,
#     "name": "Michigan",
#     "parent_id": 27281
#   },
#   {
#     "id": 27305,
#     "name": "Minnesota",
#     "parent_id": 27281
#   },
#   {
#     "id": 153,
#     "name": "Mississippi",
#     "parent_id": 27281
#   },
#   {
#     "id": 154,
#     "name": "Missouri",
#     "parent_id": 27281
#   },
#   {
#     "id": 27308,
#     "name": "Montana",
#     "parent_id": 27281
#   },
#   {
#     "id": 27309,
#     "name": "Nebraska",
#     "parent_id": 27281
#   },
#   {
#     "id": 27310,
#     "name": "Nevada",
#     "parent_id": 27281
#   },
#   {
#     "id": 27311,
#     "name": "New Hampshire",
#     "parent_id": 27281
#   },
#   {
#     "id": 27312,
#     "name": "New Jersey",
#     "parent_id": 27281
#   },
#   {
#     "id": 27313,
#     "name": "New Mexico",
#     "parent_id": 27281
#   },
#   {
#     "id": 27314,
#     "name": "New York",
#     "parent_id": 27281
#   },
#   {
#     "id": 27315,
#     "name": "North Carolina",
#     "parent_id": 27281
#   },
#   {
#     "id": 27316,
#     "name": "North Dakota",
#     "parent_id": 27281
#   },
#   {
#     "id": 27317,
#     "name": "Ohio",
#     "parent_id": 27281
#   },
#   {
#     "id": 27318,
#     "name": "Oklahoma",
#     "parent_id": 27281
#   },
#   {
#     "id": 27319,
#     "name": "Oregon",
#     "parent_id": 27281
#   },
#   {
#     "id": 27320,
#     "name": "Pennsylvania",
#     "parent_id": 27281
#   },
#   {
#     "id": 33504,
#     "name": "Puerto Rico",
#     "parent_id": 27281
#   },
#   {
#     "id": 27322,
#     "name": "Rhode Island",
#     "parent_id": 27281
#   },
#   {
#     "id": 27323,
#     "name": "South Carolina",
#     "parent_id": 27281
#   },
#   {
#     "id": 27324,
#     "name": "South Dakota",
#     "parent_id": 27281
#   },
#   {
#     "id": 193,
#     "name": "Tennessee",
#     "parent_id": 27281
#   },
#   {
#     "id": 27326,
#     "name": "Texas",
#     "parent_id": 27281
#   },
#   {
#     "id": 27328,
#     "name": "Utah",
#     "parent_id": 27281
#   },
#   {
#     "id": 27329,
#     "name": "Vermont",
#     "parent_id": 27281
#   },
#   {
#     "id": 33605,
#     "name": "Virgin Islands",
#     "parent_id": 27281
#   },
#   {
#     "id": 27330,
#     "name": "Virginia",
#     "parent_id": 27281
#   },
#   {
#     "id": 27332,
#     "name": "West Virginia",
#     "parent_id": 27281
#   },
#   {
#     "id": 27331,
#     "name": "Washington",
#     "parent_id": 27281
#   },
#   {
#     "id": 27333,
#     "name": "Wisconsin",
#     "parent_id": 27281
#   },
#   {
#     "id": 27334,
#     "name": "Wyoming",
#     "parent_id": 27281
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 27282, Alabama has 2 children
# Category 27283, Alaska has 4 children
# Category 27284, Arizona has 3 children
# Category 149, Arkansas has 2 children
# Category 27286, California has 4 children
# Category 27287, Colorado has 3 children
# Category 27288, Connecticut has 5 children
# Category 27289, Delaware has 4 children
# Category 27290, District of Columbia has 4 children
# Category 27291, Florida has 4 children
# Category 27292, Georgia has 4 children
# Category 27293, Hawaii has 4 children
# Category 27294, Idaho has 2 children
# Category 150, Illinois has 4 children
# Category 151, Indiana has 4 children
# Category 27297, Iowa has 2 children
# Category 27298, Kansas has 3 children
# Category 152, Kentucky has 3 children
# Category 27300, Louisiana has 2 children
# Category 27301, Maine has 4 children
# Category 27302, Maryland has 5 children
# Category 27303, Massachusetts has 5 children
# Category 27304, Michigan has 4 children
# Category 27305, Minnesota has 3 children
# Category 153, Mississippi has 2 children
# Category 154, Missouri has 4 children
# Category 27308, Montana has 2 children
# Category 27309, Nebraska has 2 children
# Category 27310, Nevada has 2 children
# Category 27311, New Hampshire has 5 children
# Category 27312, New Jersey has 5 children
# Category 27313, New Mexico has 2 children
# Category 27314, New York has 5 children
# Category 27315, North Carolina has 2 children
# Category 27316, North Dakota has 2 children
# Category 27317, Ohio has 3 children
# Category 27318, Oklahoma has 2 children
# Category 27319, Oregon has 3 children
# Category 27320, Pennsylvania has 5 children
# Category 33504, Puerto Rico has 2 children
# Category 27322, Rhode Island has 3 children
# Category 27323, South Carolina has 2 children
# Category 27324, South Dakota has 2 children
# Category 193, Tennessee has 2 children
# Category 27326, Texas has 4 children
# Category 27328, Utah has 2 children
# Category 27329, Vermont has 3 children
# Category 33605, Virgin Islands has 0 children
# Category 27330, Virginia has 5 children
# Category 27332, West Virginia has 4 children
# Category 27331, Washington has 4 children
# Category 27333, Wisconsin has 4 children
# Category 27334, Wyoming has 2 children

# %% [markdown]
# #### New York
#
# cat_id = 27314

# %%
args = {"category_id": 27314}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 29191,
#     "name": "Counties",
#     "parent_id": 27314
#   },
#   {
#     "id": 30799,
#     "name": "MSAs",
#     "parent_id": 27314
#   },
#   {
#     "id": 32868,
#     "name": "CPI for MSAs and Consolidated MSAs",
#     "parent_id": 27314
#   },
#   {
#     "id": 33164,
#     "name": "Metropolitan Divisions",
#     "notes": "Metropolitan Division refers to a county or group of counties within a Metropolitan Statistical Area that has a population core of at least 2.5 million.",
#     "parent_id": 27314
#   },
#   {
#     "id": 33469,
#     "name": "Metropolitan Areas",
#     "parent_id": 27314
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 29191, Counties has 62 children
# Category 30799, MSAs has 13 children
# Category 32868, CPI for MSAs and Consolidated MSAs has 1 children
# Category 33164, Metropolitan Divisions has 4 children
# Category 33469, Metropolitan Areas has 2 children

# %% [markdown]
# ### Census Regions
#
# cat_id = 32043

# %%
args = {"category_id": 32043}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32044,
#     "name": "Midwest",
#     "parent_id": 32043
#   },
#   {
#     "id": 32045,
#     "name": "Northeast",
#     "parent_id": 32043
#   },
#   {
#     "id": 32046,
#     "name": "South",
#     "parent_id": 32043
#   },
#   {
#     "id": 32047,
#     "name": "West",
#     "parent_id": 32043
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 32044, Midwest has 1 children
# Category 32045, Northeast has 1 children
# Category 32046, South has 1 children
# Category 32047, West has 1 children

# %% [markdown]
# ### Generate Categories File

# %%
root_id = 32043
root_name = "Census Regions"
filename = f"fred_regional_census_regions_{root_id}.yaml"
await find_leaf_categories(root_id, root_name, filename)
# Out:
# Found Leaf category East North Central
# Found Leaf category West North Central
# Found Leaf category Middle Atlantic
# Found Leaf category New England
# Found Leaf category East South Central
# Found Leaf category South Atlantic
# Found Leaf category West South Central
# Found Leaf category Mountain
# Found Leaf category Pacific
# Wrote 9 leaf categories (with names) to fred_regional_census_regions_32043.yaml

# %% [markdown]
# ### BEA Regions
#
# cat_id = 32061

# %%
args = {"category_id": 32061}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32062,
#     "name": "Far West",
#     "parent_id": 32061
#   },
#   {
#     "id": 32063,
#     "name": "Great Lakes",
#     "parent_id": 32061
#   },
#   {
#     "id": 32064,
#     "name": "Mideast",
#     "parent_id": 32061
#   },
#   {
#     "id": 32065,
#     "name": "New England",
#     "parent_id": 32061
#   },
#   {
#     "id": 32066,
#     "name": "Plains",
#     "parent_id": 32061
#   },
#   {
#     "id": 32067,
#     "name": "Rocky Mountain",
#     "parent_id": 32061
#   },
#   {
#     "id": 32068,
#     "name": "Southeast",
#     "parent_id": 32061
#   },
#   {
#     "id": 32069,
#     "name": "Southwest",
#     "parent_id": 32061
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 32062, Far West has 0 children
# Category 32063, Great Lakes has 0 children
# Category 32064, Mideast has 0 children
# Category 32065, New England has 0 children
# Category 32066, Plains has 0 children
# Category 32067, Rocky Mountain has 0 children
# Category 32068, Southeast has 0 children
# Category 32069, Southwest has 0 children

# %% [markdown]
# ### Generate Categories File

# %%
root_id = 32061
root_name = "BEA Regions"
filename = f"fred_regional_bea_regions_{root_id}.yaml"
await find_leaf_categories(root_id, root_name, filename)
# Out:
# Found Leaf category Far West
# Found Leaf category Great Lakes
# Found Leaf category Mideast
# Found Leaf category New England
# Found Leaf category Plains
# Found Leaf category Rocky Mountain
# Found Leaf category Southeast
# Found Leaf category Southwest
# Wrote 8 leaf categories (with names) to fred_regional_bea_regions_32061.yaml

# %% [markdown]
# ### BLS Regions
#
# cat_id = 32849

# %%
args = {"category_id": 32849}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32851,
#     "name": "Midwest Urban",
#     "parent_id": 32849
#   },
#   {
#     "id": 32850,
#     "name": "Northeast Urban",
#     "parent_id": 32849
#   },
#   {
#     "id": 32852,
#     "name": "South Urban",
#     "parent_id": 32849
#   },
#   {
#     "id": 32853,
#     "name": "West Urban",
#     "parent_id": 32849
#   },
#   {
#     "id": 32860,
#     "name": "Population Size Class A (over 1,500,000)",
#     "parent_id": 32849
#   },
#   {
#     "id": 32861,
#     "name": "Population Size Class B/C (between 50,000 and 1,500,000)",
#     "parent_id": 32849
#   },
#   {
#     "id": 32862,
#     "name": "Population Size Class D (under 50,000)",
#     "parent_id": 32849
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 32851, Midwest Urban has 3 children
# Category 32850, Northeast Urban has 2 children
# Category 32852, South Urban has 3 children
# Category 32853, West Urban has 2 children
# Category 32860, Population Size Class A (over 1,500,000) has 0 children
# Category 32861, Population Size Class B/C (between 50,000 and 1,500,000) has 0 children
# Category 32862, Population Size Class D (under 50,000) has 0 children

# %% [markdown]
# ### Generate Categories File

# %%
root_id = 32849
root_name = "BLS Regions"
filename = f"fred_regional_bls_regions_{root_id}.yaml"
await find_leaf_categories(root_id, root_name, filename)
# Out:
# Found Leaf category Population Size Class A (over 1,500,000)
# Found Leaf category Population Size Class B/C (between 50,000 and 1,500,000)
# Found Leaf category Population Size Class D (under 50,000)
# Found Leaf category Population Size Class A (over 1,500,000)
# Found Leaf category Population Size Class B/C (between 50,000 and 1,500,000)
# Found Leaf category Population Size Class D (under 50,000)
# Found Leaf category Population Size Class A (over 1,500,000)
# Found Leaf category Population Size Class B/C (between 50,000 and 1,500,000)
# Found Leaf category Population Size Class A (over 1,500,000)
# Found Leaf category Population Size Class B/C (between 50,000 and 1,500,000)
# Found Leaf category Population Size Class D (under 50,000)
# Found Leaf category Population Size Class A (over 1,500,000)
# Found Leaf category Population Size Class B/C (between 50,000 and 1,500,000)
# Wrote 13 leaf categories (with names) to fred_regional_bls_regions_32849.yaml

# %% [markdown]
# ### Federal Reserve Districts
#
# cat_id = 32071

# %%
args = {"category_id": 32071}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32146,
#     "name": "Atlanta",
#     "parent_id": 32071
#   },
#   {
#     "id": 32147,
#     "name": "Boston",
#     "parent_id": 32071
#   },
#   {
#     "id": 32148,
#     "name": "Chicago",
#     "parent_id": 32071
#   },
#   {
#     "id": 32149,
#     "name": "Cleveland",
#     "parent_id": 32071
#   },
#   {
#     "id": 32150,
#     "name": "Dallas",
#     "parent_id": 32071
#   },
#   {
#     "id": 32151,
#     "name": "Kansas City",
#     "parent_id": 32071
#   },
#   {
#     "id": 32152,
#     "name": "Minneapolis",
#     "parent_id": 32071
#   },
#   {
#     "id": 32153,
#     "name": "New York",
#     "parent_id": 32071
#   },
#   {
#     "id": 32154,
#     "name": "Philadelphia",
#     "parent_id": 32071
#   },
#   {
#     "id": 32155,
#     "name": "Richmond",
#     "parent_id": 32071
#   },
#   {
#     "id": 32156,
#     "name": "San Francisco",
#     "parent_id": 32071
#   },
#   {
#     "id": 133,
#     "name": "St. Louis",
#     "notes": "* The FRB-St. Louis District States include Arkansas, Illinois, Indiana, Kentucky, Mississippi, Missouri and Tennessee.\r\n\r\n** The FRB-St. Louis District Counties and MSAs are located in Arkansas, southern Illinois, southern Indiana, western Kentucky, northern Mississippi, eastern Missouri and western Tennessee.",
#     "parent_id": 32071
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 32146, Atlanta has 3 children
# Category 32147, Boston has 3 children
# Category 32148, Chicago has 3 children
# Category 32149, Cleveland has 3 children
# Category 32150, Dallas has 3 children
# Category 32151, Kansas City has 3 children
# Category 32152, Minneapolis has 3 children
# Category 32153, New York has 3 children
# Category 32154, Philadelphia has 3 children
# Category 32155, Richmond has 3 children
# Category 32156, San Francisco has 3 children
# Category 133, St. Louis has 3 children

# %% [markdown]
# ### Freddie Mac Regions
#
# cat_id = 32233

# %%
args = {"category_id": 32233}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32236,
#     "name": "North Central",
#     "parent_id": 32233
#   },
#   {
#     "id": 32234,
#     "name": "Northeast",
#     "parent_id": 32233
#   },
#   {
#     "id": 32235,
#     "name": "Southeast",
#     "parent_id": 32233
#   },
#   {
#     "id": 32237,
#     "name": "Southwest",
#     "parent_id": 32233
#   },
#   {
#     "id": 32238,
#     "name": "West",
#     "parent_id": 32233
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 32236, North Central has 0 children
# Category 32234, Northeast has 0 children
# Category 32235, Southeast has 0 children
# Category 32237, Southwest has 0 children
# Category 32238, West has 0 children
