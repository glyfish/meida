# %% [markdown]
# # FRED API Prices Categories

# %%
# %reload_ext autoreload
# %autoreload 2

import sys
from pathlib import Path
sys.path.append('../')

from lib.utils import print_json_vertical
from utils import call_tool, children_of_categories, explore_categories, find_leaf_categories

MCP_URL = 'http://localhost:8080/sse'
tool_name = "fred.category_children"

# %% [markdown]
# ## First Level

# %%
args = {"category_id": 0}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32991,
#     "name": "Money, Banking, & Finance",
#     "parent_id": 0
#   },
#   {
#     "id": 10,
#     "name": "Population, Employment, & Labor Markets",
#     "parent_id": 0
#   },
#   {
#     "id": 32992,
#     "name": "National Accounts",
#     "parent_id": 0
#   },
#   {
#     "id": 1,
#     "name": "Production & Business Activity",
#     "parent_id": 0
#   },
#   {
#     "id": 32455,
#     "name": "Prices",
#     "parent_id": 0
#   },
#   {
#     "id": 32263,
#     "name": "International Data",
#     "parent_id": 0
#   },
#   {
#     "id": 3008,
#     "name": "U.S. Regional Data",
#     "parent_id": 0
#   },
#   {
#     "id": 33060,
#     "name": "Academic Data",
#     "parent_id": 0
#   }
# ]

# %% [markdown]
# ## Prices
#
# cat_id = 32455

# %%
args = {"category_id": 32455}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32217,
#     "name": "Commodities",
#     "parent_id": 32455
#   },
#   {
#     "id": 9,
#     "name": "Consumer Price Indexes (CPI and PCE)",
#     "parent_id": 32455
#   },
#   {
#     "id": 33913,
#     "name": "Cryptocurrencies",
#     "parent_id": 32455
#   },
#   {
#     "id": 4,
#     "name": "Employment Cost Index",
#     "parent_id": 32455
#   },
#   {
#     "id": 33717,
#     "name": "Health Care Indexes",
#     "parent_id": 32455
#   },
#   {
#     "id": 32261,
#     "name": "House Price Indexes",
#     "parent_id": 32455
#   },
#   {
#     "id": 31,
#     "name": "Producer Price Indexes (PPI)",
#     "parent_id": 32455
#   },
#   {
#     "id": 32220,
#     "name": "Trade Indexes",
#     "parent_id": 32455
#   }
# ]

# %% [markdown]
# ### Commodities
#
# cat_id = 32217

# %%
args = {"category_id": 32217}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# []

# %% [markdown]
# ### Consumer Price Indexes (CPI and PCE)
#
# cat_id = 9

# %%
args = {"category_id": 9}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32415,
#     "name": "Food and Beverages",
#     "parent_id": 9
#   },
#   {
#     "id": 32416,
#     "name": "Housing",
#     "parent_id": 9
#   },
#   {
#     "id": 32417,
#     "name": "Apparel",
#     "parent_id": 9
#   },
#   {
#     "id": 32418,
#     "name": "Transportation",
#     "parent_id": 9
#   },
#   {
#     "id": 32419,
#     "name": "Medical Care",
#     "parent_id": 9
#   },
#   {
#     "id": 32420,
#     "name": "Recreation",
#     "parent_id": 9
#   },
#   {
#     "id": 32421,
#     "name": "Education and Communication",
#     "parent_id": 9
#   },
#   {
#     "id": 32422,
#     "name": "Other Goods and Services",
#     "parent_id": 9
#   },
#   {
#     "id": 32423,
#     "name": "Commodity and Services Groups",
#     "parent_id": 9
#   },
#   {
#     "id": 32424,
#     "name": "Special Indexes",
#     "parent_id": 9
#   }
# ]

# %% [markdown]
# ### Cryptocurrencies
#
# cat_id = 33913

# %%
args = {"category_id": 33913}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# []

# %% [markdown]
# ### Employment Cost Index
#
# cat_id = 4

# %%
args = {"category_id": 4}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# []

# %% [markdown]
# ### Health Care Indexes
#
# cat_id = 33717

# %%
args = {"category_id": 33717}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# []

# %% [markdown]
# ### House Price Indexes
#
# cat_id = 32261

# %%
args = {"category_id": 32261}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# []

# %% [markdown]
# ### Producer Price Indexes (PPI)
#
# cat_id = 31

# %%
args = {"category_id": 31}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 33583,
#     "name": "Commodity Based",
#     "parent_id": 31
#   },
#   {
#     "id": 33584,
#     "name": "Industry Based",
#     "parent_id": 31
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 33583, Commodity Based has 53 children
# Category 33584, Industry Based has 19 children

# %% [markdown]
# #### Commodity Based
#
# cat_id = 33583

# %%
args = {"category_id": 33583}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 33564,
#     "name": "Accommodation Services",
#     "parent_id": 33583
#   },
#   {
#     "id": 33548,
#     "name": "Advertising Space and Time Sales",
#     "parent_id": 33583
#   },
#   {
#     "id": 33533,
#     "name": "Chemicals and Allied Products",
#     "parent_id": 33583
#   },
#   {
#     "id": 33560,
#     "name": "Cleaning and Building Maintenance Services",
#     "parent_id": 33583
#   },
#   {
#     "id": 33573,
#     "name": "Construction",
#     "parent_id": 33583
#   },
#   {
#     "id": 33572,
#     "name": "Contract Work on Textile Products, Apparel, and Leather",
#     "parent_id": 33583
#   },
#   {
#     "id": 33551,
#     "name": "Credit Intermediation Services",
#     "parent_id": 33583
#   },
#   {
#     "id": 33550,
#     "name": "Data Processing and Related Services",
#     "parent_id": 33583
#   },
#   {
#     "id": 33574,
#     "name": "Durability of Product",
#     "parent_id": 33583
#   },
#   {
#     "id": 33563,
#     "name": "Educational Services",
#     "parent_id": 33583
#   },
#   {
#     "id": 33557,
#     "name": "Employment Services",
#     "parent_id": 33583
#   },
#   {
#     "id": 33567,
#     "name": "Entertainment Services",
#     "parent_id": 33583
#   },
#   {
#     "id": 33528,
#     "name": "Farm Products",
#     "parent_id": 33583
#   },
#   {
#     "id": 33575,
#     "name": "Final Demand",
#     "parent_id": 33583
#   },
#   {
#     "id": 33565,
#     "name": "Food and Beverage for Immediate Consumption Services",
#     "parent_id": 33583
#   },
#   {
#     "id": 33532,
#     "name": "Fuels and Related Products and Power",
#     "parent_id": 33583
#   },
#   {
#     "id": 33539,
#     "name": "Furniture and Household Durables",
#     "parent_id": 33583
#   },
#   {
#     "id": 33561,
#     "name": "Health Care Services",
#     "parent_id": 33583
#   },
#   {
#     "id": 33531,
#     "name": "Hides, Skins, Leather, and Related Products",
#     "parent_id": 33583
#   },
#   {
#     "id": 33582,
#     "name": "Inputs to Industries",
#     "parent_id": 33583
#   },
#   {
#     "id": 33553,
#     "name": "Insurance and Annuities",
#     "parent_id": 33583
#   },
#   {
#     "id": 33577,
#     "name": "Intermediate Demand By Commodity Type",
#     "parent_id": 33583
#   },
#   {
#     "id": 33576,
#     "name": "Intermediate Demand By Production Flow",
#     "parent_id": 33583
#   },
#   {
#     "id": 33552,
#     "name": "Investment Services",
#     "parent_id": 33583
#   },
#   {
#     "id": 33535,
#     "name": "Lumber and Wood Products",
#     "parent_id": 33583
#   },
#   {
#     "id": 33538,
#     "name": "Machinery and Equipment",
#     "parent_id": 33583
#   },
#   {
#     "id": 33570,
#     "name": "Metal Treatment Services",
#     "parent_id": 33583
#   },
#   {
#     "id": 33537,
#     "name": "Metals and Metal Products",
#     "parent_id": 33583
#   },
#   {
#     "id": 33571,
#     "name": "Mining Services",
#     "parent_id": 33583
#   },
#   {
#     "id": 33542,
#     "name": "Miscellaneous Products",
#     "parent_id": 33583
#   },
#   {
#     "id": 33547,
#     "name": "Network Compensation from Broadcast and Cable Television and Radio",
#     "parent_id": 33583
#   },
#   {
#     "id": 33540,
#     "name": "Nonmetallic Mineral Products",
#     "parent_id": 33583
#   },
#   {
#     "id": 33529,
#     "name": "Processed Foods and Feeds",
#     "parent_id": 33583
#   },
#   {
#     "id": 33556,
#     "name": "Professional Services",
#     "parent_id": 33583
#   },
#   {
#     "id": 33545,
#     "name": "Publishing Sales, Excluding Software",
#     "parent_id": 33583
#   },
#   {
#     "id": 33536,
#     "name": "Pulp, Paper, and Allied Products",
#     "parent_id": 33583
#   },
#   {
#     "id": 33554,
#     "name": "Real Estate Services",
#     "parent_id": 33583
#   },
#   {
#     "id": 33555,
#     "name": "Rental and Leasing of Goods",
#     "parent_id": 33583
#   },
#   {
#     "id": 33566,
#     "name": "Repair and Maintenance Services",
#     "parent_id": 33583
#   },
#   {
#     "id": 33569,
#     "name": "Retail Trade Services",
#     "parent_id": 33583
#   },
#   {
#     "id": 33534,
#     "name": "Rubber and Plastic Products",
#     "parent_id": 33583
#   },
#   {
#     "id": 33559,
#     "name": "Selected Security Services",
#     "parent_id": 33583
#   },
#   {
#     "id": 33546,
#     "name": "Software Publishing",
#     "parent_id": 33583
#   },
#   {
#     "id": 33580,
#     "name": "Special Indexes",
#     "parent_id": 33583
#   },
#   {
#     "id": 33581,
#     "name": "Stage of Processing",
#     "parent_id": 33583
#   },
#   {
#     "id": 33549,
#     "name": "Telecommunication, Cable, and Internet User Services",
#     "parent_id": 33583
#   },
#   {
#     "id": 33530,
#     "name": "Textile Products and Apparel",
#     "parent_id": 33583
#   },
#   {
#     "id": 33541,
#     "name": "Transportation Equipment",
#     "parent_id": 33583
#   },
#   {
#     "id": 33543,
#     "name": "Transportation Services",
#     "parent_id": 33583
#   },
#   {
#     "id": 33558,
#     "name": "Travel Arrangement Services",
#     "parent_id": 33583
#   },
#   {
#     "id": 33544,
#     "name": "Warehousing, Storage, and Related Services",
#     "parent_id": 33583
#   },
#   {
#     "id": 33562,
#     "name": "Waste Collection and Remediation Services",
#     "parent_id": 33583
#   },
#   {
#     "id": 33568,
#     "name": "Wholesale Trade Services",
#     "parent_id": 33583
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 33564, Accommodation Services has 0 children
# Category 33548, Advertising Space and Time Sales has 0 children
# Category 33533, Chemicals and Allied Products has 0 children
# Category 33560, Cleaning and Building Maintenance Services has 0 children
# Category 33573, Construction has 0 children
# Category 33572, Contract Work on Textile Products, Apparel, and Leather has 0 children
# Category 33551, Credit Intermediation Services has 0 children
# Category 33550, Data Processing and Related Services has 0 children
# Category 33574, Durability of Product has 0 children
# Category 33563, Educational Services has 0 children
# Category 33557, Employment Services has 0 children
# Category 33567, Entertainment Services has 0 children
# Category 33528, Farm Products has 0 children
# Category 33575, Final Demand has 0 children
# Category 33565, Food and Beverage for Immediate Consumption Services has 0 children
# Category 33532, Fuels and Related Products and Power has 0 children
# Category 33539, Furniture and Household Durables has 0 children
# Category 33561, Health Care Services has 0 children
# Category 33531, Hides, Skins, Leather, and Related Products has 0 children
# Category 33582, Inputs to Industries has 0 children
# Category 33553, Insurance and Annuities has 0 children
# Category 33577, Intermediate Demand By Commodity Type has 0 children
# Category 33576, Intermediate Demand By Production Flow has 0 children
# Category 33552, Investment Services has 0 children
# Category 33535, Lumber and Wood Products has 0 children
# Category 33538, Machinery and Equipment has 0 children
# Category 33570, Metal Treatment Services has 0 children
# Category 33537, Metals and Metal Products has 0 children
# Category 33571, Mining Services has 0 children
# Category 33542, Miscellaneous Products has 0 children
# Category 33547, Network Compensation from Broadcast and Cable Television and Radio has 0 children
# Category 33540, Nonmetallic Mineral Products has 0 children
# Category 33529, Processed Foods and Feeds has 0 children
# Category 33556, Professional Services has 0 children
# Category 33545, Publishing Sales, Excluding Software has 0 children
# Category 33536, Pulp, Paper, and Allied Products has 0 children
# Category 33554, Real Estate Services has 0 children
# Category 33555, Rental and Leasing of Goods has 0 children
# Category 33566, Repair and Maintenance Services has 0 children
# Category 33569, Retail Trade Services has 0 children
# Category 33534, Rubber and Plastic Products has 0 children
# Category 33559, Selected Security Services has 0 children
# Category 33546, Software Publishing has 0 children
# Category 33580, Special Indexes has 0 children
# Category 33581, Stage of Processing has 0 children
# Category 33549, Telecommunication, Cable, and Internet User Services has 0 children
# Category 33530, Textile Products and Apparel has 0 children
# Category 33541, Transportation Equipment has 0 children
# Category 33543, Transportation Services has 0 children
# Category 33558, Travel Arrangement Services has 0 children
# Category 33544, Warehousing, Storage, and Related Services has 0 children
# Category 33562, Waste Collection and Remediation Services has 0 children
# Category 33568, Wholesale Trade Services has 0 children

# %% [markdown]
# #### Industry Based
#
# cat_id = 33584

# %%
args = {"category_id": 33584}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 33586,
#     "name": "Accommodation and Food Services",
#     "parent_id": 33584
#   },
#   {
#     "id": 33588,
#     "name": "Administrative and Support and Waste Management and Remediation Services",
#     "parent_id": 33584
#   },
#   {
#     "id": 33585,
#     "name": "Agriculture, Forestry, Fishing and Hunting",
#     "parent_id": 33584
#   },
#   {
#     "id": 33587,
#     "name": "Arts, Entertainment, and Recreation",
#     "parent_id": 33584
#   },
#   {
#     "id": 33589,
#     "name": "Construction",
#     "parent_id": 33584
#   },
#   {
#     "id": 33591,
#     "name": "Educational Services",
#     "parent_id": 33584
#   },
#   {
#     "id": 33590,
#     "name": "Finance and Insurance",
#     "parent_id": 33584
#   },
#   {
#     "id": 33593,
#     "name": "Health Care and Social Assistance",
#     "parent_id": 33584
#   },
#   {
#     "id": 33592,
#     "name": "Information",
#     "parent_id": 33584
#   },
#   {
#     "id": 33597,
#     "name": "Manufacturing",
#     "parent_id": 33584
#   },
#   {
#     "id": 33596,
#     "name": "Mining, Quarrying, and Oil and Gas Extraction",
#     "parent_id": 33584
#   },
#   {
#     "id": 33594,
#     "name": "Other Services (except Public Administration)",
#     "parent_id": 33584
#   },
#   {
#     "id": 33599,
#     "name": "Professional, Scientific, and Technical Services",
#     "parent_id": 33584
#   },
#   {
#     "id": 33595,
#     "name": "Public Administration",
#     "parent_id": 33584
#   },
#   {
#     "id": 33598,
#     "name": "Real Estate and Rental and Leasing",
#     "parent_id": 33584
#   },
#   {
#     "id": 33600,
#     "name": "Retail Trade",
#     "parent_id": 33584
#   },
#   {
#     "id": 33601,
#     "name": "Transportation and Warehousing",
#     "parent_id": 33584
#   },
#   {
#     "id": 33602,
#     "name": "Utilities",
#     "parent_id": 33584
#   },
#   {
#     "id": 33603,
#     "name": "Wholesale Trade",
#     "parent_id": 33584
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 33586, Accommodation and Food Services has 0 children
# Category 33588, Administrative and Support and Waste Management and Remediation Services has 0 children
# Category 33585, Agriculture, Forestry, Fishing and Hunting has 0 children
# Category 33587, Arts, Entertainment, and Recreation has 0 children
# Category 33589, Construction has 0 children
# Category 33591, Educational Services has 0 children
# Category 33590, Finance and Insurance has 0 children
# Category 33593, Health Care and Social Assistance has 0 children
# Category 33592, Information has 0 children
# Category 33597, Manufacturing has 0 children
# Category 33596, Mining, Quarrying, and Oil and Gas Extraction has 0 children
# Category 33594, Other Services (except Public Administration) has 0 children
# Category 33599, Professional, Scientific, and Technical Services has 0 children
# Category 33595, Public Administration has 0 children
# Category 33598, Real Estate and Rental and Leasing has 0 children
# Category 33600, Retail Trade has 0 children
# Category 33601, Transportation and Warehousing has 0 children
# Category 33602, Utilities has 0 children
# Category 33603, Wholesale Trade has 0 children

# %% [markdown]
# ### Trade Indexes
#
# cat_id = 32220

# %%
args = {"category_id": 32220}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32221,
#     "name": "Import Price Indexes",
#     "parent_id": 32220
#   },
#   {
#     "id": 32224,
#     "name": "Export Price Indexes",
#     "parent_id": 32220
#   },
#   {
#     "id": 32231,
#     "name": "Services Price Indexes",
#     "notes": "Starting in September 2008 the Import Air Passenger Fares Indexes represent changes in the average revenue per passenger received by foreign carriers from U.S. residents and are calculated from data obtained from an airline consulting service. These data include tickets sold by travel agencies and travel websites. Tickets sold directly by the airlines are excluded, as are frequent flyer tickets generally. Starting in January 2008 the Export Air Passenger Fares Indexes represent changes in the average revenue per passenger received by U.S. carriers from foreign residents and are calculated from data collected directly from airlines. These data include frequent flyer tickets and those sold by consolidators. Taxes and fees are included in the Import Air Passenger Fares Index and excluded from the Export Air Passenger Fares Index. The Air Freight Indexes are calculated from data collected directly from airlines. These data exclude mail and passenger baggage. The scope of the service being priced is the movement of freight from airport to airport only, and does not include any ground transportation or port service. The Air Freight Indexes are presented using two definitions: Balance of Payments (which represent transactions between U.S. and foreign residents) and International (which represent transactions inbound to and outbound from the U.S.). Fact sheets specifying detailed information for each services industry are available at http://www.bls.gov/mxp under \"MXP  Publications.\"",
#     "parent_id": 32220
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 32221, Import Price Indexes has 5 children
# Category 32224, Export Price Indexes has 4 children
# Category 32231, Services Price Indexes has 0 children

# %% [markdown]
# ## Generate Categories File

# %%
root_id = 32455
root_name = "Prices"
filename = f"fred_prices_{root_id}.yaml"
await find_leaf_categories(root_id, root_name, filename)
# Out:
# Found Leaf category Commodities
# Found Leaf category Cryptocurrencies
# Found Leaf category Employment Cost Index
# Found Leaf category Health Care Indexes
# Found Leaf category House Price Indexes
# Found Leaf category Food and Beverages
# Found Leaf category Housing
# Found Leaf category Apparel
# Found Leaf category Transportation
# Found Leaf category Medical Care
# Found Leaf category Recreation
# Found Leaf category Education and Communication
# Found Leaf category Other Goods and Services
# Found Leaf category Commodity and Services Groups
# Found Leaf category Special Indexes
# Found Leaf category Services Price Indexes
# Found Leaf category Accommodation Services
# Found Leaf category Advertising Space and Time Sales
# Found Leaf category Chemicals and Allied Products
# Found Leaf category Cleaning and Building Maintenance Services
# Found Leaf category Construction
# Found Leaf category Contract Work on Textile Products, Apparel, and Leather
# Found Leaf category Credit Intermediation Services
# Found Leaf category Data Processing and Related Services
# Found Leaf category Durability of Product
# Found Leaf category Educational Services
# Found Leaf category Employment Services
# Found Leaf category Entertainment Services
# Found Leaf category Farm Products
# Found Leaf category Final Demand
# Found Leaf category Food and Beverage for Immediate Consumption Services
# Found Leaf category Fuels and Related Products and Power
# Found Leaf category Furniture and Household Durables
# Found Leaf category Health Care Services
# Found Leaf category Hides, Skins, Leather, and Related Products
# Found Leaf category Inputs to Industries
# Found Leaf category Insurance and Annuities
# Found Leaf category Intermediate Demand By Commodity Type
# Found Leaf category Intermediate Demand By Production Flow
# Found Leaf category Investment Services
# Found Leaf category Lumber and Wood Products
# Found Leaf category Machinery and Equipment
# Found Leaf category Metal Treatment Services
# Found Leaf category Metals and Metal Products
# Found Leaf category Mining Services
# Found Leaf category Miscellaneous Products
# Found Leaf category Network Compensation from Broadcast and Cable Television and Radio
# Found Leaf category Nonmetallic Mineral Products
# Found Leaf category Processed Foods and Feeds
# Found Leaf category Professional Services
# Found Leaf category Publishing Sales, Excluding Software
# Found Leaf category Pulp, Paper, and Allied Products
# Found Leaf category Real Estate Services
# Found Leaf category Rental and Leasing of Goods
# Found Leaf category Repair and Maintenance Services
# Found Leaf category Retail Trade Services
# Found Leaf category Rubber and Plastic Products
# Found Leaf category Selected Security Services
# Found Leaf category Software Publishing
# Found Leaf category Special Indexes
# Found Leaf category Stage of Processing
# Found Leaf category Telecommunication, Cable, and Internet User Services
# Found Leaf category Textile Products and Apparel
# Found Leaf category Transportation Equipment
# Found Leaf category Transportation Services
# Found Leaf category Travel Arrangement Services
# Found Leaf category Warehousing, Storage, and Related Services
# Found Leaf category Waste Collection and Remediation Services
# Found Leaf category Wholesale Trade Services
# Found Leaf category Accommodation and Food Services
# Found Leaf category Administrative and Support and Waste Management and Remediation Services
# Found Leaf category Agriculture, Forestry, Fishing and Hunting
# Found Leaf category Arts, Entertainment, and Recreation
# Found Leaf category Construction
# Found Leaf category Educational Services
# Found Leaf category Finance and Insurance
# Found Leaf category Health Care and Social Assistance
# Found Leaf category Information
# Found Leaf category Manufacturing
# Found Leaf category Mining, Quarrying, and Oil and Gas Extraction
# Found Leaf category Other Services (except Public Administration)
# Found Leaf category Professional, Scientific, and Technical Services
# Found Leaf category Public Administration
# Found Leaf category Real Estate and Rental and Leasing
# Found Leaf category Retail Trade
# Found Leaf category Transportation and Warehousing
# Found Leaf category Utilities
# Found Leaf category Wholesale Trade
# Found Leaf category End Use Classification System
# Found Leaf category By Harmonized System
# Found Leaf category By NAICS
# Found Leaf category By Locality of Origin
# Found Leaf category Standard International Trade Classification
# Found Leaf category End Use Classification System
# Found Leaf category By NAICS
# Found Leaf category By Harmonized System
# Found Leaf category Standard International Trade Classification
# Wrote 97 leaf categories (with names) to fred_prices_32455.yaml
