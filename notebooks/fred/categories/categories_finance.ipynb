# %% [markdown]
# # FRED API Finance Categories

# %%
# %reload_ext autoreload
# %autoreload 2

import sys
from pathlib import Path
sys.path.append('../')

from lib.utils import print_json_vertical
from utils import call_tool, children_of_categories, explore_categories, find_leaf_categories

MCP_URL = 'http://localhost:8080/sse'
tool_name = "fred.category_children"

# %% [markdown]
# ## First Level

# %%
args = {"category_id": 0}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32991,
#     "name": "Money, Banking, & Finance",
#     "parent_id": 0
#   },
#   {
#     "id": 10,
#     "name": "Population, Employment, & Labor Markets",
#     "parent_id": 0
#   },
#   {
#     "id": 32992,
#     "name": "National Accounts",
#     "parent_id": 0
#   },
#   {
#     "id": 1,
#     "name": "Production & Business Activity",
#     "parent_id": 0
#   },
#   {
#     "id": 32455,
#     "name": "Prices",
#     "parent_id": 0
#   },
#   {
#     "id": 32263,
#     "name": "International Data",
#     "parent_id": 0
#   },
#   {
#     "id": 3008,
#     "name": "U.S. Regional Data",
#     "parent_id": 0
#   },
#   {
#     "id": 33060,
#     "name": "Academic Data",
#     "parent_id": 0
#   }
# ]

# %% [markdown]
# ## Money, Banking, & Finance
#
# cat_id = 32991

# %%
args = {"category_id": 32991}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 22,
#     "name": "Interest Rates",
#     "parent_id": 32991
#   },
#   {
#     "id": 15,
#     "name": "Exchange Rates",
#     "parent_id": 32991
#   },
#   {
#     "id": 24,
#     "name": "Monetary Data",
#     "parent_id": 32991
#   },
#   {
#     "id": 46,
#     "name": "Financial Indicators",
#     "parent_id": 32991
#   },
#   {
#     "id": 23,
#     "name": "Banking",
#     "parent_id": 32991
#   },
#   {
#     "id": 32360,
#     "name": "Business Lending",
#     "parent_id": 32991
#   },
#   {
#     "id": 32145,
#     "name": "Foreign Exchange Intervention",
#     "notes": "In addition to the listed daily intervention series, intra-day series from the Swiss National Bank are available at: \r\nhttp://research.stlouisfed.org/fei/\r\n\r\nUnited Kingdom foreign exchange intervention data can be downloaded from Her Majesty's Treasury at the following:\r\nhttp://www.hm-treasury.gov.uk",
#     "parent_id": 32991
#   }
# ]

# %% [markdown]
# ### Interest Rates
#
# cat_id = 22

# %%
args = {"category_id": 22}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 34009,
#     "name": "AMERIBOR Benchmark Rates",
#     "parent_id": 22
#   },
#   {
#     "id": 33058,
#     "name": "Automobile Loan Rates",
#     "parent_id": 22
#   },
#   {
#     "id": 51,
#     "name": "Bankers Acceptance Rate",
#     "parent_id": 22
#   },
#   {
#     "id": 121,
#     "name": "Certificates of Deposit",
#     "parent_id": 22
#   },
#   {
#     "id": 120,
#     "name": "Commercial Paper",
#     "parent_id": 22
#   },
#   {
#     "id": 32348,
#     "name": "Corporate Bonds",
#     "parent_id": 22
#   },
#   {
#     "id": 33059,
#     "name": "Credit Card Loan Rates",
#     "parent_id": 22
#   },
#   {
#     "id": 34005,
#     "name": "EONIA Rates",
#     "parent_id": 22
#   },
#   {
#     "id": 34007,
#     "name": "Euro Short-Term Rate",
#     "parent_id": 22
#   },
#   {
#     "id": 32298,
#     "name": "Eurodollar Deposits",
#     "parent_id": 22
#   },
#   {
#     "id": 118,
#     "name": "FRB Rates - discount, fed funds, primary credit",
#     "parent_id": 22
#   },
#   {
#     "id": 33056,
#     "name": "Interest Checking Accounts",
#     "parent_id": 22
#   },
#   {
#     "id": 33446,
#     "name": "Interest Rate Spreads",
#     "parent_id": 22
#   },
#   {
#     "id": 32299,
#     "name": "Interest Rate Swaps",
#     "parent_id": 22
#   },
#   {
#     "id": 32995,
#     "name": "Long-Term Securities",
#     "parent_id": 22
#   },
#   {
#     "id": 34242,
#     "name": "Monetary Policy",
#     "parent_id": 22
#   },
#   {
#     "id": 33055,
#     "name": "Money Market Accounts",
#     "parent_id": 22
#   },
#   {
#     "id": 114,
#     "name": "Mortgage Rates",
#     "parent_id": 22
#   },
#   {
#     "id": 33057,
#     "name": "Personal Loan Rates",
#     "parent_id": 22
#   },
#   {
#     "id": 117,
#     "name": "Prime Bank Loan Rate",
#     "parent_id": 22
#   },
#   {
#     "id": 33491,
#     "name": "Saving Accounts",
#     "parent_id": 22
#   },
#   {
#     "id": 34003,
#     "name": "SONIA Rates",
#     "parent_id": 22
#   },
#   {
#     "id": 116,
#     "name": "Treasury Bills",
#     "parent_id": 22
#   },
#   {
#     "id": 115,
#     "name": "Treasury Constant Maturity",
#     "parent_id": 22
#   },
#   {
#     "id": 82,
#     "name": "Treasury Inflation-Indexed Securities",
#     "parent_id": 22
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 34009, AMERIBOR Benchmark Rates has 0 children
# Category 33058, Automobile Loan Rates has 0 children
# Category 51, Bankers Acceptance Rate has 0 children
# Category 121, Certificates of Deposit has 0 children
# Category 120, Commercial Paper has 0 children
# Category 32348, Corporate Bonds has 0 children
# Category 33059, Credit Card Loan Rates has 0 children
# Category 34005, EONIA Rates has 0 children
# Category 34007, Euro Short-Term Rate has 0 children
# Category 32298, Eurodollar Deposits has 0 children
# Category 118, FRB Rates - discount, fed funds, primary credit has 0 children
# Category 33056, Interest Checking Accounts has 0 children
# Category 33446, Interest Rate Spreads has 0 children
# Category 32299, Interest Rate Swaps has 0 children
# Category 32995, Long-Term Securities has 0 children
# Category 34242, Monetary Policy has 0 children
# Category 33055, Money Market Accounts has 0 children
# Category 114, Mortgage Rates has 0 children
# Category 33057, Personal Loan Rates has 0 children
# Category 117, Prime Bank Loan Rate has 0 children
# Category 33491, Saving Accounts has 0 children
# Category 34003, SONIA Rates has 0 children
# Category 116, Treasury Bills has 0 children
# Category 115, Treasury Constant Maturity has 0 children
# Category 82, Treasury Inflation-Indexed Securities has 0 children

# %% [markdown]
# ### Exchange Rates
#
# cat_id = 15

# %%
args = {"category_id": 15}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 94,
#     "name": "Daily Rates",
#     "notes": "Effective January 1, 2009, the Federal Reserve Board discontinued publication of the H.10 Daily Update, which provided U.S. dollar exchange rates against other currencies certified for customs purposes by the Federal Reserve Bank of New York and summary measures of the foreign exchange value of the dollar.   \r\n The Federal Reserve Board still makes the certified exchange rates available.  Effective January 5, 2009, the Board publishes the daily exchange rate data in a weekly version of the H.10 release.\r\n As a result, the daily exchange rates in the FRED database will be updated once each week to capture the daily data from the previous week.",
#     "parent_id": 15
#   },
#   {
#     "id": 95,
#     "name": "Monthly Rates",
#     "parent_id": 15
#   },
#   {
#     "id": 32219,
#     "name": "Annual Rates",
#     "parent_id": 15
#   },
#   {
#     "id": 105,
#     "name": "Trade-Weighted Indexes",
#     "parent_id": 15
#   },
#   {
#     "id": 158,
#     "name": "By Country",
#     "parent_id": 15
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 94, Daily Rates has 0 children
# Category 95, Monthly Rates has 0 children
# Category 32219, Annual Rates has 0 children
# Category 105, Trade-Weighted Indexes has 0 children
# Category 158, By Country has 34 children

# %%
args = {"category_id": 15}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 94,
#     "name": "Daily Rates",
#     "notes": "Effective January 1, 2009, the Federal Reserve Board discontinued publication of the H.10 Daily Update, which provided U.S. dollar exchange rates against other currencies certified for customs purposes by the Federal Reserve Bank of New York and summary measures of the foreign exchange value of the dollar.   \r\n The Federal Reserve Board still makes the certified exchange rates available.  Effective January 5, 2009, the Board publishes the daily exchange rate data in a weekly version of the H.10 release.\r\n As a result, the daily exchange rates in the FRED database will be updated once each week to capture the daily data from the previous week.",
#     "parent_id": 15
#   },
#   {
#     "id": 95,
#     "name": "Monthly Rates",
#     "parent_id": 15
#   },
#   {
#     "id": 32219,
#     "name": "Annual Rates",
#     "parent_id": 15
#   },
#   {
#     "id": 105,
#     "name": "Trade-Weighted Indexes",
#     "parent_id": 15
#   },
#   {
#     "id": 158,
#     "name": "By Country",
#     "parent_id": 15
#   }
# ]

# %% [markdown]
# #### By Country
#
# cat_id = 158

# %%
args = {"category_id": 158}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 287,
#     "name": "Australia",
#     "parent_id": 158
#   },
#   {
#     "id": 286,
#     "name": "Austria",
#     "parent_id": 158
#   },
#   {
#     "id": 285,
#     "name": "Belgium",
#     "parent_id": 158
#   },
#   {
#     "id": 284,
#     "name": "Brazil",
#     "parent_id": 158
#   },
#   {
#     "id": 283,
#     "name": "Canada",
#     "parent_id": 158
#   },
#   {
#     "id": 282,
#     "name": "China",
#     "parent_id": 158
#   },
#   {
#     "id": 281,
#     "name": "Denmark",
#     "parent_id": 158
#   },
#   {
#     "id": 280,
#     "name": "Euro",
#     "parent_id": 158
#   },
#   {
#     "id": 279,
#     "name": "Finland",
#     "parent_id": 158
#   },
#   {
#     "id": 278,
#     "name": "France",
#     "parent_id": 158
#   },
#   {
#     "id": 277,
#     "name": "Germany",
#     "parent_id": 158
#   },
#   {
#     "id": 274,
#     "name": "Greece",
#     "parent_id": 158
#   },
#   {
#     "id": 273,
#     "name": "Hong Kong",
#     "parent_id": 158
#   },
#   {
#     "id": 272,
#     "name": "India",
#     "parent_id": 158
#   },
#   {
#     "id": 271,
#     "name": "Ireland",
#     "parent_id": 158
#   },
#   {
#     "id": 276,
#     "name": "Italy",
#     "parent_id": 158
#   },
#   {
#     "id": 275,
#     "name": "Japan",
#     "parent_id": 158
#   },
#   {
#     "id": 270,
#     "name": "Malaysia",
#     "parent_id": 158
#   },
#   {
#     "id": 269,
#     "name": "Mexico",
#     "parent_id": 158
#   },
#   {
#     "id": 268,
#     "name": "Netherlands",
#     "parent_id": 158
#   },
#   {
#     "id": 266,
#     "name": "New Zealand",
#     "parent_id": 158
#   },
#   {
#     "id": 265,
#     "name": "Norway",
#     "parent_id": 158
#   },
#   {
#     "id": 264,
#     "name": "Portugal",
#     "parent_id": 158
#   },
#   {
#     "id": 263,
#     "name": "Singapore",
#     "parent_id": 158
#   },
#   {
#     "id": 262,
#     "name": "South Africa",
#     "parent_id": 158
#   },
#   {
#     "id": 261,
#     "name": "South Korea",
#     "parent_id": 158
#   },
#   {
#     "id": 260,
#     "name": "Spain",
#     "parent_id": 158
#   },
#   {
#     "id": 259,
#     "name": "Sri Lanka",
#     "parent_id": 158
#   },
#   {
#     "id": 258,
#     "name": "Sweden",
#     "parent_id": 158
#   },
#   {
#     "id": 257,
#     "name": "Switzerland",
#     "parent_id": 158
#   },
#   {
#     "id": 267,
#     "name": "Taiwan",
#     "parent_id": 158
#   },
#   {
#     "id": 254,
#     "name": "Thailand",
#     "parent_id": 158
#   },
#   {
#     "id": 191,
#     "name": "United Kingdom",
#     "parent_id": 158
#   },
#   {
#     "id": 192,
#     "name": "Venezuela",
#     "parent_id": 158
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 287, Australia has 0 children
# Category 286, Austria has 0 children
# Category 285, Belgium has 0 children
# Category 284, Brazil has 0 children
# Category 283, Canada has 0 children
# Category 282, China has 0 children
# Category 281, Denmark has 0 children
# Category 280, Euro has 0 children
# Category 279, Finland has 0 children
# Category 278, France has 0 children
# Category 277, Germany has 0 children
# Category 274, Greece has 0 children
# Category 273, Hong Kong has 0 children
# Category 272, India has 0 children
# Category 271, Ireland has 0 children
# Category 276, Italy has 0 children
# Category 275, Japan has 0 children
# Category 270, Malaysia has 0 children
# Category 269, Mexico has 0 children
# Category 268, Netherlands has 0 children
# Category 266, New Zealand has 0 children
# Category 265, Norway has 0 children
# Category 264, Portugal has 0 children
# Category 263, Singapore has 0 children
# Category 262, South Africa has 0 children
# Category 261, South Korea has 0 children
# Category 260, Spain has 0 children
# Category 259, Sri Lanka has 0 children
# Category 258, Sweden has 0 children
# Category 257, Switzerland has 0 children
# Category 267, Taiwan has 0 children
# Category 254, Thailand has 0 children
# Category 191, United Kingdom has 0 children
# Category 192, Venezuela has 0 children

# %% [markdown]
# ### Monetary Data
#
# cat_id = 24

# %%
args = {"category_id": 24}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 124,
#     "name": "Monetary Base",
#     "parent_id": 24
#   },
#   {
#     "id": 123,
#     "name": "Reserves",
#     "parent_id": 24
#   },
#   {
#     "id": 25,
#     "name": "M1 and Components",
#     "parent_id": 24
#   },
#   {
#     "id": 29,
#     "name": "M2 and Components",
#     "parent_id": 24
#   },
#   {
#     "id": 96,
#     "name": "M2 Minus Small Time Deposits",
#     "parent_id": 24
#   },
#   {
#     "id": 28,
#     "name": "M3 and Components",
#     "parent_id": 24
#   },
#   {
#     "id": 30,
#     "name": "MZM",
#     "parent_id": 24
#   },
#   {
#     "id": 26,
#     "name": "Memorandum Items",
#     "parent_id": 24
#   },
#   {
#     "id": 32242,
#     "name": "Money Velocity",
#     "notes": "Velocity is a ratio of nominal GDP to a measure of the money supply (M1 or M2).  It can be thought of as the rate of turnover in the money supply--that is, the number of times one dollar is used to purchase final goods and services included in GDP.",
#     "parent_id": 24
#   },
#   {
#     "id": 122,
#     "name": "Borrowings",
#     "parent_id": 24
#   },
#   {
#     "id": 32215,
#     "name": "Factors Affecting Reserve Balances",
#     "parent_id": 24
#   },
#   {
#     "id": 32218,
#     "name": "Securities, Loans, & Other Assets & Liabilities Held by Fed",
#     "parent_id": 24
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 124, Monetary Base has 0 children
# Category 123, Reserves has 0 children
# Category 25, M1 and Components has 0 children
# Category 29, M2 and Components has 0 children
# Category 96, M2 Minus Small Time Deposits has 0 children
# Category 28, M3 and Components has 0 children
# Category 30, MZM has 0 children
# Category 26, Memorandum Items has 0 children
# Category 32242, Money Velocity has 0 children
# Category 122, Borrowings has 0 children
# Category 32215, Factors Affecting Reserve Balances has 0 children
# Category 32218, Securities, Loans, & Other Assets & Liabilities Held by Fed has 0 children

# %% [markdown]
# #### Bond Market Indexes
#
# cat_id = 32414

# %%
args = {"category_id": 32414}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32413,
#     "name": "BofA Merrill Lynch Total Bond Return Index Values",
#     "parent_id": 32414
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 32413, BofA Merrill Lynch Total Bond Return Index Values has 0 children

# %% [markdown]
# ### Financial Indicators
#
# cat_id = 46

# %%
args = {"category_id": 46}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32414,
#     "name": "Bond Market Indexes",
#     "parent_id": 46
#   },
#   {
#     "id": 33119,
#     "name": "Consumer Financial Condition Indexes",
#     "parent_id": 46
#   },
#   {
#     "id": 32457,
#     "name": "Financial Activity Measures",
#     "parent_id": 46
#   },
#   {
#     "id": 32255,
#     "name": "Stock Market Indexes",
#     "parent_id": 46
#   },
#   {
#     "id": 32425,
#     "name": "Volatility Indexes",
#     "parent_id": 46
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 32414, Bond Market Indexes has 1 children
# Category 33119, Consumer Financial Condition Indexes has 0 children
# Category 32457, Financial Activity Measures has 0 children
# Category 32255, Stock Market Indexes has 0 children
# Category 32425, Volatility Indexes has 0 children

# %% [markdown]
# #### Bond Market Indexes
#
# cat_id = 32414

# %%
args = {"category_id": 32414}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32413,
#     "name": "BofA Merrill Lynch Total Bond Return Index Values",
#     "parent_id": 32414
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 32413, BofA Merrill Lynch Total Bond Return Index Values has 0 children

# %% [markdown]
# ### Banking
#
# cat_id = 23

# %%
args = {"category_id": 23}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 34078,
#     "name": "Banking Indexes",
#     "parent_id": 23
#   },
#   {
#     "id": 100,
#     "name": "Commercial Banking",
#     "parent_id": 23
#   },
#   {
#     "id": 83,
#     "name": "Condition of Banks",
#     "notes": "For census division definitions, see http://research.stlouisfed.org/fred2/censusdivisions.",
#     "parent_id": 23
#   },
#   {
#     "id": 101,
#     "name": "Consumer Credit",
#     "parent_id": 23
#   },
#   {
#     "id": 32440,
#     "name": "Delinquencies and Delinquency Rates",
#     "parent_id": 23
#   },
#   {
#     "id": 33121,
#     "name": "Failures and Assistance Transactions",
#     "parent_id": 23
#   },
#   {
#     "id": 64,
#     "name": "8th District Banking Performance",
#     "parent_id": 23
#   },
#   {
#     "id": 33445,
#     "name": "Mortgage Debt Outstanding",
#     "parent_id": 23
#   },
#   {
#     "id": 32439,
#     "name": "Net Charge-Offs and Charge-Off Rates",
#     "parent_id": 23
#   },
#   {
#     "id": 99,
#     "name": "Securities & Investments",
#     "parent_id": 23
#   },
#   {
#     "id": 34111,
#     "name": "Senior Credit Officer Opinion Survey",
#     "parent_id": 23
#   },
#   {
#     "id": 32239,
#     "name": "Senior Loan Officer Survey",
#     "parent_id": 23
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 34078, Banking Indexes has 0 children
# Category 100, Commercial Banking has 5 children
# Category 83, Condition of Banks has 10 children
# Category 101, Consumer Credit has 0 children
# Category 32440, Delinquencies and Delinquency Rates has 0 children
# Category 33121, Failures and Assistance Transactions has 0 children
# Category 64, 8th District Banking Performance has 8 children
# Category 33445, Mortgage Debt Outstanding has 0 children
# Category 32439, Net Charge-Offs and Charge-Off Rates has 0 children
# Category 99, Securities & Investments has 0 children
# Category 34111, Senior Credit Officer Opinion Survey has 0 children
# Category 32239, Senior Loan Officer Survey has 0 children

# %% [markdown]
# #### Commercial Banking
#
# cat_id = 100

# %%
args = {"category_id": 100}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 33078,
#     "name": "All Commercial Banks",
#     "parent_id": 100
#   },
#   {
#     "id": 33079,
#     "name": "Domestically Chartered Commercial Banks",
#     "parent_id": 100
#   },
#   {
#     "id": 33080,
#     "name": "Foreign-Related Institutions",
#     "notes": "U.S. branches and agencies of foreign banks",
#     "parent_id": 100
#   },
#   {
#     "id": 33081,
#     "name": "Large Domestically Chartered Commercial Banks",
#     "parent_id": 100
#   },
#   {
#     "id": 33082,
#     "name": "Small Domestically Chartered Commercial Banks",
#     "parent_id": 100
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 33078, All Commercial Banks has 0 children
# Category 33079, Domestically Chartered Commercial Banks has 0 children
# Category 33080, Foreign-Related Institutions has 0 children
# Category 33081, Large Domestically Chartered Commercial Banks has 0 children
# Category 33082, Small Domestically Chartered Commercial Banks has 0 children

# %% [markdown]
# #### Condition of Banks
#
# cat_id = 83

# %%
args = {"category_id": 83}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 93,
#     "name": "United States",
#     "parent_id": 83
#   },
#   {
#     "id": 84,
#     "name": "New England Census Division",
#     "notes": "For census division definitions, see http://research.stlouisfed.org/fred2/censusdivisions.",
#     "parent_id": 83
#   },
#   {
#     "id": 85,
#     "name": "Middle Atlantic Census Division",
#     "notes": "For census division definitions, see http://research.stlouisfed.org/fred2/censusdivisions.",
#     "parent_id": 83
#   },
#   {
#     "id": 86,
#     "name": "East North Central Census Division",
#     "notes": "For census division definitions, see http://research.stlouisfed.org/fred2/censusdivisions.",
#     "parent_id": 83
#   },
#   {
#     "id": 87,
#     "name": "West North Central Census Division",
#     "notes": "For census division definitions, see http://research.stlouisfed.org/fred2/censusdivisions.",
#     "parent_id": 83
#   },
#   {
#     "id": 88,
#     "name": "South Atlantic Census Division",
#     "notes": "For census division definitions, see http://research.stlouisfed.org/fred2/censusdivisions.",
#     "parent_id": 83
#   },
#   {
#     "id": 89,
#     "name": "East South Central Census Division",
#     "notes": "For census division definitions, see http://research.stlouisfed.org/fred2/censusdivisions.",
#     "parent_id": 83
#   },
#   {
#     "id": 90,
#     "name": "West South Central Census Division",
#     "notes": "For census division definitions, see http://research.stlouisfed.org/fred2/censusdivisions.",
#     "parent_id": 83
#   },
#   {
#     "id": 91,
#     "name": "Mountain Census Division",
#     "notes": "For census division definitions, see http://research.stlouisfed.org/fred2/censusdivisions.",
#     "parent_id": 83
#   },
#   {
#     "id": 92,
#     "name": "Pacific Census Division",
#     "notes": "For census division definitions, see http://research.stlouisfed.org/fred2/censusdivisions.",
#     "parent_id": 83
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 93, United States has 0 children
# Category 84, New England Census Division has 0 children
# Category 85, Middle Atlantic Census Division has 0 children
# Category 86, East North Central Census Division has 0 children
# Category 87, West North Central Census Division has 0 children
# Category 88, South Atlantic Census Division has 0 children
# Category 89, East South Central Census Division has 0 children
# Category 90, West South Central Census Division has 0 children
# Category 91, Mountain Census Division has 0 children
# Category 92, Pacific Census Division has 0 children

# %% [markdown]
# ### Business Lending
#
# cat_id = 32360

# %%
args = {"category_id": 32360}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32996,
#     "name": "Commercial Paper",
#     "parent_id": 32360
#   },
#   {
#     "id": 32406,
#     "name": "Commercial and Industrial Loans by Time that Pricing Terms Were Set and by Commitment",
#     "parent_id": 32360
#   },
#   {
#     "id": 33439,
#     "name": "Commercial and Industrial Loans Backed by Small Business Association",
#     "parent_id": 32360
#   },
#   {
#     "id": 32361,
#     "name": "Commercial and Industrial Loans Made by All Commercial Banks",
#     "parent_id": 32360
#   },
#   {
#     "id": 32370,
#     "name": "Commercial and Industrial Loans Made by Domestic Banks",
#     "parent_id": 32360
#   },
#   {
#     "id": 32379,
#     "name": "Commercial and Industrial Loans Made by Large Domestic Banks",
#     "parent_id": 32360
#   },
#   {
#     "id": 32388,
#     "name": "Commercial and Industrial Loans Made by Small Domestic Banks",
#     "parent_id": 32360
#   },
#   {
#     "id": 32397,
#     "name": "Commercial and Industrial Loans Made by U.S. Branches and Agencies of Foreign Banks",
#     "parent_id": 32360
#   },
#   {
#     "id": 33440,
#     "name": "Commercial and Industrial Loans Made Under Participation or Syndication",
#     "parent_id": 32360
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 32996, Commercial Paper has 0 children
# Category 32406, Commercial and Industrial Loans by Time that Pricing Terms Were Set and by Commitment has 6 children
# Category 33439, Commercial and Industrial Loans Backed by Small Business Association has 0 children
# Category 32361, Commercial and Industrial Loans Made by All Commercial Banks has 8 children
# Category 32370, Commercial and Industrial Loans Made by Domestic Banks has 8 children
# Category 32379, Commercial and Industrial Loans Made by Large Domestic Banks has 8 children
# Category 32388, Commercial and Industrial Loans Made by Small Domestic Banks has 8 children
# Category 32397, Commercial and Industrial Loans Made by U.S. Branches and Agencies of Foreign Banks has 8 children
# Category 33440, Commercial and Industrial Loans Made Under Participation or Syndication has 0 children

# %% [markdown]
# #### Loans by Time that Pricing Terms Were Set and by Commitment
#
# cat_id = 32406

# %%
args = {"category_id": 32406}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32407,
#     "name": "All Commercial Banks",
#     "parent_id": 32406
#   },
#   {
#     "id": 32408,
#     "name": "Domestic Banks",
#     "parent_id": 32406
#   },
#   {
#     "id": 32409,
#     "name": "Foreign Banks",
#     "parent_id": 32406
#   },
#   {
#     "id": 32410,
#     "name": "Large Domestic Banks",
#     "parent_id": 32406
#   },
#   {
#     "id": 32411,
#     "name": "Small Domestic Banks",
#     "parent_id": 32406
#   },
#   {
#     "id": 32412,
#     "name": "Summary Statistics",
#     "parent_id": 32406
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 32407, All Commercial Banks has 0 children
# Category 32408, Domestic Banks has 0 children
# Category 32409, Foreign Banks has 0 children
# Category 32410, Large Domestic Banks has 0 children
# Category 32411, Small Domestic Banks has 0 children
# Category 32412, Summary Statistics has 0 children

# %% [markdown]
# #### Commercial and Industrial Loans Made by All Commercial Banks
#
# cat_id = 32361

# %%
args = {"category_id": 32361}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32362,
#     "name": "All Commercial and Industrial Loans",
#     "parent_id": 32361
#   },
#   {
#     "id": 32369,
#     "name": "Base Rate of Loans",
#     "parent_id": 32361
#   },
#   {
#     "id": 32364,
#     "name": "Daily Repricing/Maturity Interval",
#     "parent_id": 32361
#   },
#   {
#     "id": 32367,
#     "name": "More Than 365 Days Repricing/Maturity Interval",
#     "parent_id": 32361
#   },
#   {
#     "id": 32368,
#     "name": "Size of Loans",
#     "parent_id": 32361
#   },
#   {
#     "id": 32366,
#     "name": "31 to 365 Days Repricing/Maturity Interval",
#     "parent_id": 32361
#   },
#   {
#     "id": 32365,
#     "name": "2 to 30 Days Repricing/Maturity Interval",
#     "parent_id": 32361
#   },
#   {
#     "id": 32363,
#     "name": "Zero Repricing/Maturity Interval",
#     "parent_id": 32361
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 32362, All Commercial and Industrial Loans has 0 children
# Category 32369, Base Rate of Loans has 0 children
# Category 32364, Daily Repricing/Maturity Interval has 0 children
# Category 32367, More Than 365 Days Repricing/Maturity Interval has 0 children
# Category 32368, Size of Loans has 0 children
# Category 32366, 31 to 365 Days Repricing/Maturity Interval has 0 children
# Category 32365, 2 to 30 Days Repricing/Maturity Interval has 0 children
# Category 32363, Zero Repricing/Maturity Interval has 0 children

# %% [markdown]
# ####  Commercial and Industrial Loans Made by Domestic Banks
#
# cat_id = 32370

# %%
args = {"category_id": 32370}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32371,
#     "name": "All Commercial and Industrial Loans",
#     "parent_id": 32370
#   },
#   {
#     "id": 32375,
#     "name": "Base Rate of Loans",
#     "parent_id": 32370
#   },
#   {
#     "id": 32372,
#     "name": "Daily Repricing/Maturity Interval",
#     "parent_id": 32370
#   },
#   {
#     "id": 32373,
#     "name": "More Than 365 Days Repricing/Maturity Interval",
#     "parent_id": 32370
#   },
#   {
#     "id": 32374,
#     "name": "Size of Loans",
#     "parent_id": 32370
#   },
#   {
#     "id": 32376,
#     "name": "31 to 365 Days Repricing/Maturity Interval",
#     "parent_id": 32370
#   },
#   {
#     "id": 32377,
#     "name": "2 to 30 Days Repricing/Maturity Interval",
#     "parent_id": 32370
#   },
#   {
#     "id": 32378,
#     "name": "Zero Repricing/Maturity Interval",
#     "parent_id": 32370
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 32371, All Commercial and Industrial Loans has 0 children
# Category 32375, Base Rate of Loans has 0 children
# Category 32372, Daily Repricing/Maturity Interval has 0 children
# Category 32373, More Than 365 Days Repricing/Maturity Interval has 0 children
# Category 32374, Size of Loans has 0 children
# Category 32376, 31 to 365 Days Repricing/Maturity Interval has 0 children
# Category 32377, 2 to 30 Days Repricing/Maturity Interval has 0 children
# Category 32378, Zero Repricing/Maturity Interval has 0 children

# %% [markdown]
# #### Commercial and Industrial Loans Made by Large Domestic Banks
#
# cat_id = 32379

# %%
args = {"category_id": 32379}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32380,
#     "name": "All Commercial and Industrial Loans",
#     "parent_id": 32379
#   },
#   {
#     "id": 32381,
#     "name": "Base Rate of Loans",
#     "parent_id": 32379
#   },
#   {
#     "id": 32382,
#     "name": "Daily Repricing/Maturity Interval",
#     "parent_id": 32379
#   },
#   {
#     "id": 32383,
#     "name": "More Than 365 Days Repricing/Maturity Interval",
#     "parent_id": 32379
#   },
#   {
#     "id": 32384,
#     "name": "Size of Loans",
#     "parent_id": 32379
#   },
#   {
#     "id": 32385,
#     "name": "31 to 365 Days Repricing/Maturity Interval",
#     "parent_id": 32379
#   },
#   {
#     "id": 32386,
#     "name": "2 to 30 Days Repricing/Maturity Interval",
#     "parent_id": 32379
#   },
#   {
#     "id": 32387,
#     "name": "Zero Repricing/Maturity Interval",
#     "parent_id": 32379
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 32380, All Commercial and Industrial Loans has 0 children
# Category 32381, Base Rate of Loans has 0 children
# Category 32382, Daily Repricing/Maturity Interval has 0 children
# Category 32383, More Than 365 Days Repricing/Maturity Interval has 0 children
# Category 32384, Size of Loans has 0 children
# Category 32385, 31 to 365 Days Repricing/Maturity Interval has 0 children
# Category 32386, 2 to 30 Days Repricing/Maturity Interval has 0 children
# Category 32387, Zero Repricing/Maturity Interval has 0 children

# %% [markdown]
# #### Commercial and Industrial Loans Made by Small Domestic Banks
#
# cat_id = 32388

# %%
args = {"category_id": 32388}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32389,
#     "name": "All Commercial and Industrial Loans",
#     "parent_id": 32388
#   },
#   {
#     "id": 32390,
#     "name": "Base Rate of Loans",
#     "parent_id": 32388
#   },
#   {
#     "id": 32391,
#     "name": "Daily Repricing/Maturity Interval",
#     "parent_id": 32388
#   },
#   {
#     "id": 32392,
#     "name": "More Than 365 Days Repricing/Maturity Interval",
#     "parent_id": 32388
#   },
#   {
#     "id": 32393,
#     "name": "Size of Loans",
#     "parent_id": 32388
#   },
#   {
#     "id": 32394,
#     "name": "31 to 365 Days Repricing/Maturity Interval",
#     "parent_id": 32388
#   },
#   {
#     "id": 32395,
#     "name": "2 to 30 Days Repricing/Maturity Interval",
#     "parent_id": 32388
#   },
#   {
#     "id": 32396,
#     "name": "Zero Repricing/Maturity Interval",
#     "parent_id": 32388
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 32389, All Commercial and Industrial Loans has 0 children
# Category 32390, Base Rate of Loans has 0 children
# Category 32391, Daily Repricing/Maturity Interval has 0 children
# Category 32392, More Than 365 Days Repricing/Maturity Interval has 0 children
# Category 32393, Size of Loans has 0 children
# Category 32394, 31 to 365 Days Repricing/Maturity Interval has 0 children
# Category 32395, 2 to 30 Days Repricing/Maturity Interval has 0 children
# Category 32396, Zero Repricing/Maturity Interval has 0 children

# %% [markdown]
# #### Commercial and Industrial Loans Made by U.S. Branches and Agencies of Foreign Banks
#
# cat_id = 32397

# %%
args = {"category_id": 32397}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32398,
#     "name": "All Commercial and Industrial Loans",
#     "parent_id": 32397
#   },
#   {
#     "id": 32399,
#     "name": "Base Rate of Loans",
#     "parent_id": 32397
#   },
#   {
#     "id": 32400,
#     "name": "Daily Repricing/Maturity Interval",
#     "parent_id": 32397
#   },
#   {
#     "id": 32401,
#     "name": "More Than 365 Days Repricing/Maturity Interval",
#     "parent_id": 32397
#   },
#   {
#     "id": 32402,
#     "name": "Size of Loans",
#     "parent_id": 32397
#   },
#   {
#     "id": 32403,
#     "name": "31 to 365 Days Repricing/Maturity Interval",
#     "parent_id": 32397
#   },
#   {
#     "id": 32404,
#     "name": "2 to 30 Days Repricing/Maturity Interval",
#     "parent_id": 32397
#   },
#   {
#     "id": 32405,
#     "name": "Zero Repricing/Maturity Interval",
#     "parent_id": 32397
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 32398, All Commercial and Industrial Loans has 0 children
# Category 32399, Base Rate of Loans has 0 children
# Category 32400, Daily Repricing/Maturity Interval has 0 children
# Category 32401, More Than 365 Days Repricing/Maturity Interval has 0 children
# Category 32402, Size of Loans has 0 children
# Category 32403, 31 to 365 Days Repricing/Maturity Interval has 0 children
# Category 32404, 2 to 30 Days Repricing/Maturity Interval has 0 children
# Category 32405, Zero Repricing/Maturity Interval has 0 children

# %% [markdown]
# ### Foreign Exchange Intervention
#
# cat_id = 32145

# %%
args = {"category_id": 32145}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# []

# %%
await children_of_categories(children)

# %% [markdown]
# ## Generate Categories File

# %%
root_id = 32991
root_name = "Money, Banking, & Finance"
filename = f"fred_finance_{root_id}.yaml"
await find_leaf_categories(root_id, root_name, filename)
# Out:
# Found Leaf category Foreign Exchange Intervention
# Found Leaf category AMERIBOR Benchmark Rates
# Found Leaf category Automobile Loan Rates
# Found Leaf category Bankers Acceptance Rate
# Found Leaf category Certificates of Deposit
# Found Leaf category Commercial Paper
# Found Leaf category Corporate Bonds
# Found Leaf category Credit Card Loan Rates
# Found Leaf category EONIA Rates
# Found Leaf category Euro Short-Term Rate
# Found Leaf category Eurodollar Deposits
# Found Leaf category FRB Rates - discount, fed funds, primary credit
# Found Leaf category Interest Checking Accounts
# Found Leaf category Interest Rate Spreads
# Found Leaf category Interest Rate Swaps
# Found Leaf category Long-Term Securities
# Found Leaf category Monetary Policy
# Found Leaf category Money Market Accounts
# Found Leaf category Mortgage Rates
# Found Leaf category Personal Loan Rates
# Found Leaf category Prime Bank Loan Rate
# Found Leaf category Saving Accounts
# Found Leaf category SONIA Rates
# Found Leaf category Treasury Bills
# Found Leaf category Treasury Constant Maturity
# Found Leaf category Treasury Inflation-Indexed Securities
# Found Leaf category Daily Rates
# Found Leaf category Monthly Rates
# Found Leaf category Annual Rates
# Found Leaf category Trade-Weighted Indexes
# Found Leaf category Monetary Base
# Found Leaf category Reserves
# Found Leaf category M1 and Components
# Found Leaf category M2 and Components
# Found Leaf category M2 Minus Small Time Deposits
# Found Leaf category M3 and Components
# Found Leaf category MZM
# Found Leaf category Memorandum Items
# Found Leaf category Money Velocity
# Found Leaf category Borrowings
# Found Leaf category Factors Affecting Reserve Balances
# Found Leaf category Securities, Loans, & Other Assets & Liabilities Held by Fed
# Found Leaf category Consumer Financial Condition Indexes
# Found Leaf category Financial Activity Measures
# Found Leaf category Stock Market Indexes
# Found Leaf category Volatility Indexes
# Found Leaf category Banking Indexes
# Found Leaf category Consumer Credit
# Found Leaf category Delinquencies and Delinquency Rates
# Found Leaf category Failures and Assistance Transactions
# Found Leaf category Mortgage Debt Outstanding
# Found Leaf category Net Charge-Offs and Charge-Off Rates
# Found Leaf category Securities & Investments
# Found Leaf category Senior Credit Officer Opinion Survey
# Found Leaf category Senior Loan Officer Survey
# Found Leaf category Commercial Paper
# Found Leaf category Commercial and Industrial Loans Backed by Small Business Association
