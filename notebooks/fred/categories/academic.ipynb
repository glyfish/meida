# %% [markdown]
# # FRED API Academic Data Categories

# %%
# %reload_ext autoreload
# %autoreload 2

import sys
from pathlib import Path
sys.path.append('../')

from lib.utils import print_json_vertical
from utils import call_tool, children_of_categories, explore_categories, find_leaf_categories

MCP_URL = 'http://localhost:8080/sse'
tool_name = "fred.category_children"

# %% [markdown]
# ## First Level

# %%
args = {"category_id": 0}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32991,
#     "name": "Money, Banking, & Finance",
#     "parent_id": 0
#   },
#   {
#     "id": 10,
#     "name": "Population, Employment, & Labor Markets",
#     "parent_id": 0
#   },
#   {
#     "id": 32992,
#     "name": "National Accounts",
#     "parent_id": 0
#   },
#   {
#     "id": 1,
#     "name": "Production & Business Activity",
#     "parent_id": 0
#   },
#   {
#     "id": 32455,
#     "name": "Prices",
#     "parent_id": 0
#   },
#   {
#     "id": 32263,
#     "name": "International Data",
#     "parent_id": 0
#   },
#   {
#     "id": 3008,
#     "name": "U.S. Regional Data",
#     "parent_id": 0
#   },
#   {
#     "id": 33060,
#     "name": "Academic Data",
#     "parent_id": 0
#   }
# ]

# %% [markdown]
# ## Academic Data
#
# cat_id = 33060

# %%
args = {"category_id": 33060}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 33833,
#     "name": "Banking and Monetary Statistics, 1914-1941",
#     "notes": "This data is from the Board of Governors' Banking and Monetary Statistics 1914-1941 publication.",
#     "parent_id": 33060
#   },
#   {
#     "id": 33951,
#     "name": "Daily Federal Funds Rate, 1928-54",
#     "parent_id": 33060
#   },
#   {
#     "id": 33825,
#     "name": "Data on the nominal term structure model from Kim and Wright",
#     "parent_id": 33060
#   },
#   {
#     "id": 33891,
#     "name": "Historical Federal Reserve Data",
#     "parent_id": 33060
#   },
#   {
#     "id": 33061,
#     "name": "NBER Macrohistory Database",
#     "parent_id": 33060
#   },
#   {
#     "id": 33100,
#     "name": "Penn World Table 7.1",
#     "parent_id": 33060
#   },
#   {
#     "id": 33402,
#     "name": "Penn World Table 9.0",
#     "parent_id": 33060
#   },
#   {
#     "id": 33120,
#     "name": "Recession Probabilities",
#     "parent_id": 33060
#   },
#   {
#     "id": 33123,
#     "name": "Weekly U.S. and State Bond Prices, 1855-1865",
#     "parent_id": 33060
#   },
#   {
#     "id": 33201,
#     "name": "Economic Policy Uncertainty",
#     "parent_id": 33060
#   },
#   {
#     "id": 33442,
#     "name": "Sticky Wages and Comovement",
#     "parent_id": 33060
#   },
#   {
#     "id": 33839,
#     "name": "A Millennium of Macroeconomic Data for the UK",
#     "parent_id": 33060
#   },
#   {
#     "id": 33934,
#     "name": "New England Textile Industry, 1815-1860",
#     "parent_id": 33060
#   },
#   {
#     "id": 34000,
#     "name": "The Effects of the 1930s HOLC \"Redlining\" Maps",
#     "parent_id": 33060
#   },
#   {
#     "id": 34309,
#     "name": "U.S. Survey of Working Arrangements and Attitudes",
#     "parent_id": 33060
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 33833, Banking and Monetary Statistics, 1914-1941 has 2 children
# Category 33951, Daily Federal Funds Rate, 1928-54 has 0 children
# Category 33825, Data on the nominal term structure model from Kim and Wright has 0 children
# Category 33891, Historical Federal Reserve Data has 0 children
# Category 33061, NBER Macrohistory Database has 16 children
# Category 33100, Penn World Table 7.1 has 18 children
# Category 33402, Penn World Table 9.0 has 6 children
# Category 33120, Recession Probabilities has 0 children
# Category 33123, Weekly U.S. and State Bond Prices, 1855-1865 has 0 children
# Category 33201, Economic Policy Uncertainty has 0 children
# Category 33442, Sticky Wages and Comovement has 0 children
# Category 33839, A Millennium of Macroeconomic Data for the UK has 7 children
# Category 33934, New England Textile Industry, 1815-1860 has 0 children
# Category 34000, The Effects of the 1930s HOLC "Redlining" Maps has 0 children
# Category 34309, U.S. Survey of Working Arrangements and Attitudes has 0 children

# %% [markdown]
# ## Generate Categories File

# %%
root_id = 33060
root_name = "academic_data"
filename = f"fred_academic_data_{root_id}.yaml"
await find_leaf_categories(root_id, root_name, filename)
# Out:
# Found Leaf category Daily Federal Funds Rate, 1928-54
# Found Leaf category Data on the nominal term structure model from Kim and Wright
# Found Leaf category Historical Federal Reserve Data
# Found Leaf category Recession Probabilities
# Found Leaf category Weekly U.S. and State Bond Prices, 1855-1865
# Found Leaf category Economic Policy Uncertainty
# Found Leaf category Sticky Wages and Comovement
# Found Leaf category New England Textile Industry, 1815-1860
# Found Leaf category The Effects of the 1930s HOLC "Redlining" Maps
# Found Leaf category U.S. Survey of Working Arrangements and Attitudes
# Found Leaf category Section 1. General Statistics of All Banks in the United States
# Found Leaf category Section 2. Assets and Liabilities of All Member Banks
# Found Leaf category Production of Commodities
# Found Leaf category Construction
# Found Leaf category Transportation and Public Utilities
# Found Leaf category Prices
# Found Leaf category Stocks of Commodities
# Found Leaf category Distribution of Commodities
# Found Leaf category Foreign Trade
# Found Leaf category Income and Employment
# Found Leaf category Financial Status of Business
# Found Leaf category Savings and Investment
# Found Leaf category Security Markets
# Found Leaf category Volume of Transactions
# Found Leaf category Interest Rates
# Found Leaf category Money and Banking
# Found Leaf category Government and Finance
# Found Leaf category Leading Indicators
# Found Leaf category Component Shares of GDP per Capita (Constant Prices)
# Found Leaf category Component Shares of GDP per Capita (Current Prices)
# Found Leaf category Exchange Rates
# Found Leaf category GDP per Capita (Current Prices)
# Found Leaf category Gross Domestic Income, Adjustments for Changes in Terms of Trade
# Found Leaf category Openness
# Found Leaf category Population
# Found Leaf category Price Levels of GDP, Consumption, Government, and Investment
# Found Leaf category Purchasing Power Parity
# Found Leaf category Purchasing Power Parity Converted GDP
# Found Leaf category Ratio of GNP to GDP
# Found Leaf category Real GDP per Capita (Constant Prices)
# Found Leaf category Real GDP per Capita Relative to U.S.
# Found Leaf category Real GDP per Equivalent Adult
# Found Leaf category Real GDP per Hour Worked by Employees
# Found Leaf category Real GDP per Person Engaged
# Found Leaf category Real GDP per Person Counted in Total Employment
# Found Leaf category Real GDP per Worker
# Found Leaf category Real GDP, Employment and Population Levels
# Found Leaf category Current Price GDP, Capital and Total Factor Productivity
# Found Leaf category National Accounts-Based Variables
# Found Leaf category Exchange Rates and GDP Price Levels
# Found Leaf category Shares in Output-side Real GDP at Current Purchasing Power Parities
# Found Leaf category Price Levels, Expenditure Categories and Capital
# Found Leaf category National Accounts
# Found Leaf category Labour, Capital and Productivity
# Found Leaf category Wages and Prices
# Found Leaf category Financial Markets
# Found Leaf category Money and Credit
# Found Leaf category Fiscal
# Found Leaf category Trade
# Wrote 59 leaf categories (with names) to fred_academic_data_33060.yaml
