# %% [markdown]
# # FRED API National Accounts Categories

# %%
# %reload_ext autoreload
# %autoreload 2

import sys
from pathlib import Path
sys.path.append('../')

from lib.utils import print_json_vertical
from utils import call_tool, children_of_categories, explore_categories, find_leaf_categories

MCP_URL = 'http://localhost:8080/sse'
tool_name = "fred.category_children"

# %% [markdown]
# ## First Level

# %%
args = {"category_id": 0}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32991,
#     "name": "Money, Banking, & Finance",
#     "parent_id": 0
#   },
#   {
#     "id": 10,
#     "name": "Population, Employment, & Labor Markets",
#     "parent_id": 0
#   },
#   {
#     "id": 32992,
#     "name": "National Accounts",
#     "parent_id": 0
#   },
#   {
#     "id": 1,
#     "name": "Production & Business Activity",
#     "parent_id": 0
#   },
#   {
#     "id": 32455,
#     "name": "Prices",
#     "parent_id": 0
#   },
#   {
#     "id": 32263,
#     "name": "International Data",
#     "parent_id": 0
#   },
#   {
#     "id": 3008,
#     "name": "U.S. Regional Data",
#     "parent_id": 0
#   },
#   {
#     "id": 33060,
#     "name": "Academic Data",
#     "parent_id": 0
#   }
# ]

# %% [markdown]
# ## National Accounts
#
# cat_id = 32992

# %%
args = {"category_id": 32992}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 18,
#     "name": "National Income & Product Accounts",
#     "parent_id": 32992
#   },
#   {
#     "id": 5,
#     "name": "Federal Government Debt",
#     "parent_id": 32992
#   },
#   {
#     "id": 32251,
#     "name": "Flow of Funds",
#     "parent_id": 32992
#   },
#   {
#     "id": 13,
#     "name": "U.S. Trade & International Transactions",
#     "parent_id": 32992
#   }
# ]

# %% [markdown]
# ### National Income & Product Accounts
#
# cat_id = 18

# %%
args = {"category_id": 18}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 112,
#     "name": "Domestic Capital Account (Saving & Investment)",
#     "parent_id": 18
#   },
#   {
#     "id": 108,
#     "name": "Foreign Transactions",
#     "parent_id": 18
#   },
#   {
#     "id": 33697,
#     "name": "Fixed Assets",
#     "parent_id": 18
#   },
#   {
#     "id": 33122,
#     "name": "Gross Domestic Income",
#     "parent_id": 18
#   },
#   {
#     "id": 106,
#     "name": "GDP/GNP",
#     "parent_id": 18
#   },
#   {
#     "id": 107,
#     "name": "Gov't Receipts, Expenditures & Investment",
#     "parent_id": 18
#   },
#   {
#     "id": 33719,
#     "name": "Health Care Spending",
#     "parent_id": 18
#   },
#   {
#     "id": 33054,
#     "name": "Imputations",
#     "parent_id": 18
#   },
#   {
#     "id": 33045,
#     "name": "Industry",
#     "parent_id": 18
#   },
#   {
#     "id": 110,
#     "name": "Personal Income & Outlays",
#     "parent_id": 18
#   },
#   {
#     "id": 21,
#     "name": "Price Indexes & Deflators",
#     "parent_id": 18
#   },
#   {
#     "id": 109,
#     "name": "Private Enterprise Income",
#     "parent_id": 18
#   },
#   {
#     "id": 33021,
#     "name": "Quantity Indexes",
#     "parent_id": 18
#   },
#   {
#     "id": 33401,
#     "name": "Effect of ARRA on Selected NIPA Estimates",
#     "parent_id": 18
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 112, Domestic Capital Account (Saving & Investment) has 8 children
# Category 108, Foreign Transactions has 2 children
# Category 33697, Fixed Assets has 3 children
# Category 33122, Gross Domestic Income has 0 children
# Category 106, GDP/GNP has 1 children
# Category 107, Gov't Receipts, Expenditures & Investment has 6 children
# Category 33719, Health Care Spending has 0 children
# Category 33054, Imputations has 0 children
# Category 33045, Industry has 24 children
# Category 110, Personal Income & Outlays has 5 children
# Category 21, Price Indexes & Deflators has 0 children
# Category 109, Private Enterprise Income has 4 children
# Category 33021, Quantity Indexes has 0 children
# Category 33401, Effect of ARRA on Selected NIPA Estimates has 0 children

# %% [markdown]
# #### Domestic Capital Account (Saving & Investment)
#
# cat_id = 112

# %%
args = {"category_id": 112}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
await children_of_categories(children)
# Out:
# Category 33042, Capital Transfers Paid has 0 children
# Category 33043, Capital Transfers Received has 0 children
# Category 33040, Consumptions of Fixed Capital has 0 children
# Category 33041, Corporate Capital Consumption has 0 children
# Category 33037, Domestic Investments has 0 children
# Category 33038, Inventories has 0 children
# Category 33044, Noncorporate Business has 0 children
# Category 33039, Private Fixed Investments has 0 children

# %% [markdown]
# #### Foreign Transactions
#
# cat_id = 108

# %%
args = {"category_id": 108}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
await children_of_categories(children)
# Out:
# Category 33018, Exports has 0 children
# Category 33019, Imports has 0 children

# %% [markdown]
# #### Fixed Assets
#
# cat_id = 33697

# %%
args = {"category_id": 33697}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
await children_of_categories(children)
# Out:
# Category 33699, Net Stocks has 0 children
# Category 33701, Depreciation has 0 children
# Category 33703, Fixed Investment has 0 children

# %% [markdown]
# #### GDP/GNP
#
# cat_id = 106

# %%
args = {"category_id": 106}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
await children_of_categories(children)
# Out:
# Category 33020, Shares of GDP has 0 children

# %% [markdown]
# #### Gov't Receipts, Expenditures & Investment
#
# cat_id = 107

# %%
args = {"category_id": 107}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
await children_of_categories(children)
# Out:
# Category 33022, Gov't Consumption Expenditures has 0 children
# Category 33024, Gov't Current Expenditures has 0 children
# Category 33025, Gov't Current Transfer Receipts has 0 children
# Category 33027, Gov't Fixed Investment has 0 children
# Category 33023, Gov't Investment has 0 children
# Category 33026, Gov't Social Benefits has 0 children

# %% [markdown]
# #### Industry
#
# cat_id = 33045

# %%
args = {"category_id": 33045}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
await children_of_categories(children)
# Out:
# Category 33883, Administrative and Waste Management Services has 0 children
# Category 33859, Agriculture, Forestry, Fishing, and Hunting has 0 children
# Category 33887, Arts, Entertainment, Recreation, Accommodation, and Food Services has 0 children
# Category 33046, Auto Output has 0 children
# Category 33865, Construction has 0 children
# Category 33885, Educational Services, Health Care, and Social Assistance has 0 children
# Category 33047, Farm Output has 0 children
# Category 33877, Finance, Insurance, Real Estate, Rental, and Leasing has 0 children
# Category 33050, Full-time Equivalent Employees has 0 children
# Category 33049, Full-time & Part-time Employees has 0 children
# Category 33889, Government has 0 children
# Category 33048, Households has 0 children
# Category 33053, Imputed Interest has 0 children
# Category 33875, Information has 0 children
# Category 33881, Management Of Companies and Enterprises has 0 children
# Category 33867, Manufacturing has 0 children
# Category 33861, Mining has 0 children
# Category 33052, Persons Engaged in Production has 0 children
# Category 33879, Professional and Business Services has 0 children
# Category 33871, Retail Trade has 0 children
# Category 33051, Self-employed Persons has 0 children
# Category 33873, Transportation and Warehousing has 0 children
# Category 33863, Utilities has 0 children
# Category 33869, Wholesale Trade has 0 children

# %% [markdown]
# #### Personal Income & Outlays
#
# cat_id = 110

# %%
args = {"category_id": 110}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
await children_of_categories(children)
# Out:
# Category 33029, Compensation of Employees has 0 children
# Category 33031, Employer Contributions has 0 children
# Category 33028, Personal Consumption Expenditures has 0 children
# Category 33032, Personal Current Taxes has 0 children
# Category 33030, Wage and Salary Accruals has 0 children

# %% [markdown]
# #### Private Enterprise Income
#
# cat_id = 109

# %%
args = {"category_id": 109}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
await children_of_categories(children)
# Out:
# Category 33035, Corporate Dividends has 0 children
# Category 33033, Corporate Profits has 0 children
# Category 33036, Proprietorship has 0 children
# Category 33034, Taxes on Corporate Income has 0 children

# %% [markdown]
# ### Federal Government Debt
#
# cat_id = 5

# %%
args = {"category_id": 5}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# []

# %% [markdown]
# ### Flow of Funds
#
# cat_id = 32251

# %%
args = {"category_id": 32251}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32258,
#     "name": "B.101 Balance Sheet of Households and Nonprofit Organizations",
#     "parent_id": 32251
#   },
#   {
#     "id": 32259,
#     "name": "B.103 Balance Sheet of Nonfinancial Corporate Business",
#     "parent_id": 32251
#   },
#   {
#     "id": 32260,
#     "name": "B.104 Balance Sheet of Nonfinancial Noncorporate Business",
#     "parent_id": 32251
#   },
#   {
#     "id": 32256,
#     "name": "D.3 Credit Market Debt Outstanding by Sector",
#     "parent_id": 32251
#   },
#   {
#     "id": 32257,
#     "name": "L.1 Credit Market Debt Outstanding",
#     "parent_id": 32251
#   },
#   {
#     "id": 33722,
#     "name": "L.203 Net Interbank Transactions",
#     "parent_id": 32251
#   },
#   {
#     "id": 33726,
#     "name": "L.208 Debt Securities",
#     "parent_id": 32251
#   },
#   {
#     "id": 33729,
#     "name": "L.214 Loans",
#     "parent_id": 32251
#   },
#   {
#     "id": 33204,
#     "name": "S.1 Total Economy - Current Account",
#     "parent_id": 32251
#   },
#   {
#     "id": 33205,
#     "name": "S.2 Selected Aggregates for Total Economy and Sectors",
#     "parent_id": 32251
#   },
#   {
#     "id": 33240,
#     "name": "S.3 Households and Nonprofit Institutions Serving Households",
#     "parent_id": 32251
#   },
#   {
#     "id": 33241,
#     "name": "S.4 Nonfinancial Noncorporate Business",
#     "parent_id": 32251
#   },
#   {
#     "id": 33242,
#     "name": "S.5 Nonfinancial Corporate Business",
#     "parent_id": 32251
#   },
#   {
#     "id": 33243,
#     "name": "S.6 Financial Business",
#     "parent_id": 32251
#   },
#   {
#     "id": 33244,
#     "name": "S.7 Federal Government",
#     "parent_id": 32251
#   },
#   {
#     "id": 33245,
#     "name": "S.8 State and Local Governments",
#     "parent_id": 32251
#   },
#   {
#     "id": 33246,
#     "name": "S.9 Rest of the World",
#     "parent_id": 32251
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 32258, B.101 Balance Sheet of Households and Nonprofit Organizations has 0 children
# Category 32259, B.103 Balance Sheet of Nonfinancial Corporate Business has 0 children
# Category 32260, B.104 Balance Sheet of Nonfinancial Noncorporate Business has 0 children
# Category 32256, D.3 Credit Market Debt Outstanding by Sector has 0 children
# Category 32257, L.1 Credit Market Debt Outstanding has 0 children
# Category 33722, L.203 Net Interbank Transactions has 0 children
# Category 33726, L.208 Debt Securities has 0 children
# Category 33729, L.214 Loans has 0 children
# Category 33204, S.1 Total Economy - Current Account has 0 children
# Category 33205, S.2 Selected Aggregates for Total Economy and Sectors has 0 children
# Category 33240, S.3 Households and Nonprofit Institutions Serving Households has 0 children
# Category 33241, S.4 Nonfinancial Noncorporate Business has 0 children
# Category 33242, S.5 Nonfinancial Corporate Business has 0 children
# Category 33243, S.6 Financial Business has 0 children
# Category 33244, S.7 Federal Government has 0 children
# Category 33245, S.8 State and Local Governments has 0 children
# Category 33246, S.9 Rest of the World has 0 children

# %% [markdown]
# ### U.S. Trade & International Transactions
#
# cat_id = 13

# %%
args = {"category_id": 13}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 16,
#     "name": "Exports",
#     "parent_id": 13
#   },
#   {
#     "id": 17,
#     "name": "Imports",
#     "parent_id": 13
#   },
#   {
#     "id": 3000,
#     "name": "Income Payments & Receipts",
#     "parent_id": 13
#   },
#   {
#     "id": 33705,
#     "name": "International Investment Position",
#     "parent_id": 13
#   },
#   {
#     "id": 125,
#     "name": "Trade Balance",
#     "parent_id": 13
#   },
#   {
#     "id": 127,
#     "name": "U.S. International Finance",
#     "parent_id": 13
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 16, Exports has 0 children
# Category 17, Imports has 0 children
# Category 3000, Income Payments & Receipts has 0 children
# Category 33705, International Investment Position has 0 children
# Category 125, Trade Balance has 0 children
# Category 127, U.S. International Finance has 0 children

# %% [markdown]
# ## Generate Categories File

# %%
root_id = 32992
root_name = "National Accounts"
filename = f"fred_national_accounts_{root_id}.yaml"
await find_leaf_categories(root_id, root_name, filename)
# Out:
# Found Leaf category Federal Government Debt
# Found Leaf category Gross Domestic Income
# Found Leaf category Health Care Spending
# Found Leaf category Imputations
# Found Leaf category Price Indexes & Deflators
# Found Leaf category Quantity Indexes
# Found Leaf category Effect of ARRA on Selected NIPA Estimates
# Found Leaf category B.101 Balance Sheet of Households and Nonprofit Organizations
# Found Leaf category B.103 Balance Sheet of Nonfinancial Corporate Business
# Found Leaf category B.104 Balance Sheet of Nonfinancial Noncorporate Business
# Found Leaf category D.3 Credit Market Debt Outstanding by Sector
# Found Leaf category L.1 Credit Market Debt Outstanding
# Found Leaf category L.203 Net Interbank Transactions
# Found Leaf category L.208 Debt Securities
# Found Leaf category L.214 Loans
# Found Leaf category S.1 Total Economy - Current Account
# Found Leaf category S.2 Selected Aggregates for Total Economy and Sectors
# Found Leaf category S.3 Households and Nonprofit Institutions Serving Households
# Found Leaf category S.4 Nonfinancial Noncorporate Business
# Found Leaf category S.5 Nonfinancial Corporate Business
# Found Leaf category S.6 Financial Business
# Found Leaf category S.7 Federal Government
# Found Leaf category S.8 State and Local Governments
# Found Leaf category S.9 Rest of the World
# Found Leaf category Exports
# Found Leaf category Imports
# Found Leaf category Income Payments & Receipts
# Found Leaf category International Investment Position
# Found Leaf category Trade Balance
# Found Leaf category U.S. International Finance
# Found Leaf category Capital Transfers Paid
# Found Leaf category Capital Transfers Received
# Found Leaf category Consumptions of Fixed Capital
# Found Leaf category Corporate Capital Consumption
# Found Leaf category Domestic Investments
# Found Leaf category Inventories
# Found Leaf category Noncorporate Business
# Found Leaf category Private Fixed Investments
# Found Leaf category Exports
# Found Leaf category Imports
# Found Leaf category Net Stocks
# Found Leaf category Depreciation
# Found Leaf category Fixed Investment
# Found Leaf category Shares of GDP
# Found Leaf category Gov't Consumption Expenditures
# Found Leaf category Gov't Current Expenditures
# Found Leaf category Gov't Current Transfer Receipts
# Found Leaf category Gov't Fixed Investment
# Found Leaf category Gov't Investment
# Found Leaf category Gov't Social Benefits
# Found Leaf category Administrative and Waste Management Services
# Found Leaf category Agriculture, Forestry, Fishing, and Hunting
# Found Leaf category Arts, Entertainment, Recreation, Accommodation, and Food Services
# Found Leaf category Auto Output
# Found Leaf category Construction
# Found Leaf category Educational Services, Health Care, and Social Assistance
# Found Leaf category Farm Output
# Found Leaf category Finance, Insurance, Real Estate, Rental, and Leasing
# Found Leaf category Full-time Equivalent Employees
# Found Leaf category Full-time & Part-time Employees
# Found Leaf category Government
# Found Leaf category Households
# Found Leaf category Imputed Interest
# Found Leaf category Information
# Found Leaf category Management Of Companies and Enterprises
# Found Leaf category Manufacturing
# Found Leaf category Mining
# Found Leaf category Persons Engaged in Production
# Found Leaf category Professional and Business Services
# Found Leaf category Retail Trade
# Found Leaf category Self-employed Persons
# Found Leaf category Transportation and Warehousing
# Found Leaf category Utilities
# Found Leaf category Wholesale Trade
# Found Leaf category Compensation of Employees
# Found Leaf category Employer Contributions
# Found Leaf category Personal Consumption Expenditures
# Found Leaf category Personal Current Taxes
# Found Leaf category Wage and Salary Accruals
# Found Leaf category Corporate Dividends
# Found Leaf category Corporate Profits
# Found Leaf category Proprietorship
# Found Leaf category Taxes on Corporate Income
# Wrote 83 leaf categories (with names) to fred_national_accounts_32992.yaml
