# %% [markdown]
# # FRED API Production Categories

# %%
# %reload_ext autoreload
# %autoreload 2

import sys
from pathlib import Path
sys.path.append('../')

from lib.utils import print_json_vertical
from utils import call_tool, children_of_categories, explore_categories, find_leaf_categories

MCP_URL = 'http://localhost:8080/sse'
tool_name = "fred.category_children"

# %% [markdown]
# ## First Level

# %%
args = {"category_id": 0}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32991,
#     "name": "Money, Banking, & Finance",
#     "parent_id": 0
#   },
#   {
#     "id": 10,
#     "name": "Population, Employment, & Labor Markets",
#     "parent_id": 0
#   },
#   {
#     "id": 32992,
#     "name": "National Accounts",
#     "parent_id": 0
#   },
#   {
#     "id": 1,
#     "name": "Production & Business Activity",
#     "parent_id": 0
#   },
#   {
#     "id": 32455,
#     "name": "Prices",
#     "parent_id": 0
#   },
#   {
#     "id": 32263,
#     "name": "International Data",
#     "parent_id": 0
#   },
#   {
#     "id": 3008,
#     "name": "U.S. Regional Data",
#     "parent_id": 0
#   },
#   {
#     "id": 33060,
#     "name": "Academic Data",
#     "parent_id": 0
#   }
# ]

# %% [markdown]
# ## Production & Business Activity
#
# cat_id = 1

# %%
args = {"category_id": 1}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32262,
#     "name": "Business Cycle Expansions & Contractions",
#     "parent_id": 1
#   },
#   {
#     "id": 33936,
#     "name": "Business Surveys",
#     "parent_id": 1
#   },
#   {
#     "id": 32436,
#     "name": "Construction",
#     "parent_id": 1
#   },
#   {
#     "id": 33940,
#     "name": "Emissions",
#     "parent_id": 1
#   },
#   {
#     "id": 33955,
#     "name": "Expenditures",
#     "parent_id": 1
#   },
#   {
#     "id": 33490,
#     "name": "Finance Companies",
#     "parent_id": 1
#   },
#   {
#     "id": 32216,
#     "name": "Health Insurance",
#     "parent_id": 1
#   },
#   {
#     "id": 97,
#     "name": "Housing",
#     "parent_id": 1
#   },
#   {
#     "id": 3,
#     "name": "Industrial Production & Capacity Utilization",
#     "parent_id": 1
#   },
#   {
#     "id": 32429,
#     "name": "Manufacturing",
#     "parent_id": 1
#   },
#   {
#     "id": 33959,
#     "name": "Patents",
#     "parent_id": 1
#   },
#   {
#     "id": 6,
#     "name": "Retail Trade",
#     "parent_id": 1
#   },
#   {
#     "id": 33441,
#     "name": "Services",
#     "parent_id": 1
#   },
#   {
#     "id": 33492,
#     "name": "Technology",
#     "parent_id": 1
#   },
#   {
#     "id": 33202,
#     "name": "Transportation",
#     "parent_id": 1
#   },
#   {
#     "id": 33203,
#     "name": "Wholesale Trade",
#     "parent_id": 1
#   }
# ]

# %% [markdown]
# ### Business Cycle Expansions & Contractions
#
# cat_id = 32262

# %%
args = {"category_id": 32262}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# []

# %% [markdown]
# ## Business Surveys
#
# cat_id = 33936

# %%
args = {"category_id": 33936}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# []

# %% [markdown]
# ## Construction
#
# cat_id = 32436

# %%
args = {"category_id": 32436}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# []

# %% [markdown]
# ## Emissions
#
# cat_id = 33940

# %%
args = {"category_id": 33940}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# []

# %% [markdown]
# # Expenditures
#
# cat_id = 33955

# %%
args = {"category_id": 33940}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# []

# %% [markdown]
# ## Finance Companies
#
# cat_id = 33490

# %%
args = {"category_id": 33490}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# []

# %% [markdown]
# ## Health Insurance
#
# cat_id = 32216

# %%
args = {"category_id": 32216}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# []

# %% [markdown]
# ## Housing
#
# cat_id = 97

# %%
args = {"category_id": 97}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32300,
#     "name": "Housing Units Authorized by Building Permits",
#     "parent_id": 97
#   },
#   {
#     "id": 32301,
#     "name": "Housing Units Authorized, But Not Yet Started",
#     "parent_id": 97
#   },
#   {
#     "id": 32302,
#     "name": "Housing Starts",
#     "parent_id": 97
#   },
#   {
#     "id": 32303,
#     "name": "Housing Units Under Construction",
#     "parent_id": 97
#   },
#   {
#     "id": 32304,
#     "name": "Housing Units Completed",
#     "parent_id": 97
#   },
#   {
#     "id": 32426,
#     "name": "New Residential Sales",
#     "parent_id": 97
#   },
#   {
#     "id": 33949,
#     "name": "Manufactured Housing",
#     "parent_id": 97
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 32300, Housing Units Authorized by Building Permits has 0 children
# Category 32301, Housing Units Authorized, But Not Yet Started has 0 children
# Category 32302, Housing Starts has 0 children
# Category 32303, Housing Units Under Construction has 0 children
# Category 32304, Housing Units Completed has 0 children
# Category 32426, New Residential Sales has 0 children
# Category 33949, Manufactured Housing has 0 children

# %% [markdown]
# ## Industrial Production & Capacity Utilization
#
# cat_id = 3

# %%
args = {"category_id": 3}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 33938,
#     "name": "Automotive Production Seasonal Factor",
#     "parent_id": 3
#   }
# ]

# %% [markdown]
# ## Manufacturing
#
# cat_id = 32429

# %%
args = {"category_id": 3}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 33938,
#     "name": "Automotive Production Seasonal Factor",
#     "parent_id": 3
#   }
# ]

# %% [markdown]
# ## Patents
#
# cat_id = 33959

# %%
args = {"category_id": 33959}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# []

# %% [markdown]
# ## Retail Trade
#
# cat_id = 33959

# %%
args = {"category_id": 33959}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# []

# %% [markdown]
# ## Services
#
# cat_id = 33441

# %%
args = {"category_id": 33441}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# []

# %% [markdown]
# ## Technology
#
# cat_id=33492

# %%
args = {"category_id": 33492}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# []

# %% [markdown]
# ## Transportation
#
# cat_id=33202

# %%
args = {"category_id": 33202}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32993,
#     "name": "Motor Vehicles",
#     "parent_id": 33202
#   }
# ]

# %% [markdown]
# ## Wholesale Trade
#
# cat_id=33203

# %%
args = {"category_id": 33203}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# []

# %% [markdown]
# ## Generate Categories File

# %%
root_id = 1
root_name = "Production & Business Activity"
filename = f"fred_production_{root_id}.yaml"
await find_leaf_categories(root_id, root_name, filename)
# Out:
# Found Leaf category Business Cycle Expansions & Contractions
# Found Leaf category Business Surveys
# Found Leaf category Construction
# Found Leaf category Emissions
# Found Leaf category Finance Companies
# Found Leaf category Health Insurance
# Found Leaf category Patents
# Found Leaf category Retail Trade
# Found Leaf category Services
# Found Leaf category Technology
# Found Leaf category Wholesale Trade
# Found Leaf category Consumer Expenditures
# Found Leaf category Housing Units Authorized by Building Permits
# Found Leaf category Housing Units Authorized, But Not Yet Started
# Found Leaf category Housing Starts
# Found Leaf category Housing Units Under Construction
# Found Leaf category Housing Units Completed
# Found Leaf category New Residential Sales
# Found Leaf category Manufactured Housing
# Found Leaf category Automotive Production Seasonal Factor
# Found Leaf category Inventories
# Found Leaf category New Orders
# Found Leaf category Inventory to Shipments
# Found Leaf category Unfilled Orders
# Found Leaf category Unfilled Orders to Shipments
# Found Leaf category Shipments
# Found Leaf category Motor Vehicles
# Wrote 27 leaf categories (with names) to fred_production_1.json
