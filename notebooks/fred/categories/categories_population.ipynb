# %% [markdown]
# # FRED API Population Categories

# %%
# %reload_ext autoreload
# %autoreload 2

import sys
from pathlib import Path
sys.path.append('../')

from lib.utils import print_json_vertical
from utils import call_tool, children_of_categories, explore_categories, find_leaf_categories

MCP_URL = 'http://localhost:8080/sse'
tool_name = "fred.category_children"

# %% [markdown]
# ## First Level

# %%
args = {"category_id": 0}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32991,
#     "name": "Money, Banking, & Finance",
#     "parent_id": 0
#   },
#   {
#     "id": 10,
#     "name": "Population, Employment, & Labor Markets",
#     "parent_id": 0
#   },
#   {
#     "id": 32992,
#     "name": "National Accounts",
#     "parent_id": 0
#   },
#   {
#     "id": 1,
#     "name": "Production & Business Activity",
#     "parent_id": 0
#   },
#   {
#     "id": 32455,
#     "name": "Prices",
#     "parent_id": 0
#   },
#   {
#     "id": 32263,
#     "name": "International Data",
#     "parent_id": 0
#   },
#   {
#     "id": 3008,
#     "name": "U.S. Regional Data",
#     "parent_id": 0
#   },
#   {
#     "id": 33060,
#     "name": "Academic Data",
#     "parent_id": 0
#   }
# ]

# %% [markdown]
# ## Population, Employment, & Labor Markets
#
# cat_id = 10

# %%
args = {"category_id": 10}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 12,
#     "name": "Current Population Survey (Household Survey)",
# ...

# %% [markdown]
# ### Current Population Survey (Household Survey)
#
# cat_id = 12

# %%
args = {"category_id": 12}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32442,
#     "name": "Civilian Labor Force",
#     "notes": "All persons in the civilian noninstitutional population classified as either employed or unemployed.",
#     "parent_id": 12
#   },
#   {
#     "id": 32443,
#     "name": "Civilian Labor Force Participation Rate",
#     "parent_id": 12
#   },
#   {
#     "id": 32444,
#     "name": "Employment",
#     "notes": "Employed persons consist of: persons who did any work for pay or profit during the survey reference week; persons who did at least 15 hours of unpaid work in a family-operated enterprise; and persons who were temporarily absent from their regular jobs because of illness, vacation, bad weather, industrial dispute, or various personal reasons. Each employed person is counted only once, even if he or she holds more than one job.",
#     "parent_id": 12
#   },
#   {
#     "id": 32445,
#     "name": "Employment Population Ratio",
# ...

# %%
await children_of_categories(children)
# Out:
# Category 32442, Civilian Labor Force has 0 children
# Category 32443, Civilian Labor Force Participation Rate has 0 children
# Category 32444, Employment has 0 children
# Category 32445, Employment Population Ratio has 0 children
# Category 32446, Unemployment Level has 0 children
# Category 32447, Unemployment Rate has 0 children
# Category 32448, Not in Labor Force has 0 children
# Category 32449, Labor Force Participation Rate has 0 children
# Category 32450, Multiple Jobholders has 0 children
# Category 32451, Duration of Unemployment has 0 children
# Category 32452, Losers and Leavers has 0 children
# Category 33501, Earnings has 0 children
# Category 32453, Entrants and Reentrants has 0 children
# Category 33502, Labor Force Status Flows has 0 children

# %% [markdown]
# ### Current Employment Statistics (Establishment Survey)
#
# cat_id = 11

# %%
args = {"category_id": 11}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32305,
#     "name": "Total Nonfarm",
#     "parent_id": 11
#   },
#   {
#     "id": 32306,
#     "name": "Total Private",
#     "parent_id": 11
#   },
#   {
#     "id": 32307,
#     "name": "Goods-Producing",
#     "parent_id": 11
#   },
#   {
#     "id": 32326,
#     "name": "Service-Providing",
#     "parent_id": 11
#   },
#   {
#     "id": 32308,
#     "name": "Private Service-Providing",
#     "parent_id": 11
#   },
#   {
#     "id": 32309,
#     "name": "Mining and Logging",
#     "parent_id": 11
#   },
#   {
#     "id": 32310,
#     "name": "Construction",
#     "parent_id": 11
#   },
#   {
#     "id": 32311,
#     "name": "Manufacturing",
#     "parent_id": 11
#   },
#   {
#     "id": 32312,
#     "name": "Durable Goods",
#     "parent_id": 11
#   },
#   {
#     "id": 32313,
#     "name": "Nondurable Goods",
#     "parent_id": 11
#   },
#   {
#     "id": 32314,
#     "name": "Trade, Transportation, and Utilities",
#     "parent_id": 11
#   },
#   {
# ...

# %%
await children_of_categories(children)
# Out:
# Category 32305, Total Nonfarm has 0 children
# Category 32306, Total Private has 0 children
# Category 32307, Goods-Producing has 0 children
# Category 32326, Service-Providing has 0 children
# Category 32308, Private Service-Providing has 0 children
# Category 32309, Mining and Logging has 0 children
# Category 32310, Construction has 0 children
# Category 32311, Manufacturing has 0 children
# Category 32312, Durable Goods has 0 children
# Category 32313, Nondurable Goods has 0 children
# Category 32314, Trade, Transportation, and Utilities has 0 children
# Category 32315, Wholesale Trade has 0 children
# Category 32316, Retail Trade has 0 children
# Category 32317, Transportation and Warehousing has 0 children
# Category 32318, Utilities has 0 children
# Category 32319, Information has 0 children
# Category 32320, Financial Activities has 0 children
# Category 32321, Professional and Business Services has 0 children
# Category 32322, Education and Health Services has 0 children
# ...

# %% [markdown]
# ### ADP Employment
#
# cat_id = 32250

# %%
args = {"category_id": 32250}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# []

# %% [markdown]
# ### Education
#
# cat_id = 33500

# %%
args = {"category_id": 33500}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# []

# %% [markdown]
# ### Income Distribution
#
# cat_id = 33001

# %%
args = {"category_id": 33001}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# []

# %% [markdown]
# ### Job Openings and Labor Turnover (JOLTS)
#
# cat_id = 32241

# %%
args = {"category_id": 32241}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 32243,
#     "name": "Job Openings (Levels and Rates)",
#     "parent_id": 32241
#   },
#   {
#     "id": 32245,
#     "name": "Hires (Levels and Rates)",
#     "parent_id": 32241
#   },
#   {
#     "id": 32246,
#     "name": "Total Separations (Levels and Rates)",
#     "parent_id": 32241
#   },
#   {
#     "id": 32247,
#     "name": "Quits (Levels and Rates)",
#     "parent_id": 32241
#   },
#   {
#     "id": 32248,
#     "name": "Layoffs and Discharges (Levels and Rates)",
#     "parent_id": 32241
#   },
#   {
#     "id": 32249,
#     "name": "Other Separations (Levels and Rates)",
#     "parent_id": 32241
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 32243, Job Openings (Levels and Rates) has 0 children
# Category 32245, Hires (Levels and Rates) has 0 children
# Category 32246, Total Separations (Levels and Rates) has 0 children
# Category 32247, Quits (Levels and Rates) has 0 children
# Category 32248, Layoffs and Discharges (Levels and Rates) has 0 children
# Category 32249, Other Separations (Levels and Rates) has 0 children

# %% [markdown]
# ### Labor Market Conditions
#
# cat_id = 33509

# %%
args = {"category_id": 33509}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# []

# %% [markdown]
# ### Population
#
# cat_id = 104

# %%
args = {"category_id": 104}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 33735,
#     "name": "Poverty Measures",
#     "parent_id": 104
#   },
#   {
#     "id": 33514,
#     "name": "Supplemental Nutrition Assistance Program",
#     "parent_id": 104
#   }
# ]

# %%
await children_of_categories(children)
# Out:
# Category 33735, Poverty Measures has 0 children
# Category 33514, Supplemental Nutrition Assistance Program has 0 children

# %% [markdown]
# ### Productivity & Costs
#
# cat_id = 2

# %%
args = {"category_id": 2}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# [
#   {
#     "id": 33961,
#     "name": "Agriculture, Forestry, Fishing and Hunting",
#     "parent_id": 2
#   },
#   {
#     "id": 33963,
#     "name": "Mining",
#     "parent_id": 2
#   },
#   {
#     "id": 33965,
#     "name": "Utilities",
#     "parent_id": 2
#   },
#   {
#     "id": 33967,
#     "name": "Construction",
#     "parent_id": 2
#   },
#   {
#     "id": 32349,
#     "name": "Manufacturing",
#     "parent_id": 2
#   },
#   {
#     "id": 33969,
#     "name": "Wholesale Trade",
#     "parent_id": 2
#   },
#   {
#     "id": 33972,
#     "name": "Retail Trade",
#     "parent_id": 2
#   },
#   {
#     "id": 33974,
#     "name": "Transportation and Warehousing",
#     "parent_id": 2
#   },
#   {
#     "id": 33976,
#     "name": "Information",
#     "parent_id": 2
#   },
#   {
#     "id": 33978,
#     "name": "Finance and Insurance",
#     "parent_id": 2
#   },
#   {
#     "id": 33980,
#     "name": "Real Estate and Rental and Leasing",
#     "parent_id": 2
#   },
#   {
# ...

# %%
await children_of_categories(children)
# Out:
# Category 33961, Agriculture, Forestry, Fishing and Hunting has 0 children
# Category 33963, Mining has 0 children
# Category 33965, Utilities has 0 children
# Category 33967, Construction has 0 children
# Category 32349, Manufacturing has 2 children
# Category 33969, Wholesale Trade has 0 children
# Category 33972, Retail Trade has 0 children
# Category 33974, Transportation and Warehousing has 0 children
# Category 33976, Information has 0 children
# Category 33978, Finance and Insurance has 0 children
# Category 33980, Real Estate and Rental and Leasing has 0 children
# Category 33982, Professional, Scientific, and Technical Services has 0 children
# Category 33984, Management of Companies and Enterprises has 0 children
# Category 33986, Administrative and Support and Waste Management and Remediation Services has 0 children
# Category 33988, Educational Services has 0 children
# Category 33990, Health Care and Social Assistance has 0 children
# ...

# %% [markdown]
# ### Minimum Wage
#
# cat_id = 33831

# %%
args = {"category_id": 33831}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# []

# %% [markdown]
# ### Weekly Initial Claims
#
# cat_id = 32240

# %%
args = {"category_id": 32240}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# []

# %% [markdown]
# ### Tax Data
#
# cat_id = 33731

# %%
args = {"category_id": 33731}
result = await call_tool(tool_name, args)
children = result.structuredContent['result']['categories'] # type: ignore
print_json_vertical(children)
# Out:
# []

# %% [markdown]
# ## Generate Categories File

# %%
root_id = 10
root_name = "Population, Employment, & Labor Markets"
filename = f"fred_population_{root_id}.yaml"
await find_leaf_categories(root_id, root_name, filename)
# Out:
# Found Leaf category ADP Employment
# Found Leaf category Education
# Found Leaf category Income Distribution
# Found Leaf category Labor Market Conditions
# Found Leaf category Minimum Wage
# Found Leaf category Weekly Initial Claims
# Found Leaf category Tax Data
# Found Leaf category Civilian Labor Force
# Found Leaf category Civilian Labor Force Participation Rate
# Found Leaf category Employment
# Found Leaf category Employment Population Ratio
# Found Leaf category Unemployment Level
# Found Leaf category Unemployment Rate
# Found Leaf category Not in Labor Force
# Found Leaf category Labor Force Participation Rate
# Found Leaf category Multiple Jobholders
# Found Leaf category Duration of Unemployment
# Found Leaf category Losers and Leavers
# Found Leaf category Earnings
# Found Leaf category Entrants and Reentrants
# Found Leaf category Labor Force Status Flows
# Found Leaf category Total Nonfarm
# Found Leaf category Total Private
# Found Leaf category Goods-Producing
# ...
