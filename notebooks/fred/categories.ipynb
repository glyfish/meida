# %% [markdown]
# # FRED API Categories

# %%
from typing import Any
from lib.mcp_client import MCPClient, MCPClientConfig
from lib.utils import print_json_vertical

MCP_URL = 'http://localhost:8080/sse'

# %%
config = MCPClientConfig(url=MCP_URL)

async def call_tool(tool_name: str, arguments: dict[str, Any] | None = None):
    async with MCPClient(config) as client:
        result = await client.call_tool(tool_name, arguments or {})
        print_json_vertical(result.model_dump())


async def explore_categories(root_id: int = 0, depth: int = 2):
    async with MCPClient(config) as client:
        queue = [(root_id, 0)]
        while queue:
            category_id, level = queue.pop(0)
            indent = "  " * level
            print(f"{indent}- category {category_id}")
            if level >= depth:
                continue
            response = await client.call_tool("fred.category_children", {"category_id": category_id})
            payload = response.structuredContent or {}
            for child in payload.get("categories", []):
                queue.append((child["id"], level + 1))

tool_name = "fred.category_children"

# %% [markdown]
# ## First Level

# %%
args = {"category_id": 0}
result = await call_tool(tool_name, args)
# Out:
# {
#   "content": [
#     {
#       "annotations": null,
#       "meta": null,
#       "text": "{\n  \"categories\": [\n    {\n      \"id\": 32991,\n      \"name\": \"Money, Banking, & Finance\",\n      \"parent_id\": 0\n    },\n    {\n      \"id\": 10,\n      \"name\": \"Population, Employment, & Labor Markets\",\n      \"parent_id\": 0\n    },\n    {\n      \"id\": 32992,\n      \"name\": \"National Accounts\",\n      \"parent_id\": 0\n    },\n    {\n      \"id\": 1,\n      \"name\": \"Production & Business Activity\",\n      \"parent_id\": 0\n    },\n    {\n      \"id\": 32455,\n      \"name\": \"Prices\",\n      \"parent_id\": 0\n    },\n    {\n      \"id\": 32263,\n      \"name\": \"International Data\",\n      \"parent_id\": 0\n    },\n    {\n      \"id\": 3008,\n      \"name\": \"U.S. Regional Data\",\n      \"parent_id\": 0\n    },\n    {\n      \"id\": 33060,\n      \"name\": \"Academic Data\",\n      \"parent_id\": 0\n    }\n  ]\n}",
#       "type": "text"
#     }
#   ],
# ...

# %% [markdown]
# ## Money, Banking, & Finance
#
# cat_id = 32991

# %%
args = {"category_id": 32991}
result = await call_tool(tool_name, args)
# Out:
# {
#   "content": [
#     {
#       "annotations": null,
#       "meta": null,
# ...

# %% [markdown]
# ### Interest Rates
#
# cat_id = 22

# %%
args = {"category_id": 22}
result = await call_tool(tool_name, args)
# Out:
# {
#   "content": [
#     {
#       "annotations": null,
#       "meta": null,
# ...

# %% [markdown]
# #### AMERIBOR Benchmark Rates
#
# cat_id = 34009

# %%
args = {"category_id": 34009}
result = await call_tool(tool_name, args)
# Out:
# {
#   "content": [
#     {
#       "annotations": null,
#       "meta": null,
#       "text": "{\n  \"categories\": []\n}",
#       "type": "text"
#     }
#   ],
#   "isError": false,
#   "meta": null,
#   "structuredContent": {
#     "result": {
#       "categories": []
#     }
#   }
# }

# %% [markdown]
# #### Automobile Loan Rates
#
# cat_id = 33058

# %% [markdown]
# #### Automobile Loan Rates
#
# cat_id = 33058

# %% [markdown]
# ## Population, Employment, & Labor Markets
#
# cat_id = 10

# %%
args = {"category_id": 10}
result = await call_tool(tool_name, args)
# Out:
# {
#   "content": [
#     {
#       "annotations": null,
#       "meta": null,
# ...

# %% [markdown]
# ## National Accounts
#
# cat_id = 32992

# %%
args = {"category_id": 32992}
result = await call_tool(tool_name, args)
# Out:
# {
#   "content": [
#     {
#       "annotations": null,
#       "meta": null,
#       "text": "{\n  \"categories\": [\n    {\n      \"id\": 18,\n      \"name\": \"National Income & Product Accounts\",\n      \"parent_id\": 32992\n    },\n    {\n      \"id\": 5,\n      \"name\": \"Federal Government Debt\",\n      \"parent_id\": 32992\n    },\n    {\n      \"id\": 32251,\n      \"name\": \"Flow of Funds\",\n      \"parent_id\": 32992\n    },\n    {\n      \"id\": 13,\n      \"name\": \"U.S. Trade & International Transactions\",\n      \"parent_id\": 32992\n    }\n  ]\n}",
#       "type": "text"
#     }
#   ],
#   "isError": false,
#   "meta": null,
#   "structuredContent": {
#     "result": {
#       "categories": [
#         {
#           "id": 18,
#           "name": "National Income & Product Accounts",
#           "parent_id": 32992
#         },
#         {
#           "id": 5,
#           "name": "Federal Government Debt",
#           "parent_id": 32992
#         },
#         {
# ...

# %% [markdown]
# ## Production & Business Activity
#
# cat_id = 1

# %%
args = {"category_id": 1}
result = await call_tool(tool_name, args)
# Out:
# {
#   "content": [
#     {
#       "annotations": null,
#       "meta": null,
# ...

# %% [markdown]
# ## International Data
#
# cat_id = 32263

# %%
args = {"category_id": 32263}
result = await call_tool(tool_name, args)
# Out:
# {
#   "content": [
#     {
#       "annotations": null,
#       "meta": null,
#       "text": "{\n  \"categories\": [\n    {\n      \"id\": 32264,\n      \"name\": \"Countries\",\n      \"parent_id\": 32263\n    },\n    {\n      \"id\": 32955,\n      \"name\": \"Geography\",\n      \"parent_id\": 32263,\n      \"notes\": \"This category contains both data aggregated for a specific geographic region and a way to find country categories based upon geographic region.\"\n    },\n    {\n      \"id\": 32265,\n      \"name\": \"Indicators\",\n      \"parent_id\": 32263\n    },\n    {\n      \"id\": 32956,\n      \"name\": \"Institutions\",\n      \"parent_id\": 32263,\n      \"notes\": \"This category contains data aggregated for multinational institutions and a way to find country series by membership to institutions.\"\n    }\n  ]\n}",
#       "type": "text"
#     }
#   ],
#   "isError": false,
#   "meta": null,
#   "structuredContent": {
#     "result": {
#       "categories": [
# ...

# %% [markdown]
# ## U.S. Regional Data
#
# cat_id = 3008

# %%
args = {"category_id":  3008}
result = await call_tool(tool_name, args)
# Out:
# {
#   "content": [
#     {
#       "annotations": null,
#       "meta": null,
#       "text": "{\n  \"categories\": [\n    {\n      \"id\": 27281,\n      \"name\": \"States\",\n      \"parent_id\": 3008\n    },\n    {\n      \"id\": 32043,\n      \"name\": \"Census Regions\",\n      \"parent_id\": 3008\n    },\n    {\n      \"id\": 32061,\n      \"name\": \"BEA Regions\",\n      \"parent_id\": 3008\n    },\n    {\n      \"id\": 32849,\n      \"name\": \"BLS Regions\",\n      \"parent_id\": 3008\n    },\n    {\n      \"id\": 32071,\n      \"name\": \"Federal Reserve Districts\",\n      \"parent_id\": 3008\n    },\n    {\n      \"id\": 32233,\n      \"name\": \"Freddie Mac Regions\",\n      \"parent_id\": 3008\n    }\n  ]\n}",
#       "type": "text"
#     }
#   ],
#   "isError": false,
#   "meta": null,
#   "structuredContent": {
#     "result": {
#       "categories": [
#         {
#           "id": 27281,
#           "name": "States",
#           "parent_id": 3008
#         },
# ...

# %% [markdown]
# ## Academic Data
#
# cat_id = 33060

# %%
args = {"category_id": 33060}
result = await call_tool(tool_name, args)
# Out:
# {
#   "content": [
#     {
#       "annotations": null,
#       "meta": null,
# ...
